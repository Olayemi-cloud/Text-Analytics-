# %% [markdown]
# # Lab 4: Regular Expressions and Text Normalisation
#
# ### Learning Outcomes
# * Be able to set up a Python and Jupyter notebook environment for text analytics
# * Understand how to use regular expressions to preprocess text
# * Know how to carry out text normalisation using the NLTK library
#
# ### Outline
#
# * Getting started: how to set up your environment, Jupyter notebooks introduction
# * Acquiring raw text data
# * Regular expressions
# * Text normalisation
#
# ### How To Complete This Lab
#
# Read the text and the code then look for 'TODOs' that instruct you to complete some missing code. Aim to work through the lab during the scheduled lab hours. To get help, you can talk to TAs or the lecturer during the labs, post questions to Blackboard (anonymously) or book office hours.
#
# As you work through the notebooks, please make a note of any code that is unclear to you.
#
# The labs *will not be marked*. However, they will prepare you for the coursework, so try to keep up with the weekly labs and have fun with the exercises!

# %% [markdown]
# ## Getting Started
#
# ### Setting up your environment
#
# We recommend using ```conda``` to create an environment with the correct versions of all the packages you need for these labs. You can install either Anaconda or Miniconda, which will include the ```conda``` program.
#
# We provide a .yml file that lists all the packages you will need, and the versions that we have tested the labs with. You can use this file to create your environment as follows.
#
# 1. Open a terminal. Use the command line to navigate to the directory containing this notebook and the file ```crossplatform_environment.yml```. You can use the command ```cd``` to change directory on the command line.
#
# 1. Run the conda program by typing ```conda env create -f crossplatform_environment.yml```, then answer any questions that appear on the command line.
#
# 1. Activate the environment by running the command ```conda activate data_analytics```.
#
# 1. Make kernel available in Jupyter: ```python -m ipykernel install --user --name=data_analytics```.
#
# 1. Relaunch Jupyter: shutdown any running instances, and then type ```jupyter lab``` or ```jupyter notebook``` into your command line, depending on whether you prefer the full Jupyter lab development environment, or the simpler Jupyter notebook.
#
# 1. Find this notebook and open it up again.
#
# 1. Go to the top menu and change the kernel: click on 'Kernel'--> 'Change kernel' --> data_analytics.
#
#
# You should now be ready to go!
#
# The core libraries we will be using in this unit are:
#
# - [Datasets](https://huggingface.co/docs/datasets/), produced by HuggingFace, is a hub for lots of interesting text datasets.
# - [NLTK](https://www.nltk.org), a comprehensive NLP library.
# - [Scikit-learn](https://scikit-learn.org/stable/user_guide.html), for machine learning and classifier evaluation.
# - [Gensim](https://radimrehurek.com/gensim/), for topic modelling.
#
# The libraries above have good documentation, which is available either online (links above) or via Python itself, e.g. `help(numpy.array)` in the Python interpreter.
#
# ### Refreshers for Python and Jupyter
#
# **Skip this part if you are already familiar with Python and Jupyter notebooks.**
#
# This lab assumes you have used Python and Jupyter Notebooks before.
#
# For an introduction or refresher on Python, see the [Introduction to Python lab](https://github.com/UoB-COMS21202/lab_sheets_public/tree/master/lab_1) or the University of Bristol [Beginning Python](https://milliams.gitlab.io/beginning_python/) course. If you are a beginner with Python, you might also like to look at Chapter 1 in the NLTK book, which also provides a guide for "getting started with Python": https://www.nltk.org/book/
#
# You will need to use Python 3, not Python 2, and Python 3.6 or newer are recommended.
#
# The labs will be run on [Jupyter Notebook](http://jupyter.org/), an interactive coding environment embedded in a webpage supporting various programing languages (Python, R, Lua, etc.) through the concept of kernels.
#
# It allows you to enrich your code with complex comments formatted in Markdown and $\LaTeX$, as well as to place the results of your computation right below your code.
#
# Notebooks are organised in cells which can contain either code (in our case, this will be Python code) or text, which can be easily and nicely formatted using the Markdown notation.
#
# To edit an already existing cell simply double-click on it. You can use the toolbar to insert new cells, edit and delete them (or use keyboard shortcuts which are very handy to speed up coding).
#
# Cells can be run, by hitting `shift+enter` when editing a cell or by clicking on the `Run` button at the top. Running a Markdown cell will simply display the formatted text, while running a code cell will execute the commands executed in it.
#
# **Note**: when you run a code cell, all the created variables, implemented functions and imported libraries will be then available to every other code cell. However, it is commonly assumed that cells will be run sequentially in terms of prerequisites. To reset all variables and functions (for debugging) simply click `Kernel > Restart` from the Jupyter menu.
#
# #### Markdown
#
# Markdown cells allow you to write fancy and simple comments: all of this is written in Markdown - double click on this cell to see the source. An introduction to Markdown syntax can be found [here](https://daringfireball.net/projects/markdown/syntax).
#
# As Markdown is translated to HTML upon displaying it also allows you to use pure HTML: more details are available [here](https://daringfireball.net/projects/markdown/syntax#html).
#
# Finally, you can also display simple $\LaTeX$ equations in Markdown thanks to `MathJax` support. For inline equations wrap your equation between `$` symbols; for display mode equations use `$$`.

# %% [markdown]
# ## 1. Acquiring Raw Text Data
#
# Now, let us get some text data! We will start with the Reuters dataset, which contains financial newswire articles.  Run the code below to download the data from [HuggingFace's datasets hub](https://huggingface.co/datasets/newsgroup):

# %%
from datasets import load_dataset

train_dataset = load_dataset(
    "reuters21578", 
    "ModHayes",  # Choose this variant of the dataset
    split="train",
    cache_dir="./data_cache",  # Save the data here 
)

print(f"Training dataset with {len(train_dataset)} instances loaded")
# Out:
# Reusing dataset reuters21578 (./data_cache\reuters21578\ModHayes\1.0.0\98a2ad6a0242627562db83992f9625261854c40a88619322596153a5a16a206c)
# Training dataset with 20856 instances loaded

# %% [markdown]
# We can access the documents in the dataset like elements in a list. For example, document 3 looks like this:

# %%
train_dataset[3]
# Out:
# {'text': 'BankAmerica Corp is not under\npressure to act quickly on its proposed equity offering and\nwould do well to delay it because of the stock\'s recent poor\nperformance, banking analysts said.\n    Some analysts said they have recommended BankAmerica delay\nits up to one-billion-dlr equity offering, which has yet to be\napproved by the Securities and Exchange Commission.\n    BankAmerica stock fell this week, along with other banking\nissues, on the news that Brazil has suspended interest payments\non a large portion of its foreign debt.\n    The stock traded around 12, down 1/8, this afternoon,\nafter falling to 11-1/2 earlier this week on the news.\n    Banking analysts said that with the immediate threat of the\nFirst Interstate Bancorp &lt;I> takeover bid gone, BankAmerica is\nunder no pressure to sell the securities into a market that\nwill be nervous on bank stocks in the near term.\n    BankAmerica filed the offer on January 26. It was seen as\none of the major factors leading the First Interstate\nwithdrawing its takeover bid on February 9.\n    A BankAmerica spokesman said SEC approval is taking longer\nthan expected and market conditions must now be re-evaluated.\n    "The circumstances at the time will determine what we do,"\nsaid Arthur Miller, BankAmerica\'s Vice President for Financial\nCommunications, when asked if BankAmerica would proceed with\nthe offer immediately after it receives SEC approval.\n    "I\'d put it off as long as they conceivably could," said\nLawrence Cohn, analyst with Merrill Lynch, Pierce, Fenner and\nSmith.\n    Cohn said the longer BankAmerica waits, the longer they\nhave to show the market an improved financial outlook.\n    Although BankAmerica has yet to specify the types of\nequities it would offer, most analysts believed a convertible\npreferred stock would encompass at least part of it.\n    Such an offering at a depressed stock price would mean a\nlower conversion price and more dilution to BankAmerica stock\nholders, noted Daniel Williams, analyst with Sutro Group.\n    Several analysts said that while they believe the Brazilian\ndebt problem will continue to hang over the banking industry\nthrough the quarter, the initial shock reaction is likely to\nease over the coming weeks.\n    Nevertheless, BankAmerica, which holds about 2.70 billion\ndlrs in Brazilian loans, stands to lose 15-20 mln dlrs if the\ninterest rate is reduced on the debt, and as much as 200 mln\ndlrs if Brazil pays no interest for a year, said Joseph\nArsenio, analyst with Birr, Wilson and Co.\n    He noted, however, that any potential losses would not show\nup in the current quarter.\n    With other major banks standing to lose even more than\nBankAmerica if Brazil fails to service its debt, the analysts\nsaid they expect the debt will be restructured, similar to way\nMexico\'s debt was, minimizing losses to the creditor banks.\n Reuter\n',
#  'text_type': '"NORM"',
#  'topics': [],
#  'lewis_split': '"TRAIN"',
#  'cgis_split': '"TRAINING-SET"',
#  'old_id': '"5547"',
#  'new_id': '"4"',
#  'places': ['usa', 'brazil'],
#  'people': [],
#  'orgs': [],
#  'exchanges': [],
#  'date': '26-FEB-1987 15:07:13.72',
#  'title': 'TALKING POINT/BANKAMERICA &lt;BAC> EQUITY OFFER'}

# %% [markdown]
# # 2. Regular Expressions
#
# ## 2.1 Search
#
# Now, let us get to grips with regular expressions. Suppose we want to discover all sentences discussing mergers between companies. A first step would be to find all occurrences of the word 'merger':

# %%
import re  # Python regular expressions library

all_matches = []

for article in train_dataset:
    matches = re.findall('merger', article['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 810
# merger

# %% [markdown]
# This has given us a list of matches in the variable `all_matches`, which all contain the string 'merger', but not the sentences themselves.
# This is not very useful, but we can do better if we define the right regular expression!
#
# Regular expressions define a pattern, rather than a specific string, allowing us to generalise our search and retrieve many different strings that match the pattern.
# In Python, we differentiate a regular expression from a normal string by putting an 'r' character in front of the string.
#
# We can generalise our search by using a _disjunction_, which will match against any one of a set of characters. The disjunction is written inside square brackets.
#
# Let us try to retrieve instances of the word "merger" followed by any letter. We can write a disjunction that matches any lower case letter as `[a-z]`:

# %%
all_matches = []

for article in train_dataset:
    matches = re.findall(r'merger [a-z]', article['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
print(all_matches)
# Out:
# 556
# merger u
# merger r
# merger s
# merger a
# merger f
# merger b
# merger w
# merger t
# merger d
# merger p
# merger n
# merger c
# merger o
# merger i
# merger m
# merger e
# merger h
# merger l
# merger g
# ['merger a', 'merger a', 'merger o', 'merger o', 'merger o', 'merger o', 'merger s', 'merger o', 'merger i', 'merger w', 'merger i', 'merger a', 'merger a', 'merger i', 'merger d', 'merger t', 'merger w', 'merger w', 'merger p', 'merger w', 'merger w', 'merger a', 'merger a', 'merger i', 'merger c', 'merger o', 'merger t', 'merger t', 'merger a', 'merger a', 'merger a', 'merger o', 'merger i', 'merger i', 'merger w', 'merger a', 'merger o', 'merger a', 'merger p', 'merger i', 'merger b', 'merger w', 'merger w', 'merger o', 'merger a', 'merger w', 'merger o', 'merger w', 'merger b', 'merger w', 'merger o', 'merger o', 'merger a', 'merger w', 'merger w', 'merger a', 'merger t', 'merger a', 'merger a', 'merger e', 'merger i', 'merger m', 'merger i', 'merger a', 'merger w', 'merger a', 'merger p', 'merger o', 'merger t', 'merger i', 'merger o', 'merger w', 'merger t', 'merger w', 'merger t', 'merger u', 'merger w', 'merger t', 'merger w', 'merger w', 'merger w', 'merger i', 'merger i', 'merger i', 'merger d', 'merger a', 'merger p', 'merger o', 'merger i', 'merger p', 'merger o', 'merger c', 'merger o', 'merger p', 'merger o', 'merger c', 'merger o', 'merger a', 'merger o', 'merger a', 'merger a', 'merger o', 'merger o', 'merger f', 'merger c', 'merger o', 'merger i', 'merger t', 'merger i', 'merger b', 'merger n', 'merger o', 'merger a', 'merger a', 'merger a', 'merger a', 'merger o', 'merger a', 'merger h', 'merger w', 'merger b', 'merger w', 'merger w', 'merger t', 'merger o', 'merger o', 'merger o', 'merger n', 'merger o', 'merger o', 'merger w', 'merger w', 'merger o', 'merger w', 'merger a', 'merger w', 'merger w', 'merger s', 'merger o', 'merger o', 'merger w', 'merger a', 'merger d', 'merger w', 'merger i', 'merger o', 'merger o', 'merger w', 'merger g', 'merger o', 'merger i', 'merger p', 'merger a', 'merger w', 'merger i', 'merger i', 'merger i', 'merger i', 'merger t', 'merger o', 'merger i', 'merger p', 'merger p', 'merger a', 'merger t', 'merger i', 'merger a', 'merger a', 'merger t', 'merger o', 'merger w', 'merger a', 'merger w', 'merger a', 'merger w', 'merger o', 'merger a', 'merger a', 'merger d', 'merger w', 'merger o', 'merger i', 'merger w', 'merger s', 'merger o', 'merger w', 'merger w', 'merger o', 'merger w', 'merger a', 'merger o', 'merger a', 'merger w', 'merger a', 'merger i', 'merger t', 'merger w', 'merger w', 'merger l', 'merger b', 'merger n', 'merger w', 'merger p', 'merger a', 'merger a', 'merger o', 'merger o', 'merger t', 'merger a', 'merger i', 'merger b', 'merger a', 'merger w', 'merger w', 'merger o', 'merger i', 'merger w', 'merger w', 'merger i', 'merger o', 'merger w', 'merger p', 'merger a', 'merger c', 'merger b', 'merger w', 'merger w', 'merger h', 'merger o', 'merger b', 'merger b', 'merger o', 'merger p', 'merger o', 'merger p', 'merger w', 'merger o', 'merger m', 'merger w', 'merger w', 'merger b', 'merger o', 'merger a', 'merger i', 'merger i', 'merger i', 'merger w', 'merger i', 'merger a', 'merger b', 'merger a', 'merger a', 'merger o', 'merger o', 'merger h', 'merger c', 'merger f', 'merger l', 'merger w', 'merger o', 'merger a', 'merger o', 'merger m', 'merger w', 'merger i', 'merger b', 'merger i', 'merger w', 'merger t', 'merger w', 'merger w', 'merger w', 'merger a', 'merger a', 'merger o', 'merger w', 'merger o', 'merger a', 'merger c', 'merger s', 'merger w', 'merger i', 'merger p', 'merger w', 'merger s', 'merger p', 'merger b', 'merger i', 'merger a', 'merger w', 'merger o', 'merger i', 'merger i', 'merger a', 'merger o', 'merger w', 'merger w', 'merger i', 'merger a', 'merger i', 'merger o', 'merger o', 'merger o', 'merger p', 'merger w', 'merger a', 'merger i', 'merger b', 'merger i', 'merger a', 'merger p', 'merger a', 'merger t', 'merger o', 'merger a', 'merger b', 'merger o', 'merger i', 'merger w', 'merger o', 'merger o', 'merger t', 'merger a', 'merger w', 'merger o', 'merger i', 'merger o', 'merger p', 'merger w', 'merger w', 'merger w', 'merger b', 'merger t', 'me ...

# %% [markdown]
# Our current search only matches a single letter of the word after 'merger'. The length of that following word is variable, so how can we write an expression to match the whole word?
#
# Here, we can use a special character, '\*', which will match against zero or more repetitions of the preceding regular expression. Let us try it out:

# %%
all_matches = []

for article in train_dataset:
    matches = re.findall(r'merger [a-z]*', article['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
print(all_matches)
# Out:
# 560
# merger becomes
# merger had
# merger completed
# merger debt
# merger proxy
# merger expenses
# merger notification
# merger between
# merger at
# merger took
# merger that
# merger by
# merger would
# merger shareholders
# merger is
# merger are
# merger practical
# merger calls
# merger partners
# merger in
# merger should
# merger facility
# merger accord
# merger could
# merger each
# merger provides
# merger offer
# merger speculation
# merger overtures
# merger this
# merger which
# merger analysis
# merger talks
# merger after
# merger with
# merger activity
# merger of
# merger because
# merger on
# merger takes
# merger into
# merger decision
# merger commitment
# merger mania
# merger attempt
# merger still
# merger and
# merger or
# merger involves
# merger plans
# merger following
# merger as
# merger announced
# merger appears
# merger acquisition
# merger transaction
# merger documents
# merger case
# merger until
# merger but
# merger
# merger to
# merger the
# merger within
# merger without
# merger trasaction
# merger for
# merger date
# merger among
# merger application
# merger since
# merger specialists
# merger while
# merger costs
# merger has
# merger guidelines
# merger involving
# merger recently
# merger negotiations
# merger wave
# merger approved
# merger partner
# merger discussions
# merger was
# merger proposal
# merger specialist
# merger offers
# merger we
# merger called
# merger agreement
# merger plan
# merger terms
# merger continues
# merger it
# merger will
# merger last
# merger activities
# merger cannot
# ['merger and', 'merger and', 'merger of', 'merger or', 'merger of', 'merger of', 'merger shareholders', 'merger offers', 'merger into', 'merger with', 'merger is', 'merger at', 'merger agreement', 'merger is', 'merger documents', 'merger this', 'merger with', 'merger with', 'merger plan', 'merger with', 'merger with', 'merger agreement', 'merger agreement', 'merger is', 'merger costs', 'merger of', 'merger talks', 'merger talks', 'merger agreement', 'merger agreement', 'merger ', 'merger agreement', 'merger of', 'merger into', 'merger into', 'merger with', 'merger agreement', 'merger of', 'merger as', 'merger proposal', 'merger is', 'merger between', 'merger with', 'merger would', 'merger of', 'merger agreement', 'merger would', 'merger of', 'merger with', 'merger because', 'merger with', 'merger on', 'merger of', 'merger agreement', 'merger with', 'merger without', 'merger agreement', 'merger to', 'merger agreement', 'merger agreement', 'merger each', 'merger in', 'merger mania', 'merger into', 'merger and', 'merger was', 'merger and', 'merger proposal', 'merger on', 'merger took', 'merger is', 'merger of', 'merger would', 'merger to', 'merger with', 'merger that', 'merger until', 'merger was', 'merger to', 'merger with', 'merger with', 'merger with', 'merger is', 'merger is', 'merger ', 'merger ', 'merger it', 'merger date', 'merger accord', 'merger proposal', 'merger of', 'merger is', 'merger proposal', 'merger of', 'merger case', 'merger of', 'merger plan', 'merger of', 'merger case', 'merger of', 'merger agreement', 'merger offer', 'merger agreement', 'merger agreement', 'merger of', 'merger of', 'merger for', 'merger case', 'merger of', 'merger is', 'merger takes', 'merger in', 'merger but', 'merger notification', 'merger or', 'merger at', 'merger agreement', 'merger and', 'merger at', 'merger offer', 'merger agreement', 'merger has', 'merger will', 'merger between', 'merger with', 'merger with', 'merger talks', 'merger or', 'merger of', 'merger of', 'merger negotiations', 'merger of', 'merger of', 'merger with', 'merger with', 'merger of', 'merger would', 'merger are', 'merger with', 'merger was', 'merger since', 'merger or', 'merger of', 'merger with', 'merger application', 'merger discussions', 'merger which', 'merger is', 'merger of', 'merger or', 'merger wave', 'merger guidelines', 'merger of', 'merger is', 'merger proposal', 'merger agreement', 'merger we', 'merger into', 'merger is', 'merger is', 'merger into', 'merger the', 'merger or', 'merger into', 'merger proxy', 'merger proxy', 'merger agreement', 'merger to', 'merger is', 'merger agreement', 'merger agreement', 'merger takes', 'merger of', 'merger would', 'merger approved', 'merger without', 'merger at', 'merger with', 'merger of', 'merger agreement', 'merger agreement', 'merger discussions', 'merger will', 'merger of', 'merger into', 'merger with', 'merger should', 'merger of', 'merger with', 'merger was', 'merger of', 'merger will', 'merger and', 'merger of', 'merger agreement', 'merger with', 'merger agreement', 'merger into', 'merger ', 'merger talks', 'merger with', 'merger would', 'merger last', 'merger by', 'merger negotiations', 'merger with', 'merger plan', 'merger accord', 'merger as', 'merger of', 'merger of', 'merger terms', 'merger agreement', 'merger into', 'merger between', 'merger among', 'merger with', 'merger will', 'merger or', 'merger is', 'merger with', 'merger with', 'merger is', 'merger or', 'merger with', 'merger proposal', 'merger agreement', 'merger cannot', 'merger between', 'merger with', 'merger was', 'merger has', 'merger of', 'merger between', 'merger between', 'merger or', 'merger partner', 'merger of', 'merger proposal', 'merger with', 'merger of', 'merger mania', 'merger with', 'merger would', 'merger between', 'merger of', 'merger agreement', 'merger into', 'merger is', 'merger into', 'merger with', 'merger is', 'merger and', 'merger but', 'merger at', 'merger agreement', 'merger of', 'merger of', 'merger has', 'merger com ...

# %%
all_matches = []

for article in train_dataset:
    matches = re.findall(r'merger [a-z]+', article['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
print(all_matches)
# Out:
# 556
# merger becomes
# merger had
# merger completed
# merger debt
# merger proxy
# merger expenses
# merger notification
# merger between
# merger at
# merger took
# merger that
# merger by
# merger would
# merger shareholders
# merger is
# merger are
# merger practical
# merger calls
# merger partners
# merger in
# merger should
# merger facility
# merger accord
# merger could
# merger each
# merger provides
# merger offer
# merger speculation
# merger overtures
# merger this
# merger which
# merger analysis
# merger talks
# merger after
# merger with
# merger activity
# merger of
# merger because
# merger on
# merger takes
# merger into
# merger decision
# merger commitment
# merger mania
# merger attempt
# merger still
# merger and
# merger or
# merger involves
# merger plans
# merger following
# merger as
# merger announced
# merger appears
# merger acquisition
# merger transaction
# merger documents
# merger case
# merger until
# merger but
# merger to
# merger the
# merger within
# merger without
# merger trasaction
# merger for
# merger date
# merger among
# merger application
# merger since
# merger specialists
# merger while
# merger costs
# merger has
# merger guidelines
# merger involving
# merger recently
# merger negotiations
# merger wave
# merger approved
# merger partner
# merger discussions
# merger was
# merger proposal
# merger specialist
# merger offers
# merger we
# merger called
# merger agreement
# merger plan
# merger terms
# merger continues
# merger it
# merger will
# merger last
# merger activities
# merger cannot
# ['merger and', 'merger and', 'merger of', 'merger or', 'merger of', 'merger of', 'merger shareholders', 'merger offers', 'merger into', 'merger with', 'merger is', 'merger at', 'merger agreement', 'merger is', 'merger documents', 'merger this', 'merger with', 'merger with', 'merger plan', 'merger with', 'merger with', 'merger agreement', 'merger agreement', 'merger is', 'merger costs', 'merger of', 'merger talks', 'merger talks', 'merger agreement', 'merger agreement', 'merger agreement', 'merger of', 'merger into', 'merger into', 'merger with', 'merger agreement', 'merger of', 'merger as', 'merger proposal', 'merger is', 'merger between', 'merger with', 'merger would', 'merger of', 'merger agreement', 'merger would', 'merger of', 'merger with', 'merger because', 'merger with', 'merger on', 'merger of', 'merger agreement', 'merger with', 'merger without', 'merger agreement', 'merger to', 'merger agreement', 'merger agreement', 'merger each', 'merger in', 'merger mania', 'merger into', 'merger and', 'merger was', 'merger and', 'merger proposal', 'merger on', 'merger took', 'merger is', 'merger of', 'merger would', 'merger to', 'merger with', 'merger that', 'merger until', 'merger was', 'merger to', 'merger with', 'merger with', 'merger with', 'merger is', 'merger is', 'merger it', 'merger date', 'merger accord', 'merger proposal', 'merger of', 'merger is', 'merger proposal', 'merger of', 'merger case', 'merger of', 'merger plan', 'merger of', 'merger case', 'merger of', 'merger agreement', 'merger offer', 'merger agreement', 'merger agreement', 'merger of', 'merger of', 'merger for', 'merger case', 'merger of', 'merger is', 'merger takes', 'merger in', 'merger but', 'merger notification', 'merger or', 'merger at', 'merger agreement', 'merger and', 'merger at', 'merger offer', 'merger agreement', 'merger has', 'merger will', 'merger between', 'merger with', 'merger with', 'merger talks', 'merger or', 'merger of', 'merger of', 'merger negotiations', 'merger of', 'merger of', 'merger with', 'merger with', 'merger of', 'merger would', 'merger are', 'merger with', 'merger was', 'merger since', 'merger or', 'merger of', 'merger with', 'merger application', 'merger discussions', 'merger which', 'merger is', 'merger of', 'merger or', 'merger wave', 'merger guidelines', 'merger of', 'merger is', 'merger proposal', 'merger agreement', 'merger we', 'merger into', 'merger is', 'merger is', 'merger into', 'merger the', 'merger or', 'merger into', 'merger proxy', 'merger proxy', 'merger agreement', 'merger to', 'merger is', 'merger agreement', 'merger agreement', 'merger takes', 'merger of', 'merger would', 'merger approved', 'merger without', 'merger at', 'merger with', 'merger of', 'merger agreement', 'merger agreement', 'merger discussions', 'merger will', 'merger of', 'merger into', 'merger with', 'merger should', 'merger of', 'merger with', 'merger was', 'merger of', 'merger will', 'merger and', 'merger of', 'merger agreement', 'merger with', 'merger agreement', 'merger into', 'merger talks', 'merger with', 'merger would', 'merger last', 'merger by', 'merger negotiations', 'merger with', 'merger plan', 'merger accord', 'merger as', 'merger of', 'merger of', 'merger terms', 'merger agreement', 'merger into', 'merger between', 'merger among', 'merger with', 'merger will', 'merger or', 'merger is', 'merger with', 'merger with', 'merger is', 'merger or', 'merger with', 'merger proposal', 'merger agreement', 'merger cannot', 'merger between', 'merger with', 'merger was', 'merger has', 'merger of', 'merger between', 'merger between', 'merger or', 'merger partner', 'merger of', 'merger proposal', 'merger with', 'merger of', 'merger mania', 'merger with', 'merger would', 'merger between', 'merger of', 'merger agreement', 'merger into', 'merger is', 'merger into', 'merger with', 'merger is', 'merger and', 'merger but', 'merger at', 'merger agreement', 'merger of', 'merger of', 'merger has', 'merger commitment', 'merger facility', 'merger last',  ...

# %% [markdown]
# Now, let us try to match the preceding word as well. It would be better to match capital letters as well as lower case, which we can do with the disjunction `[a-zA-Z]`.
#
# TODO 1: complete the code below to retrieve the words that precede and follow 'merger', including capitalised and lower case words.

# %%
all_matches = []

for article in train_dataset:
    pattern = r'\b(\w+)\s+(?:merger|Merger|MERGER)\s+(\w+)\b'
    
    ### COMPLETE THE CODE HERE
    matches = re.findall(pattern, article['text'])
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 611
# ('Baker', 'on')
# ('Cyclop', 'agreement')
# ('dlr', 'with')
# ('seeking', 'partners')
# ('the', 'called')
# ('reverse', 'last')
# ('end', 'while')
# ('the', 'until')
# ('into', 'negotiations')
# ('of', 'provides')
# ('the', 'becomes')
# ('proposed', 'between')
# ('the', 'by')
# ('proposed', 'is')
# ('proposed', 'of')
# ('proposed', 'documents')
# ('a', 'to')
# ('a', 'agreement')
# ('the', 'offer')
# ('preliminary', 'proposal')
# ('Progressive', 'because')
# ('and', 'could')
# ('resulting', 'would')
# ('their', 'completed')
# ('found', 'partners')
# ('a', 'as')
# ('the', 'terms')
# ('of', 'providing')
# ('Communications', 'Corp')
# ('proposed', 'into')
# ('TBS', 'agreement')
# ('a', 'plan')
# ('conversion', 'recently')
# ('of', 'Kaiser')
# ('a', 'attempt')
# ('planned', 'for')
# ('proposed', 'at')
# ('terminated', 'talks')
# ('its', 'proposal')
# ('proposed', 'and')
# ('subsequent', 'with')
# ('The', 'still')
# ('the', 'on')
# ('The', 'agreement')
# ('a', 'between')
# ('rail', 'case')
# ('biggest', 'since')
# ('and', 'Commission')
# ('pursue', 'talks')
# ('a', 'is')
# ('the', 'for')
# ('reflect', 'in')
# ('whole', 'mania')
# ('said', 'discussions')
# ('Rainbow', 'involves')
# ('rampant', 'mania')
# ('Rainbow', 'and')
# ('nonrecurring', 'expenses')
# ('its', 'with')
# ('of', 'with')
# ('s', 'activities')
# ('its', 'commitment')
# ('The', 'plan')
# ('and', 'and')
# ('the', 'should')
# ('to', 'with')
# ('the', 'cannot')
# ('a', 'under')
# ('satisfactory', 'agreement')
# ('a', 'into')
# ('proposed', 'involving')
# ('proposed', 'until')
# ('cash', 'with')
# ('the', 'continues')
# ('That', 'was')
# ('the', 'with')
# ('acceptable', 'agreement')
# ('defintive', 'agreement')
# ('the', 'accord')
# ('a', 'which')
# ('the', 'within')
# ('a', 'at')
# ('a', 'and')
# ('announced', 'agreement')
# ('the', 'Nolan')
# ('The', 'is')
# ('projected', 'date')
# ('and', 'talks')
# ('s', 'agreement')
# ('tentative', 'talks')
# ('revised', 'offers')
# ('aborted', 'agreement')
# ('pending', 'of')
# ('suspended', 'talks')
# ('a', 'partner')
# ('anticipated', 'of')
# ('the', 'are')
# ('through', 'or')
# ('the', 'has')
# ('and', 'are')
# ('a', 'took')
# ('a', 'transaction')
# ('step', 'agreement')
# ('A', 'approved')
# ('a', 'would')
# ('preliminary', 'agreement')
# ('Sabena', 'could')
# ('latest', 'plan')
# ('Their', 'would')
# ('The', 'involves')
# ('on', 'speculation')
# ('heightened', 'or')
# ('unsolicited', 'proposal')
# ('announced', 'between')
# ('potential', 'partners')
# ('rejected', 'overtures')
# ('a', 'could')
# ('Airlines', 'would')
# ('by', 'mania')
# ('announced', 'of')
# ('a', 'offer')
# ('interests', 'with')
# ('the', 'each')
# ('the', 'practical')
# ('The', 'will')
# ('its', 'agreement')
# ('the', 'shareholders')
# ('the', 'was')
# ('cash', 'proposal')
# ('way', 'would')
# ('proposed', 'or')
# ('possible', 'with')
# ('the', 'proposal')
# ('announced', 'into')
# ('a', 'of')
# ('The', 'would')
# ('The', 'took')
# ('the', 'that')
# ('ended', 'talks')
# ('formal', 'agreement')
# ('the', 'without')
# ('planned', 'with')
# ('the', 'to')
# ('cash', 'in')
# ('this', 'has')
# ('the', 'in')
# ('the', 'but')
# ('further', 'activity')
# ('way', 'between')
# ('said', 'negotiations')
# ('off', 'discussions')
# ('further', 'negotiations')
# ('proposed', 'has')
# ('The', 'of')
# ('negotiated', 'or')
# ('the', 'blocked')
# ('preliminary', 'proxy')
# ('terminated', 'discussions')
# ('negotiated', 'with')
# ('the', 'we')
# ('the', 'takes')
# ('extended', 'agreement')
# ('its', 'into')
# ('a', 'accord')
# ('announced', 'negotiations')
# ('dlr', 'of')
# ('The', 'calls')
# ('their', 'will')
# ('subsequent', 'will')
# ('their', 'agreement')
# ('the', 'because')
# ('similar', 'operation')
# ('proposed', 'was')
# ('1', 'between')
# ('of', 'proxy')
# ('A', 'at')
# ('the', 'does')
# ('proposed', 'that')
# ('the', 'which')
# ('open', 'discussions')
# ('future', 'between')
# ('corporate', 'wave')
# ('possible', 'but')
# ('share', 'agreement')
# ('that', 'is')
# ('its', 'last')
# ('pending', 'with')
# ('from', 'of')
# ('a', 'trasaction')
# ('represented', 'costs')
# ('proposed', 'with')
# ('the', 'agreement')
# ('the', 'the')
# ('the', 'had')
# ('defnitive', 'agreement')
# ('former', 'specialist')
# ('the', 'took')
# ('definitive', 'agreement')
# ('the', 'as')
# ('a', 'among')
# ('the', 'would')
# ('of', 'analysis')
# ('said', 'talks')
# ('the', 'transaction')
# ('Chemical', 'is')
# ('the', 'decision')
# ('for', 'of')
# ('the', 'announced')
# ('the', 'violated')
# ('a', 'was')
# ('the', 'plan')
# ('possible', 'of')
# ('original', 'plans')
# ('a', 'proposal')
# ('other', 'of')
# ('and', 'candidates')
# ('10', 'of')
# ('share', 'acquisition')
# ('announced', 'with')
# ('each', 'will')
# ('planned', 'of')
# ('friendly', 'for')
# ('any', 'or')
# ('1984', 'of')
# ('s', 'with')
# ('a', 'in')
# ('unsuccessful', 'attempt')
# ('proposed', 'application')
# ('possible', 'into')
# ('to', 'of')
# ('the', 'between')
# ('a', 'or')
# ('simultaneous', 'into')
# ('own', 'guidelines')
# ('cash', 'of')
# ('the', 'is')
# ('the', 'of')
# ('a', 'with')
# ('the', 'facility')
# ('recent', 'that')
# ('The', 'was')
# ('assisted', 'or')
# ('preliminary', 'talks')
# ('announced', 'has')
# ('its', 'and')
# ('the', 'into')
# ('subsequent', 'talks')
# ('their', 'last')
# ('to', 'and')
# ('the', 'be')
# ('the', 'at')
# ('the', 'and')
# ('proposed', 'appears')
# ('or', 'of')
# ('no', 'talks')
# ('through', 'of')
# ('swap', 'agreement')
# ('a', 'application')
# ('proposed', 'as')
# ('revive', 'plans')
# ('reflect', 'with')
# ('Corp', 'proposal')
# ('definitive', 'and')
# ('the', 'after')
# ('its', 'talks')
# ('its', 'debt')
# ('proposed', 'would')
# ('top', 'specialists')
# ('the', 'it')
# ('The', 'following')
# ('the', 'will')
# ('unsolicited', 'offer')
# ('the', 'case')

# %% [markdown]
# ##### Corrrection: For the words preceeding and after merger

# %%
all_matches = []

for article in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r'[a-zA-Z]* merger [a-zA-Z]*', article['text'])
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 494
# 494
# way merger would
# the merger to
# by merger mania
# proposed merger was
# definitive merger agreement
# the merger plan
# former merger specialist
# seeking merger partners
# the merger offer
# a merger with
# found merger partners
# resulting merger would
# and merger talks
# the merger each
# the merger proposal
# dlr merger of
# its merger with
# formal merger agreement
# planned merger with
# and merger and
# the merger by
# preliminary merger proxy
# the merger will
# The merger still
# other merger of
# The merger agreement
# announced merger negotiations
# announced merger between
# their merger last
# possible merger of
# That merger was
# their merger will
# unsolicited merger proposal
# latest merger plan
# negotiated merger with
# of merger provides
# defintive merger agreement
# the merger it
#  merger negotiations
# heightened merger or
# projected merger date
# potential merger partners
# proposed merger until
# to merger with
# further merger activity
# proposed merger has
# from merger of
# the merger has
# acceptable merger agreement
# The merger calls
# end merger while
# The merger will
# announced merger of
# the merger becomes
# announced merger has
# its merger commitment
# the merger at
# subsequent merger will
# the merger continues
# the merger facility
# possible merger with
# a merger at
# rail merger case
# a merger into
# proposed merger involving
# proposed merger would
#  merger into
# assisted merger or
# rejected merger overtures
# any merger or
# the merger within
# its merger agreement
# the merger decision
# the merger on
# Airlines merger would
# proposed merger appears
# the merger between
# a merger partner
# proposed merger documents
# the merger took
# the merger was
# the merger should
# cash merger with
# to merger of
# the merger the
# the merger because
# Sabena merger could
# the merger
# a merger trasaction
# its merger into
# the merger that
# the merger into
#  merger this
# aborted merger agreement
# suspended merger talks
#  merger between
# Chemical merger is
# preliminary merger talks
# their merger completed
# into merger negotiations
# a merger is
# a merger which
# top merger specialists
# the merger for
# the merger Nolan
# biggest merger since
# reflect merger with
# proposed merger of
# the merger after
# and merger could
# The merger following
#  merger and
# a merger attempt
# anticipated merger of
# step merger agreement
# extended merger agreement
# future merger between
# its merger last
# possible merger but
# The merger involves
# the merger are
# A merger at
# pursue merger talks
# this merger has
# definitive merger and
# own merger guidelines
# revised merger offers
# pending merger with
# dlr merger with
# the merger agreement
# a merger was
# preliminary merger proposal
# on merger speculation
# a merger and
# the merger had
# a merger would
# through merger or
# a merger could
# s merger activities
# proposed merger with
# proposed merger is
# simultaneous merger into
# Corp merger proposal
# the merger takes
# The merger plan
# unsolicited merger offer
# a merger of
# a merger as
# The merger was
# proposed merger that
# nonrecurring merger expenses
# the merger with
# announced merger into
# Rainbow merger and
# the merger until
# original merger plans
# the merger without
# satisfactory merger agreement
# proposed merger at
# the merger accord
# the merger which
# subsequent merger with
# whole merger mania
# or merger of
# a merger offer
# a merger proposal
# a merger agreement
# recent merger that
# a merger in
# pending merger of
# Rainbow merger involves
# its merger debt
# The merger of
# the merger announced
# the merger we
# proposed merger and
# the merger would
# s merger with
# corporate merger wave
# the merger terms
# a merger took
# A merger approved
# The merger took
# its merger and
# the merger called
# through merger of
# of merger with
# cash merger proposal
# Progressive merger because
# reverse merger last
# the merger of
# its merger proposal
# proposed merger between
# a merger among
# the merger transaction
# revive merger plans
# the merger and
# announced merger agreement
# the merger as
# of merger Kaiser
# reflect merger in
# proposed merger or
# a merger to
# ended merger talks
# of merger analysis
# preliminary merger agreement
# off merger discussions
# s merger agreement
# TBS merger agreement
# way merger between
# share merger agreement
# the merger but
# The merger is
# rampant merger mania
# share merger acquisition
# proposed merger into
# the merger is
# negotiated merger or
# a merger or
# a merger between
# Their merger would
# a merger accord
# announced merger with
# The merger would
# planned merger of
# for merger of
# conversion merger recently
#  merger of
# the merger cannot
# and merger are
# the merger shareholders
# a merger plan
# Baker merger on
# the merger in
# their merger agreement
# cash merger of

# %% [markdown]
# Other way to achieve this - Added by me (Olayemi): You can achieve the same result by using
#
# import re
#
# all_matches = []
#
# for article in train_dataset:
#     # Regular expression to capture words before and after 'merger' (case insensitive)
#
#     pattern = r'\b(\w+)\s+(?:merger|Merger|MERGER)\s+(\w+)\b'
#
#     matches = re.findall(pattern, article['text'], re.IGNORECASE)  # Find all occurrences
#
#     if matches:
#         all_matches.extend(matches)
#
# print(len(all_matches))  # Number of matches found
#
# for match in set(all_matches):
#     print(match)

# %% [markdown]
# This is starting to look more useful, but we still want to retrieve whole sentences.
#
# Sentences in English are usually demarcated by punctuation, so let us use the following punctuation marks to identify sentence boundaries: '.', '!', '?'. Those punctuation marks are special characters when used in regular expressions, so to force Python to interpret them literally, we need to put the escape character '\' in front of them.
#
# Now, we can write a disjunction that matches against the punctuation like this: `[\.\!\?]`.
#
# To retrieve a whole sentence, we would like to match all of the text between two punctuation marks. Besides letters, the text of a sentence contains space characters and new line characters, which appear as '\n'. These are formatting characters that specify a line break. To retrieve a whole sentence, we will need to match against letters, spaces and new line characters.
#
# TODO 2: Retrieve all strings containing 'merger', starting from the preceding punctuation mark, until the following punctuation mark. To do this, modify the disjunction that matches against letters to also match spaces and new line characters.

# %%
all_matches = []

for article in train_dataset:
    pattern = r'([.!?][\s\n]*([\w\s\n]*?merger[\w\s\n]*?)[.!?])'
    
    ### COMPLETE THE CODE HERE
    matches = re.findall(pattern, article['text'], re.IGNORECASE)
    
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 161
# ('. Independence\nsaid the merger will be accounted for as a pooling of\ninterests.', 'Independence\nsaid the merger will be accounted for as a pooling of\ninterests')
# ('.19 billion dlr merger with Chemical.', '19 billion dlr merger with Chemical')
# ('.\n    But a Cable spokesman said it still believed a merger of\nthe two consortia would be impracticable.', 'But a Cable spokesman said it still believed a merger of\nthe two consortia would be impracticable')
# ('.\n    The aim of the merger is to seek Recognised Investment\nExchange status as required by the 1986 Financial Services Act.', 'The aim of the merger is to seek Recognised Investment\nExchange status as required by the 1986 Financial Services Act')
# ('. We consider this to be a merger\nof equals.', 'We consider this to be a merger\nof equals')
# ('. Canadian Airlines was recently\nformed through the merger of Canadian Pacific Airlines and\nPacific Western Airlines.', 'Canadian Airlines was recently\nformed through the merger of Canadian Pacific Airlines and\nPacific Western Airlines')
# ('.\n   \n    IDC said the merger agreement also provides for payment of\nan equivalent amount in respect of employee stock options to be\ncancelled in the merger.', 'IDC said the merger agreement also provides for payment of\nan equivalent amount in respect of employee stock options to be\ncancelled in the merger')
# ('. Circuit Court of Appeals in San Francisco had\nblocked the merger until a dispute over union representation\nhad been settled by arbitration.', 'Circuit Court of Appeals in San Francisco had\nblocked the merger until a dispute over union representation\nhad been settled by arbitration')
# ('.\n    It said Quest Blood expects to complete the merger within\nthe next several weeks.', 'It said Quest Blood expects to complete the merger within\nthe next several weeks')
# ('.\n    Greyhound announced June 19 that it wanted the ICC to let\nit begin operating Trailways immediately while continuing to\nevaluate the merger for possible antitrust problems.', 'Greyhound announced June 19 that it wanted the ICC to let\nit begin operating Trailways immediately while continuing to\nevaluate the merger for possible antitrust problems')
# ('. Baker then filed a suit seeking punitive damages from\nHughes for calling off the merger.', 'Baker then filed a suit seeking punitive damages from\nHughes for calling off the merger')
# ('.\n    Metzenbaum said he introduced a bill to transfer antitrust\nauthority over airline mergers to the Justice Department in\nhopes it would more restrictive than the Transportation\nDepartment.', 'Metzenbaum said he introduced a bill to transfer antitrust\nauthority over airline mergers to the Justice Department in\nhopes it would more restrictive than the Transportation\nDepartment')
# ('.\n    Mattson also declined to comment on whether the directors\nof Baker and Hughes have scheduled any meetings to discuss the\nmerger.', 'Mattson also declined to comment on whether the directors\nof Baker and Hughes have scheduled any meetings to discuss the\nmerger')
# ('. The company said it will\ntreat the merger as a pooling of interests.', 'The company said it will\ntreat the merger as a pooling of interests')
# ('.\n    The executive said the merger would not alter his target of\nmaintaining sales and earnings growth of 30 pct to 35 pct.', 'The executive said the merger would not alter his target of\nmaintaining sales and earnings growth of 30 pct to 35 pct')
# ('. The resulting merger would\ncreate the largest independent software company yet.', 'The resulting merger would\ncreate the largest independent software company yet')
# ('.\n    Gardner noted that the terms of the merger agreement in\nwhich the company would bought out by a group of its managers\nand E.', 'Gardner noted that the terms of the merger agreement in\nwhich the company would bought out by a group of its managers\nand E')
# ('.\n    The company said it is seriously considering the new offer\nbut has also received an expression of interest for a possible\nmerger into a Fortune 500 company it did not identify that will\nbe investigated at meetings to be held later this week.', 'The company said it is seriously considering the new offer\nbut has also received an expression of interest for a possible\nmerger into a Fortune 500 company it did not identify that will\nbe investigated at meetings to be held later this week')
# ('. Others argue the merger\nwas more cost effective than creating a comparable branch\nnetwork from scratch.', 'Others argue the merger\nwas more cost effective than creating a comparable branch\nnetwork from scratch')
# ('.\n    The company said the board decision to adopt its own\ndivestiture plan and terminate the merger agreement if Baker\ndid not accept was unanimous.', 'The company said the board decision to adopt its own\ndivestiture plan and terminate the merger agreement if Baker\ndid not accept was unanimous')
# ('.\n    The company said it is continuing talks with Piedmont on\narriving at a definitive merger agreement and the two companies\nhope to reach one very shortly.', 'The company said it is continuing talks with Piedmont on\narriving at a definitive merger agreement and the two companies\nhope to reach one very shortly')
# ('.\n    The DOT had given tentative approval to the merger plan\nFeb.', 'The DOT had given tentative approval to the merger plan\nFeb')
# ('.\n    Sorg said the group also agreed to vote as a body on any\nproposed merger or election of directors.', 'Sorg said the group also agreed to vote as a body on any\nproposed merger or election of directors')
# ('.\n    Baker said today it would withdraw the one billion dlr\nlawsuit it had filed to force Hughes to follow through with the\nmerger.', 'Baker said today it would withdraw the one billion dlr\nlawsuit it had filed to force Hughes to follow through with the\nmerger')
# ('. The Banco Pan de Azucar after being taken over by the\nBanco de la Republic in 1985 carried out a similar merger\noperation with the Banco de Italia.', 'The Banco Pan de Azucar after being taken over by the\nBanco de la Republic in 1985 carried out a similar merger\noperation with the Banco de Italia')
# ('.\n    Mattson told Reuters that Baker still believed a merger was\npossible between the two giant oilfield service companies.', 'Mattson told Reuters that Baker still believed a merger was\npossible between the two giant oilfield service companies')
# ('. The complaint said Vaskevitch leaked information\nabout 12 companies that were involved in a merger or aquisition\nwhich resulted in more than four mln dlrs in profit for himself\nand others involved in the scheme.', 'The complaint said Vaskevitch leaked information\nabout 12 companies that were involved in a merger or aquisition\nwhich resulted in more than four mln dlrs in profit for himself\nand others involved in the scheme')
# ('.\n    The swirl of corporate mergers and the financial\ninformation explosion have blurred the distinction between the\nactivities of banks and security brokerages.', 'The swirl of corporate mergers and the financial\ninformation explosion have blurred the distinction between the\nactivities of banks and security brokerages')
# ('. He said the agency has not yet received\na formal notice of the merger which would start the review\nprocess.', 'He said the agency has not yet received\na formal notice of the merger which would start the review\nprocess')
# ('.\n    There was no comparable figure for the third quarter of\n1986 because the company was formed in June 1987 through the\nmerger of RepublicBank Corp and Interfirst Corp.', 'There was no comparable figure for the third quarter of\n1986 because the company was formed in June 1987 through the\nmerger of RepublicBank Corp and Interfirst Corp')
# ('. The following results reflect the\noperations of the companies prior to the merger.', 'The following results reflect the\noperations of the companies prior to the merger')
# ('.\n    The companies said they agreed not to pursue the merger\nbecause several actions recently taken by AmBrit would mean\nsubstantial delays in completing the deal.', 'The companies said they agreed not to pursue the merger\nbecause several actions recently taken by AmBrit would mean\nsubstantial delays in completing the deal')
# ('.\n    Hutton added that PC Acquisition also terminated its merger\nagreement with Purolator.', 'Hutton added that PC Acquisition also terminated its merger\nagreement with Purolator')
# ('. He said he\nbelieves such a merger could create a stronger force in the\ntire industry.', 'He said he\nbelieves such a merger could create a stronger force in the\ntire industry')
# ('.86 dlrs per share on exchange of common of Pan America\nBanks Inc for common of NCNB Corp purusant to a merger of the\ncompanies.', '86 dlrs per share on exchange of common of Pan America\nBanks Inc for common of NCNB Corp purusant to a merger of the\ncompanies')
# ('. The merger is\nexpected to be completed by June 25.', 'The merger is\nexpected to be completed by June 25')
# ('.\n    Hanson said that promptly following the filing of the\ncertificate of merger Kaiser Cement common shares will be\ndelisted from the New York Stock Exchange.', 'Hanson said that promptly following the filing of the\ncertificate of merger Kaiser Cement common shares will be\ndelisted from the New York Stock Exchange')
# ('.19 billion dlr merger.', '19 billion dlr merger')
# ('.\n    Completion of the merger transaction is expected in three\nto four months.', 'Completion of the merger transaction is expected in three\nto four months')
# ('. Several firms had protested the\nproposed merger.', 'Several firms had protested the\nproposed merger')
# ('.\n    Charter said the merger is subject to approval of the\nFederal Home Loan Bank Board.', 'Charter said the merger is subject to approval of the\nFederal Home Loan Bank Board')
# ('.\n    Analysts said the merger would dilute the holdings of\ncurrent Computer Associates shareholders by about 10 pct.', 'Analysts said the merger would dilute the holdings of\ncurrent Computer Associates shareholders by about 10 pct')
# ('.5 mln\ndlrs in costs mainly associated with an unsuccessful merger\nattempt.', '5 mln\ndlrs in costs mainly associated with an unsuccessful merger\nattempt')
# ('.\n    A MITI official told Reuters he did not rule out the\npossibility of further mergers within the Japanese oil industry\nin the event of the relaxation of oil controls.', 'A MITI official told Reuters he did not rule out the\npossibility of further mergers within the Japanese oil industry\nin the event of the relaxation of oil controls')
# ('.\n    S and P cited the adjournment of a special shareholder\nmeeting in which Hughes objected to certain conditions for the\nmerger of the companies set by the U.', 'S and P cited the adjournment of a special shareholder\nmeeting in which Hughes objected to certain conditions for the\nmerger of the companies set by the U')
# ('.\n    Hughes yesterday adjourned the special meeting at which\nshareholders were to vote on the merger without permitting the\ncounting of votes on the deal.', 'Hughes yesterday adjourned the special meeting at which\nshareholders were to vote on the merger without permitting the\ncounting of votes on the deal')
# ('.\n    The company said a definitive merger agreement is expected\nto be negotiated within six weeks and shareholders are expected\nto vote on the deal at a meeting expected to be held in June or\nJuly.', 'The company said a definitive merger agreement is expected\nto be negotiated within six weeks and shareholders are expected\nto vote on the deal at a meeting expected to be held in June or\nJuly')
# ('. That\nmeeting was called to act on a merger agreement calling for a\nbuyout by BCW Acquisitions Inc.', 'That\nmeeting was called to act on a merger agreement calling for a\nbuyout by BCW Acquisitions Inc')
# ('. Kistler\nsaid its counter proposal to merge with Baker International\nCorp was still under consideration and that a merger was in the\nbest interests of both companies.', 'Kistler\nsaid its counter proposal to merge with Baker International\nCorp was still under consideration and that a merger was in the\nbest interests of both companies')
# ('.\n    Kim said mergers of some financial companies and the\nupgrading of others to merchant banks or full banks were being\nconsidered by the financial development committee of the\nfinance ministry.', 'Kim said mergers of some financial companies and the\nupgrading of others to merchant banks or full banks were being\nconsidered by the financial development committee of the\nfinance ministry')
# ('.\n    Entertainment said the offer would be conducted through a\nnegotiated merger with a new corporation to be formed by\nEntertainment Marketing.', 'Entertainment said the offer would be conducted through a\nnegotiated merger with a new corporation to be formed by\nEntertainment Marketing')
# ('.  The\nChemLawn board has approved the tender and a merger at the same\nprice that is to follow.', 'The\nChemLawn board has approved the tender and a merger at the same\nprice that is to follow')
# ('.\n    The change affects 515 mln dlrs in debt and assumes a\nmerger of the two companies will be completed.', 'The change affects 515 mln dlrs in debt and assumes a\nmerger of the two companies will be completed')
# ('.\n    The merger is subject to regulatory and shareholder\napproval.', 'The merger is subject to regulatory and shareholder\napproval')
# ('.\n    Baker International has proposed a merger with Hughes Tool\nwhich could create a 1.', 'Baker International has proposed a merger with Hughes Tool\nwhich could create a 1')
# ('.\n    He said simply looking at the number of challenges filed\nagainst pending mergers was misleading because there was no\nreason to believe that a fixed proportion of all mergers were\nanticompetitive.', 'He said simply looking at the number of challenges filed\nagainst pending mergers was misleading because there was no\nreason to believe that a fixed proportion of all mergers were\nanticompetitive')
# ('.\n    MCO said one MAXXAM shareholder has filed an objection to\nthe proposed settlement of shareholder actions related to the\nmerger in the Delaware Court of Chancery.', 'MCO said one MAXXAM shareholder has filed an objection to\nthe proposed settlement of shareholder actions related to the\nmerger in the Delaware Court of Chancery')
# ('. Justice Department has announced that it will\nrequire divestiture of the product line for approval of the\nmerger.', 'Justice Department has announced that it will\nrequire divestiture of the product line for approval of the\nmerger')
# ('.\n    The merger plan has been criticised for excluding foreign\nfirms from a meaningful position in the market.', 'The merger plan has been criticised for excluding foreign\nfirms from a meaningful position in the market')
# ('.\n    Such a merger would be complex and analysts said it would\nresult in an airline iwth an 18 pct market share.', 'Such a merger would be complex and analysts said it would\nresult in an airline iwth an 18 pct market share')
# ('. Emery\nsaid as a result it is renewing its request that Purolatr enter\ninto merger negotiations with it.', 'Emery\nsaid as a result it is renewing its request that Purolatr enter\ninto merger negotiations with it')
# ('.\n    Hoechst Celanese was formed Feb 27 by the merger of\nCelanese Corp and American Hoechst Corp.', 'Hoechst Celanese was formed Feb 27 by the merger of\nCelanese Corp and American Hoechst Corp')
# ('. S and P said the\nmerger would allow American Security to diversify its wholesale\nfunding base.', 'S and P said the\nmerger would allow American Security to diversify its wholesale\nfunding base')
# ('.\n    The complaint said Vaskevitch leaked information about 12\ncompanies involved in a merger or acquisition which resulted in\nmore than four mln dlrs in profit for himself and others\ninvolved in the scheme.', 'The complaint said Vaskevitch leaked information about 12\ncompanies involved in a merger or acquisition which resulted in\nmore than four mln dlrs in profit for himself and others\ninvolved in the scheme')
# ('. United Security said it is anticipated that\nsuch stock would represent a substantial majority of the shares\noutstanding after the merger.', 'United Security said it is anticipated that\nsuch stock would represent a substantial majority of the shares\noutstanding after the merger')
# ('. \n    The company said it will hold a special meeting on July 10\nfor a vote on approval of a merger at the tender price.', 'The company said it will hold a special meeting on July 10\nfor a vote on approval of a merger at the tender price')
# ('.\n    The offer will be followed by a merger in which each\nremaining share will be converted into 19.', 'The offer will be followed by a merger in which each\nremaining share will be converted into 19')
# ('. Pennzoil said the merger\nviolated a prior agreement it had to buy Getty and sued Texaco.', 'Pennzoil said the merger\nviolated a prior agreement it had to buy Getty and sued Texaco')
# ('.5 mln dlrs\nfor the merger facility.', '5 mln dlrs\nfor the merger facility')
# ('.  But Imtec said no\nmerger talks havew yet taken place.', 'But Imtec said no\nmerger talks havew yet taken place')
# ('.\n    The ICC had rejected in July the merger of the Santa Fe and\nSouthern Pacific Railroads on the grounds that it would reduce\ncompetition.', 'The ICC had rejected in July the merger of the Santa Fe and\nSouthern Pacific Railroads on the grounds that it would reduce\ncompetition')
# ('.\n    Analysts said the merger is virtually certain to go ahead.', 'Analysts said the merger is virtually certain to go ahead')
# ('.\n    The Post and Telecommunications Ministry has urged the\nmerger of the two firms because it says the market can only\nsupport a single KDD competitor.', 'The Post and Telecommunications Ministry has urged the\nmerger of the two firms because it says the market can only\nsupport a single KDD competitor')
# ('.\n    The rating adjustments are based on the likelihood that the\nproposed merger of the two Texas banks will be consummated.', 'The rating adjustments are based on the likelihood that the\nproposed merger of the two Texas banks will be consummated')
# ('.\n    The 1987 pro forma first quarter results include\nnonrecurring merger expenses of 4.', 'The 1987 pro forma first quarter results include\nnonrecurring merger expenses of 4')
# ('.\n    The merger is expected to close on April 22.', 'The merger is expected to close on April 22')
# ('.\n    The investment company said after the merger the combined\ncompany will have 15 mln shares outstanding.', 'The investment company said after the merger the combined\ncompany will have 15 mln shares outstanding')
# ('.\n    He said the company continues to look at mergers and\nacquisitions.', 'He said the company continues to look at mergers and\nacquisitions')
# ('.25 dlrs to 95 dlrs the amount per share paid in the\nmerger of a Dixons subsidiary with Cyclops.', '25 dlrs to 95 dlrs the amount per share paid in the\nmerger of a Dixons subsidiary with Cyclops')
# ('.\n    OII said each common share still outstanding at the time of\nthe merger has been converted into the right to receive 60.', 'OII said each common share still outstanding at the time of\nthe merger has been converted into the right to receive 60')
# ('.\n    The merger of Uccel and Computer Associates combines the\ntwo biggest systems utilities suppliers other than IBM.', 'The merger of Uccel and Computer Associates combines the\ntwo biggest systems utilities suppliers other than IBM')
# ('.9 mln dlrs in both periods of earlier\nyear from merger of divisions.', '9 mln dlrs in both periods of earlier\nyear from merger of divisions')
# ('.\n    The directors of Baker immediately after receiving the\ncounter proposal filed a law suit in Texas in a Texas state\ncourt to force to Hughes to complete the merger.', 'The directors of Baker immediately after receiving the\ncounter proposal filed a law suit in Texas in a Texas state\ncourt to force to Hughes to complete the merger')
# ('.\n    The spokesman said agency action on the proposed merger\napplication could take as long as six months.', 'The spokesman said agency action on the proposed merger\napplication could take as long as six months')
# ('.\n    Paues said the merger was a direct result of the sharp fall\nin oil prices 18 months ago which led oil firms to cut back\nexploration activities.', 'Paues said the merger was a direct result of the sharp fall\nin oil prices 18 months ago which led oil firms to cut back\nexploration activities')
# ('.978825 shares of Amsouth stock for each First Tuskaloosa\nshare held when the merger is effected April 17.', '978825 shares of Amsouth stock for each First Tuskaloosa\nshare held when the merger is effected April 17')
# ('.\n    Interco said the merger becomes effective April 14.', 'Interco said the merger becomes effective April 14')
# ('. Pettee estimated 58 dlrs would\nbe in a more reasonable range based on other airline mergers.', 'Pettee estimated 58 dlrs would\nbe in a more reasonable range based on other airline mergers')
# ('.\n    Vernitron said that it currently expects the special\nshareholder meeting concerning the merger will be held in\nAugust.', 'Vernitron said that it currently expects the special\nshareholder meeting concerning the merger will be held in\nAugust')
# ('.\n    The merger agreement was announced earlier this week.', 'The merger agreement was announced earlier this week')
# ('.\n    Revlon said its board of directors unanimously approved the\nmerger agreement.', 'Revlon said its board of directors unanimously approved the\nmerger agreement')
# ('. Secretary of State George Schultz have\nwritten to the Japanese government about the planned merger.', 'Secretary of State George Schultz have\nwritten to the Japanese government about the planned merger')
# ('.\n   \n    Magellan said it will be the surviving corporation\nfollowing the merger.', 'Magellan said it will be the surviving corporation\nfollowing the merger')
# ('.\n    The companies said the proposed merger would bring together\nbusinesses that were largely complementary.', 'The companies said the proposed merger would bring together\nbusinesses that were largely complementary')
# ('.\n    A Chemlawn spokesman said further details on the merger\nwould be issued later.', 'A Chemlawn spokesman said further details on the merger\nwould be issued later')
# ('.\n    Hutton said in the merger shareholders would get 46 mln\ndlrs aggregate amount of guaranteed debentures due 2002 of PC\nAcquisition and warrants to buy 15 pct of the common stock of\nthe PC courier subsidiary.', 'Hutton said in the merger shareholders would get 46 mln\ndlrs aggregate amount of guaranteed debentures due 2002 of PC\nAcquisition and warrants to buy 15 pct of the common stock of\nthe PC courier subsidiary')
# ('.\n    Instinet said it expects the merger to become effective as\nsoon as possible after shareholder approval at the special\nmeeting.', 'Instinet said it expects the merger to become effective as\nsoon as possible after shareholder approval at the special\nmeeting')
# ('.25 dlrs the amount per share paid in the merger of a\nDixons subsidiary with Cyclops.', '25 dlrs the amount per share paid in the merger of a\nDixons subsidiary with Cyclops')
# ('.\n    Analysts said that the drop in bank stock prices is likely\nto depress the level of mergers and acquisition in the banking\nindustry.', 'Analysts said that the drop in bank stock prices is likely\nto depress the level of mergers and acquisition in the banking\nindustry')
# ('.\n    Comdata said WCAS and its affiliate investors would commit\n50 mln dlrs to buy the securities comprising the new entities\nunits of securities resulting from the merger in the same\nproportions and at the same price as the company shareholders.', 'Comdata said WCAS and its affiliate investors would commit\n50 mln dlrs to buy the securities comprising the new entities\nunits of securities resulting from the merger in the same\nproportions and at the same price as the company shareholders')
# ('.\n    Boston Five said the planned merger with Newworld Bank for\nSavings Will create the largest savings bank in Massachusetts\nand the third largest in New England with combined assets of\n3.', 'Boston Five said the planned merger with Newworld Bank for\nSavings Will create the largest savings bank in Massachusetts\nand the third largest in New England with combined assets of\n3')
# ('.\n    Banner said it expects to complete the merger with Rexnord\nwithin 60 days.', 'Banner said it expects to complete the merger with Rexnord\nwithin 60 days')
# ('.\n    OII said the New York Stock Exchange said the securities\nwill be delisted as a result of the merger.', 'OII said the New York Stock Exchange said the securities\nwill be delisted as a result of the merger')
# ('.\n1987 results reflect the TBS merger agreement and operations of\nthe company as independent agent.', '1987 results reflect the TBS merger agreement and operations of\nthe company as independent agent')
# ('.\n    The company said its board recommended that shareholders\napprove the merger of the oilfield service companies.', 'The company said its board recommended that shareholders\napprove the merger of the oilfield service companies')
# ('.\n    Seton said its board of directors unanimously approved the\nmerger in a meeting held today.', 'Seton said its board of directors unanimously approved the\nmerger in a meeting held today')
# ('.\n    Corning said the prospectus regarding the merger is\nexpected to be mailed tomorrow to all Hazleton holders of\nrecord February 18.', 'Corning said the prospectus regarding the merger is\nexpected to be mailed tomorrow to all Hazleton holders of\nrecord February 18')
# ('.\n    Advanced said it had suspended merger talks with other\nparties as a result of the exclusivity agreement.', 'Advanced said it had suspended merger talks with other\nparties as a result of the exclusivity agreement')
# ('.\n    The deadline for seeking ICC reconsideration of the merger\nplan is midnight tonight.', 'The deadline for seeking ICC reconsideration of the merger\nplan is midnight tonight')
# ('. The merger is\nsubject to court approval of the settlement as well as to other\nconditions.', 'The merger is\nsubject to court approval of the settlement as well as to other\nconditions')
# ('. Quest said it\nexpects to complete the merger within the next several weeks.', 'Quest said it\nexpects to complete the merger within the next several weeks')
# ('.\n    Modulaire has scheduled a special shareholders meeting for\nJuly 15 to vote on the merger.', 'Modulaire has scheduled a special shareholders meeting for\nJuly 15 to vote on the merger')
# ('.\n    Instinet said the filing of the preliminary merger proxy\nmaterials is tied to the finalization of audited financial\nstatements of Instinet and Reuters for 1986.', 'Instinet said the filing of the preliminary merger proxy\nmaterials is tied to the finalization of audited financial\nstatements of Instinet and Reuters for 1986')
# ('.  A merger at the tender price that has been\napproved by the ARGOSystems board is to follow the offer.', 'A merger at the tender price that has been\napproved by the ARGOSystems board is to follow the offer')
# ('.\n    Terms of the merger called for each share of Arrays to be\nexchange for a share of Haba in a transaction valued at 4.', 'Terms of the merger called for each share of Arrays to be\nexchange for a share of Haba in a transaction valued at 4')
# ('. He predicted there would be mergers and\nindividual firms would carve out specialised niches to ensure\ntheir survival in a deregulated climate.', 'He predicted there would be mergers and\nindividual firms would carve out specialised niches to ensure\ntheir survival in a deregulated climate')
# ('.\n    Hoechst and Celanese completed their merger last month.', 'Hoechst and Celanese completed their merger last month')
# ('.\n    Metrobanc said the merger is still subject to regulatory\napproval.', 'Metrobanc said the merger is still subject to regulatory\napproval')
# ('.\n    Rainbow has said the merger is soundly based.', 'Rainbow has said the merger is soundly based')
# ('.\n    Tender Loving Care said the extended merger agreement\ncontinues to provide for the exchange of 1.', 'Tender Loving Care said the extended merger agreement\ncontinues to provide for the exchange of 1')
# ('. FCS said merger\nnegotiations with this other company have been continuing since\nlate August.', 'FCS said merger\nnegotiations with this other company have been continuing since\nlate August')
# ('. BIL opposes the Rainbow merger and\nanalysts say BIL needs a 25 pct stake in Progressive to prevent\nit occurring.', 'BIL opposes the Rainbow merger and\nanalysts say BIL needs a 25 pct stake in Progressive to prevent\nit occurring')
# ('. But the company said that it would\ntake more than five billion dlrs to consummate the merger and\nretire certain company debt.', 'But the company said that it would\ntake more than five billion dlrs to consummate the merger and\nretire certain company debt')
# ('.\n    While mergers and acquisitions among U.', 'While mergers and acquisitions among U')
# ('.\n    The letter from Gardner said he resigned the board because\nthe merger agreement with Hutton barred directors from\nsoliciting new offers and he believes shareholders might get a\nbetter deal.', 'The letter from Gardner said he resigned the board because\nthe merger agreement with Hutton barred directors from\nsoliciting new offers and he believes shareholders might get a\nbetter deal')
# ('.\n    ICC voted four to one last summer to reject the merger as\ninherently anticompetitive.', 'ICC voted four to one last summer to reject the merger as\ninherently anticompetitive')
# ('.\n    The proposed merger that would create a 1.', 'The proposed merger that would create a 1')
# ('.\n    USG also said shareholders will be asked to approve an\namendment to its restated certificate of incorporation that\nincludes staggered election of directors and the requirement of\nan 80 pct vote on certain mergers and asset sales or leases.', 'USG also said shareholders will be asked to approve an\namendment to its restated certificate of incorporation that\nincludes staggered election of directors and the requirement of\nan 80 pct vote on certain mergers and asset sales or leases')
# ('.\n    ANova said it created Duvel to act as a blind pool and will\nseek an operating private company to merger with Duvel.', 'ANova said it created Duvel to act as a blind pool and will\nseek an operating private company to merger with Duvel')
# ('.\n    The company said the merger will be accounted for as a\ncorporate reorganization and be recorded at historical book\nvalues.', 'The company said the merger will be accounted for as a\ncorporate reorganization and be recorded at historical book\nvalues')
# ('.\n    Kerridge said the board met yesterday to discuss the merger\nbut decided against it.', 'Kerridge said the board met yesterday to discuss the merger\nbut decided against it')
# ('.\n    The companies cited a combination of extraordinary market\nconditions and unresolved terms of the merger as contributing\nto the action.', 'The companies cited a combination of extraordinary market\nconditions and unresolved terms of the merger as contributing\nto the action')
# ('.\n    Cable and Wireless has a 20 pct stake in one of the two\ncompanies involved in the mooted merger.', 'Cable and Wireless has a 20 pct stake in one of the two\ncompanies involved in the mooted merger')
# ('.8 pct of its stock and have agreed to vote in favor of\nthe merger.', '8 pct of its stock and have agreed to vote in favor of\nthe merger')
# ('. The company said it expects to complete the\nmerger by June 17.', 'The company said it expects to complete the\nmerger by June 17')
# ('.\n    Greyhound officials told Reuters late today the company\nhoped for ICC action on the merger by tomorrow.', 'Greyhound officials told Reuters late today the company\nhoped for ICC action on the merger by tomorrow')
# ('.\n    The barriers are crumbling anyway because state\nlegislatures are agreeing to permit bank mergers across state\nlines within a region.', 'The barriers are crumbling anyway because state\nlegislatures are agreeing to permit bank mergers across state\nlines within a region')
# ('.Former managing director of the mergers and\nacquisitions department of the London office of Merrill Lynch\nand Co.', 'Former managing director of the mergers and\nacquisitions department of the London office of Merrill Lynch\nand Co')
# ('.\n    He said the department considers the effect each merger\nwill have on competition over all the routes involved and will\nnot approve a merger which will reduce competition.', 'He said the department considers the effect each merger\nwill have on competition over all the routes involved and will\nnot approve a merger which will reduce competition')
# ('.\n    The junior subordinated discount debentures to be issued in\nthe merger will carry a 13 pct coupon and will begin paying\ncash interest after five years.', 'The junior subordinated discount debentures to be issued in\nthe merger will carry a 13 pct coupon and will begin paying\ncash interest after five years')
# ('.\n    The Hughes board last week indicated that it might cancel\nthe merger because of the Department of Justice requirement.', 'The Hughes board last week indicated that it might cancel\nthe merger because of the Department of Justice requirement')
# ('.\n    A Norstar spokesman said that a press release containing\nfurther details on the merger would be issued shortly.', 'A Norstar spokesman said that a press release containing\nfurther details on the merger would be issued shortly')
# ('. Both boards have approved the merger.', 'Both boards have approved the merger')
# ('. senator said a corporate merger wave was harming the\neconomy and blamed the Reagan administration for laxness in\nenforcing the federal antitrust laws.', 'senator said a corporate merger wave was harming the\neconomy and blamed the Reagan administration for laxness in\nenforcing the federal antitrust laws')
# ('. in an attempt to block the merger.', 'in an attempt to block the merger')
# ('.\n    The voting trust agreement requires the bank to vote in\nfavor of any acquisition agreement between TWA and USAir and to\nopposed any other merger of USAir.', 'The voting trust agreement requires the bank to vote in\nfavor of any acquisition agreement between TWA and USAir and to\nopposed any other merger of USAir')
# ('.\n    This week Hughes seemed to back out of the merger but then\nsaid it was still interested in talking.', 'This week Hughes seemed to back out of the merger but then\nsaid it was still interested in talking')
# ('. The merger still requires\nshareholder approval.', 'The merger still requires\nshareholder approval')
# ('.\n    Emery said Purolator would operate as a wholly owned unit\nof the company after the merger.', 'Emery said Purolator would operate as a wholly owned unit\nof the company after the merger')
# ('. Britain opposes the proposed merger.', 'Britain opposes the proposed merger')
# ('.\n    But it said investment banking firms should be allowed to\ncontinue to engage in both arbitrage and merger and acquisition\nactivities so long as those functions were kept separate.', 'But it said investment banking firms should be allowed to\ncontinue to engage in both arbitrage and merger and acquisition\nactivities so long as those functions were kept separate')
# ('.\n    The companies also said the signing cleared the way for\ntheir merger completed today.', 'The companies also said the signing cleared the way for\ntheir merger completed today')
# ('.\n    Analysts said such a merger would be costly and\ncomplicated.', 'Analysts said such a merger would be costly and\ncomplicated')
# ('.\n    The merger is still subject to approval by shareholders of\nboth companies.', 'The merger is still subject to approval by shareholders of\nboth companies')
# ('.\n    Baker said it believes the merger to be in the best\ninterests of shareholders of both companies.', 'Baker said it believes the merger to be in the best\ninterests of shareholders of both companies')
# ('.\n    KPMG was created as part of the merger announced last\nSeptember of Peat Marwick International Klynveld Main Goerdeler\nto form Klynveld Peat Marwick Goerdeler.', 'KPMG was created as part of the merger announced last\nSeptember of Peat Marwick International Klynveld Main Goerdeler\nto form Klynveld Peat Marwick Goerdeler')
# ('.\n    S and P said the reviews reflect its perception of the\nimplications of a proposed merger involving the two firms.', 'S and P said the reviews reflect its perception of the\nimplications of a proposed merger involving the two firms')
# ('.\n    Analysts said the merger continues a trend in the\nautomobile industry of diversification away from carmaking.', 'Analysts said the merger continues a trend in the\nautomobile industry of diversification away from carmaking')
# ('.\n    The merger is effective April one and is subject to\nshareholder approval.', 'The merger is effective April one and is subject to\nshareholder approval')

# %% [markdown]
# #### Correction: TO DO 2

# %%
all_matches = []

for article in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r'[\.\!\?][ \na-zA-Z]* merger [ \na-zA-Z]*[\.\!\?]', article['text'])
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 71
# . Circuit Court of Appeals in San Francisco had
# blocked the merger until a dispute over union representation
# had been settled by arbitration.
# .
#     It said the price to be paid in the tender and merger could
# be reduced by any fees and expenses the court may award to
# counsel for the plaintiffs in the class action suit brought
# against it in Delaware Chancery Court by Ronda Inc.
# .
#     Metrobanc said the merger is still subject to regulatory
# approval.
# .
#     The merger is still subject to approval by shareholders of
# both companies.
# .
#     Analysts said the merger is virtually certain to go ahead.
# .
#     ANova said it created Duvel to act as a blind pool and will
# seek an operating private company to merger with Duvel.
# .
#     Hoechst and Celanese completed their merger last month.
# .
#     Greyhound officials told Reuters late today the company
# hoped for ICC action on the merger by tomorrow.
# .
#     The voting trust agreement requires the bank to vote in
# favor of any acquisition agreement between TWA and USAir and to
# opposed any other merger of USAir.
# .
#     Completion of the merger transaction is expected in three
# to four months.
# .
#     Hughes yesterday adjourned the special meeting at which
# shareholders were to vote on the merger without permitting the
# counting of votes on the deal.
# .
#     But it said investment banking firms should be allowed to
# continue to engage in both arbitrage and merger and acquisition
# activities so long as those functions were kept separate.
# .
#     Analysts said the merger continues a trend in the
# automobile industry of diversification away from carmaking.
# .
#     ICC voted four to one last summer to reject the merger as
# inherently anticompetitive.
# .
#     The companies said the proposed merger would bring together
# businesses that were largely complementary.
# .
#     KPMG was created as part of the merger announced last
# September of Peat Marwick International Klynveld Main Goerdeler
# to form Klynveld Peat Marwick Goerdeler.
# . Emery
# said as a result it is renewing its request that Purolatr enter
# into merger negotiations with it.
# .
#     The merger is subject to regulatory and shareholder
# approval.
# .
#     S and P said the reviews reflect its perception of the
# implications of a proposed merger involving the two firms.
# .
#     Mattson told Reuters that Baker still believed a merger was
# possible between the two giant oilfield service companies.
# .  The
# ChemLawn board has approved the tender and a merger at the same
# price that is to follow.
# .
#     The company said its board recommended that shareholders
# approve the merger of the oilfield service companies.
# . He said the agency has not yet received
# a formal notice of the merger which would start the review
# process.
# .
#     The company said the merger will be accounted for as a
# corporate reorganization and be recorded at historical book
# values.
# .
#     A Norstar spokesman said that a press release containing
# further details on the merger would be issued shortly.
# .
#     But a Cable spokesman said it still believed a merger of
# the two consortia would be impracticable.
# . The resulting merger would
# create the largest independent software company yet.
# .
#     Baker said it believes the merger to be in the best
# interests of shareholders of both companies.
# .
#     Santa Fe Southern Pacific owns the Santa Fe railroad and
# holds the Southern Pacific railroad assets in trust while
# awaiting federal approval of the merger plan.
# .
#     The merger plan has been criticised for excluding foreign
# firms from a meaningful position in the market.
# .
#     Charter said the merger is subject to approval of the
# Federal Home Loan Bank Board.
# .
#     Entertainment said the offer would be conducted through a
# negotiated merger with a new corporation to be formed by
# Entertainment Marketing.
# .
#     This week Hughes seemed to back out of the merger but then
# said it was still interested in talking.
# . Independence
# said the merger will be accounted for as a pooling of
# interests.
# .
#     The companies also said the signing cleared the way for
# their merger completed today.
# .
#     Gardner noted that the terms of the merger agreement in
# which the company would bought out by a group of its managers
# and E.
# . The merger is
# subject to court approval of the settlement as well as to other
# conditions.
# .
#
#     IDC said the merger agreement also provides for payment of
# an equivalent amount in respect of employee stock options to be
# cancelled in the merger.
# .
#     The DOT had given tentative approval to the merger plan
# Feb.
# .
#     The company said the board decision to adopt its own
# divestiture plan and terminate the merger agreement if Baker
# did not accept was unanimous.
# .
#     The ICC had rejected in July the merger of the Santa Fe and
# Southern Pacific Railroads on the grounds that it would reduce
# competition.
# . Kistler
# said its counter proposal to merge with Baker International
# Corp was still under consideration and that a merger was in the
# best interests of both companies.
# . The merger still requires
# shareholder approval.
# .
#     The company said a definitive merger agreement is expected
# to be negotiated within six weeks and shareholders are expected
# to vote on the deal at a meeting expected to be held in June or
# July.
# . The company said it will
# treat the merger as a pooling of interests.
# .
#     It said Quest Blood expects to complete the merger within
# the next several weeks.
# . But the company said that it would
# take more than five billion dlrs to consummate the merger and
# retire certain company debt.
# .
#     The companies cited a combination of extraordinary market
# conditions and unresolved terms of the merger as contributing
# to the action.
# .
#     Advanced said it had suspended merger talks with other
# parties as a result of the exclusivity agreement.
# . That
# meeting was called to act on a merger agreement calling for a
# buyout by BCW Acquisitions Inc.
# .
#     The merger agreement was announced earlier this week.
# . Canadian Airlines was recently
# formed through the merger of Canadian Pacific Airlines and
# Pacific Western Airlines.
# . senator said a corporate merger wave was harming the
# economy and blamed the Reagan administration for laxness in
# enforcing the federal antitrust laws.
# .
#     The letter from Gardner said he resigned the board because
# the merger agreement with Hutton barred directors from
# soliciting new offers and he believes shareholders might get a
# better deal.
# .
#     He said the department considers the effect each merger
# will have on competition over all the routes involved and will
# not approve a merger which will reduce competition.
# . Quest said it
# expects to complete the merger within the next several weeks.
# .
#     The Hughes board last week indicated that it might cancel
# the merger because of the Department of Justice requirement.
# .
#     Analysts said such a merger would be costly and
# complicated.
# . He said he
# believes such a merger could create a stronger force in the
# tire industry.
# .
#     The rating adjustments are based on the likelihood that the
# proposed merger of the two Texas banks will be consummated.
# .
#     Sorg said the group also agreed to vote as a body on any
# proposed merger or election of directors.
# .
#     The company said it is continuing talks with Piedmont on
# arriving at a definitive merger agreement and the two companies
# hope to reach one very shortly.
# .
#     Rainbow has said the merger is soundly based.
# .
#     Hanson said that promptly following the filing of the
# certificate of merger Kaiser Cement common shares will be
# delisted from the New York Stock Exchange.
# .
#     The merger of Uccel and Computer Associates combines the
# two biggest systems utilities suppliers other than IBM.
# .
#     Instinet said it expects the merger to become effective as
# soon as possible after shareholder approval at the special
# meeting.
# .  A merger at the tender price that has been
# approved by the ARGOSystems board is to follow the offer.
# .
#     Vernitron said that it currently expects the special
# shareholder meeting concerning the merger will be held in
# August.
# .
#     The merger is effective April one and is subject to
# shareholder approval.
# .
#     They said they might revive merger plans at a later date or
# seek other ways for Clabir to increase its holdings in AmBrit.

# %% [markdown]
# So far, we have assumed the sentences consist only of letters, spaces and new lines. Can you think of any characters we have excluded here?
#
# A better way to find all matches would be to use _negation_ to match against any character _except_ the punctuation marks that bound the sentences. A negation will match any character except those specified, which we can write like this: `[^\.\!\?]`, where the '^' indicates the negation.
#
# TODO 3: Modify the expression you used in the previous cell to use the negation `[^\.\!\?]` to try to find all sentences.

# %%
all_matches = []

for article in train_dataset:
    pattern = r'([.!?])\s*([^.!?]*?\bmerger\b[^.!?]*?)[.!?]'
    
    ### COMPLETE THE CODE HERE
    matches = re.findall(pattern, article['text'], re.IGNORECASE)
    
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 530
# ('.', '"We simply regard Progressive Enterprises shares to be worth\napproximately twice as much as Rainbow shares and do not think\nthe merger, as proposed, is soundly based," BIL chief executive\nPaul Collins said in an interview in the weekly National\nBusiness Review newspaper published today')
# ('.', "The agency cited Western Air's merger with Delta and\nDelta's assumption of Western's debt")
# ('.', '"Schlumberger\'s management shift, asset restructuring,\nincluding a pending merger of Fairchild Semiconductor, and its\nconsiderable cash horde sets the stage for the company to\nmaximize its significant industry advantage and capitalize on\nthe project upturn in exploration and development activity,"\naccording to a report by George Gaspar, first vice president at\nRobert W')
# ('.', '&lt;Brierley Investments Ltd>, which has been a frequent\ncritic of the merger, launched a full bid for Progressive at\n4')
# ('.', 'The two groups have also begun exploratory talks on a\npossible merger of the Holmes business with the compatible\nbusinesses of Wormald, comprising some or all of its fire\nprotection and security businesses in the Americas and Europe,\nWormald said in a statement')
# ('.', "Hughes said it proposed to Baker that the companies ask the\nJustice Department to allow them to proceed with the merger on\ncondition that they find a buyer approved by the  Department\nfor the domestic oilfield tricine rock bit assets of Baker's\nReed subsidiary, its Singapore plant and Baker Lift's domestic\nelectrical submersible pump business by April 22, the last date\nthe merger of Baker and Hughes could occur under their\nagreement")
# ('.', "The bank said Community State Bank's shareholders approved\nthe merger at a meeting last Saturday, while Monday the\ndirectors of 1st Source also approved the move")
# ('.', 'But a Cable spokesman said it still believed a merger of\nthe two consortia would be impracticable')
# ('.', 'Opposition\nto the planned merger of two rival firms seeking to compete\nwith the current monopoly &lt;Kokusai Denwa Denshin Co Ltd>, and\nto reduce the share held in any KDD rival by U')
# ('.', '1 pct\nstake in Crazy Eddie common stock, said they may acquire more\nshares through a negotiated merger or tender offer')
# ('.', 'Under the terms of the merger, Dixons said the remaining\npublic Cyclops shareholders are to receive 95 dlrs a share')
# ('.', 'senator said a corporate merger wave was harming the\neconomy and blamed the Reagan administration for laxness in\nenforcing the federal antitrust laws')
# ('.', '75 dlrs a\nshare in connection with the merger with Hemdale, Computer\nMemories said')
# ('.', 'Charter said the merger is subject to approval of the\nFederal Home Loan Bank Board')
# ('.', ', has approved a\nmerger into CB and T for an undisclosed amount of stock,\nsubject to approval by regulatory agencies and Carrolton\nshareholders')
# ('.', "The rating agency cited USAir Group's proposed acquisition\nof Piedmont Aviation Inc &lt;PIE>, as well as Trans World Airlines\nInc's &lt;TWA> proposed cash merger with USAir")
# ('.', "The\noffer, which has been approved by the Auxton board and is to be\nfollowed by a merger at the same price, is conditioned on\nreceipt of a majority of Auxton's voting stock on a fully\ndiluted basis")
# ('.', 'Kistler\nsaid its counter proposal to merge with Baker International\nCorp was still under consideration and that a merger was in the\nbest interests of both companies')
# ('.', 'Baker said the new terms that Hughes proposed for the\nmerger, as an alternative to the consent decree, were "more\nburdensome" than those of the consent decree themselves')
# ('.', 'Circuit Court of Appeals in San Francisco had\nblocked the merger until a dispute over union representation\nhad been settled by arbitration')
# ('.', "Rosenfeld joined Salomon in 1979 and has been a member of\nSalomon Brothers' merger and acquisitions group")
# ('.', 'For Computer Associates, the merger with Uccel caps a\nsix-year acquisition campaign that has vaulted the Garden City,\nN')
# ('.', 'The complaint said Vaskevitch leaked information about 12\ncompanies involved in a merger or acquisition which resulted in\nmore than four mln dlrs in profit for himself and others\ninvolved in the scheme')
# ('.', '"It\'s silly not to take a look (at making a merger or\nacquisition)')
# ('.', "Yesterday Citicorp &lt;CCI>, with Audio/Video Affiliates Inc\n&lt;AVA> an owner of CYACQ, said it had offered to acquire from\nDixons after the merger of Cyclops into Dixons, Cyclops'\nindustrial businesses for 12")
# ('.', 'Figures for last\nyear are unavailable as the bank was formed in June this year\nafter a merger of two Dallas-based banks, RepublicBank Corp and\nInterFirst Corp')
# ('.', "Analysts said they foresaw no major complications that\nwould abort a combination which historians said would be the\nauto industry's biggest merger since American Motors was formed\nin 1954")
# ('.', 'And European firms will be\nfalling prey to Japanese corporations bulging with cash and\neager to extend their reach further overseas, according to\nmerger and acquisitions specialists polled by Reuters')
# ('.', 'Kansas said Santa Fe in petitioning\nfor reconsideration now argues that the trackage agreements\nwith the Union Pacific, the Denver and Rio Grande Western and\nother railroads, adds to the value of the merger')
# ('.', 'Greyhound announced June 19 that it wanted the ICC to let\nit begin operating Trailways immediately while continuing to\nevaluate the merger for possible antitrust problems')
# ('.', 'When the merger is completed, each of the 50,000 shares of\nthe Bank of Sissonville common stock outstanding will be\nconverted into 2')
# ('.', "Following a meeting yesterday with Borg-Warner officials\nand investment bankers, GAF said, it is today delivering a\nletter to the Borg-Warner board outling the terms of the\nproposal that would be made by tender offer, pursuant to a\nmutually acceptable merger agreement to be approved by the\nBorg-Warner board and conditioned on that board's\nrecommendation of the tender offer and merger")
# ('.', 'A Chemlawn spokesman said further details on the merger\nwould be issued later')
# ('.', 'The company said its was served the suit in Minneapolis on\nMarch 31, the day after it announced its definitive merger\nagreement with Bristol-Myers')
# ('.', '2 pct of the total, and left open\nthe possibility that it might acquire more through a merger')
# ('.', 'Hawkins said the merger has been assessed by independent\nconsultants and declared fair in all respects, with benefits to\nall shareholders')
# ('.', "The agreement with Dixons Group calls for Cyclops's steel\nand construction businesses to be sold to a unit of Alleghany\nCorp &lt;Y> for about 110 mln dlrs once the merger is completed")
# ('.', 'industries; any differences are not\nsignificant for the purpose of merger analysis," Andewelt said')
# ('.', 'Earlier this week, ChemLawn agreed to accept a merger\nproposal at 36')
# ('.', "Under the merger's terms, Strata shareholders will receive\n5")
# ('.', "department of justice, resolving the department's objections to\ntheir merger")
# ('.', "The company said it has also agreed to let Purolator pay\nall of PC Acquisition's documented expenses in connection with\nthe merger agreement up to three mln dlrs and Emery has agreed\nto pay the amounts itself should Purolator fail to do so")
# ('.', 'S and P cited the adjournment of a special shareholder\nmeeting in which Hughes objected to certain conditions for the\nmerger of the companies set by the U')
# ('.', 'Suggesting that the total cost of completing the merger\nwould be 190 mln dlrs, Cross said he would use 20 mln dlrs of\nhis own money for the deal and up to 170 mln dlrs which would\nbe borrowed from the First National Bank of Boston under a\nrevolving credit facility the bank has agreed to provide')
# ('.', "If Pubco is acquired in a merger or other transaction, each\nright will entitle its holder to purchase, at the right's\nthen-current exercise price, a number of the acquiring\ncompany's common shares having a market value at that time of\ntwice the right's exercise price, the company said")
# ('.', "Jacy Mendonca, industrial relations director of Autolatina,\na merger of Volkswagen and Ford in Brazil and Argentina, said\nlast week this would be the worst year ever for Brazil's auto\nindustry")
# ('.', 'As a result of the merger, Borg-Warner will become a wholly\nowned subsidiary of AV Holdings')
# ('.', 'The transaction is structured as a merger of Liberty with a\nduly-formed unit of Equimark, the company said')
# ('.', 'The letter from Gardner said he resigned the board because\nthe merger agreement with Hutton barred directors from\nsoliciting new offers and he believes shareholders might get a\nbetter deal')
# ('.', 'The Rainbow merger involves shareholders in\nboth Rainbow and Progressive being issued shares in a new\ncompany, &lt;Astral Pacific Corp Ltd>, on a one-for-one basis')
# ('.', 'textile maker focused\non its own business as its competitors found merger partners,\nbut now Burlington Industries Inc may have restructured itself\ninto an attractive takeover candidate, analysts said')
# ('.', 'But the company said that it would\ntake more than five billion dlrs to consummate the merger and\nretire certain company debt')
# ('.', 'In the merger, holders of remaining Instinet shares will\nreceive 8')
# ('.', 'Gardner noted that the terms of the merger agreement in\nwhich the company would bought out by a group of its managers\nand E')
# ('.', '"\n    Under the merger terms, announced Nov')
# ('.', 'However, the agency pointed out that the\nmerger is a unique opportunity for RepublicBank to expand its\nalready strong market position')
# ('.', 'S and P said the reviews reflect its perception of the\nimplications of a proposed merger involving the two firms')
# ('.', 'Others argue the merger\nwas more cost effective than creating a comparable branch\nnetwork from scratch')
# ('.', 'Boston Five said the planned merger with Newworld Bank for\nSavings Will create the largest savings bank in Massachusetts\nand the third largest in New England with combined assets of\n3')
# ('.', 'The aim of the merger is to seek Recognised Investment\nExchange status as required by the 1986 Financial Services Act')
# ('.', 'The rating adjustments are based on the likelihood that the\nproposed merger of the two Texas banks will be consummated')
# ('.', "Pay N' Pak said the second proposal is structured as a\nmerger in which each holder would receive a combination of\n17")
# ('.', '"  The\nconsolidation follows the merger of Foley\'s and Sanger Harris\nin January')
# ('.', 'Bradt was referring to a merger among the four exchanges at\nthe Commodity Exchange Center, an idea that has been discussed\nintermittently for several years')
# ('.', "He said the tender would be the first step in acquiring all\nof Caesars' shares and if successful would be followed by a\nmerger transaction")
# ('.', "They said he showed skill in reducing Ozark Airlines'\ncosts when he merged it into TWA last year, and he might be a\nnecessary ingredient for a merger to work")
# ('.', 'Wall Street analysts said the merger accord between Fleet\nand Albany, N')
# ('.', "After a failed first attempt earlier this year, Rorer's\nlatest merger plan calls for a share swap worth about 720 mln\ndlrs")
# ('.', "The companies said the previously announced merger has been\napproved by TI-CARO's board and is expected to close by early\nApril")
# ('.', 'The Texas Commerce-Chemical merger is the only acquisition\nby a major out-of-state bank since Texas lawmakers approved\ninterstate banking effective January 1')
# ('.', 'Modulaire has scheduled a special shareholders meeting for\nJuly 15 to vote on the merger')
# ('.', "Emery said pending the termination of PC Acquisition's\nmerger agreement, PC has released Purolator from an agreement\nnot to discuss Emery's acquisition proposal with Emery")
# ('.', "The company also said it was advised that Dixons'\nshareholders approved the merger, satisfying that condition of\nthe agreement")
# ('.', '19 billion dlr merger with Chemical')
# ('.', "Their merger would not\nalter American's third-place ranking, according to data\ncompiled by Aviation Daily, a leading industry trade magazine")
# ('.', 'Under the merger, H')
# ('.', "T> is certain to\nlose its status as Japan's most profitable bank as a result of\nits merger with the Heiwa Sogo Bank, financial analysts said")
# ('.', ',\nhave approved a merger into First Union for 40 dlrs per share,\nor about 5,100,000 dlrs')
# ('.', 'Baker International has proposed a merger with Hughes Tool\nwhich could create a 1')
# ('.', "The boards of both companies have approved the merger,\nwhich will be accomplished through a tender offer by a Boeing\nsubsidiary of 37 dlrs a share cash for all of ARGOSystems'\nshares, the companies said")
# ('.', 'American Motors said it received a letter from Chrysler\nCorp "advising us of their proposal to enter into a merger\ntransaction with American Motors Corp')
# ('.', "The ruling came in a lawsuit in which the Air Transport\nEmployees union said Western's management should fulfil a\npromise to honour union contracts if a merger took place")
# ('.', "Justice's opposition to quick federal approval of a bid by\nGreyhound Lines Inc to take immediate control Trailways Corp\nprompted Greyhound to threaten -- in a brief filed with the\nInterstate Commerce Commission (ICC) -- to drop the merger\nplan")
# ('.', '50 dlr a\nshare exercise price before the merger is effective, it said')
# ('.', 'Under the terms of the merger, each Liebert shareholder\nwill receive ')
# ('.', 'The company said if the merger is approved by shareholders\nof both companies, the shareholders of John Paul Richards would\nbecome majority shareholders, owning 60 pct of the common\nstock, of the new public company')
# ('.', 'Carroll also noted that since the merger accord was first\nsigned "the outlook for the industry has improved materially')
# ('.', 'It was the fourth federally-assisted merger or acquisition\nof a troubled savings institution this year, the FHLBB said')
# ('.', 'The company said on completion of the merger, the combined\ncompany wopuld be known as Power-Cell Inc and be engaged in the\ndevelopment of Balzac technology related to its Quick Charge\nproduct for charging auto batteries')
# ('.', "S and P cited the completion of the firm's merger with PNC\nFinancial Corp &lt;PNCF>, saying PNC has shown solid earnings,\nexcellent liquidity and a conservative capital position")
# ('.', "Allied's first disclosure of the DeBartolo takeover was\nmade on Oct 8, even though its board approved the merger on Oct\n3 and the merger agreement was executed on Oct 7, the complaint\nsaid")
# ('.', 'The ICC had rejected in July, on grounds it would reduce\ncompetition, the merger of the Santa Fe and Southern Pacific\nRailroads')
# ('.', 'The 1987 pro forma first quarter results include\nnonrecurring merger expenses of 4')
# ('.', 'It said it would leave open a range of options regarding\nthe debentures, including buying more, selling some or all of\ntheir current stake in the market or in negotiated deals,\ntalking with other Harcourt security holders, surrendering the\ndebentures if there were a merger or tender offer or converting\nthem into stock')
# ('.', 'Interco said the merger becomes effective April 14')
# ('.', 'OII said the New York Stock Exchange said the securities\nwill be delisted as a result of the merger')
# ('.', 'The interest rate to be used to increase the cash value of the\nmerger, if delayed beyond April 30, was raised to nine pct from\neight pct and 12 pct after May 31')
# ('.', 'The company said under the terms, Great Western has agreed\nnot to acquire or seek to acquire any voting securities of\nCitadel or propose a merger with Citadel for five years, and\nCitadel has paid Great Western six mln dlrs')
# ('.', '"The frenzy and disruption created by merger mania\nis particularly distressing')
# ('.', '"\n    BIL has said it is against the merger because it sees\nProgressive shares as being worth twice as as much as\nRainbow\'s')
# ('.', "Depending on its evaluation of the company, including\nactions by Crazy Eddie's board and any possible third party\nbids for the company, Entertainment Marketing and its president\nsaid they may hold their present stake in the company, sell\nsome of their shares, or purchase more shares on the open\nmarket, through private purchases or in connection with a\nmerger or tender offer")
# ('.', "Upon clearance of the revised proxy\nstatement by the commission and its distribution to Staff\nBuilders' shareholders, that company's management will continue\nto solicit proxies for approval of the merger")
# ('.', 'OII said each common share still outstanding at the time of\nthe merger has been converted into the right to receive 60')
# ('.', "Under the agreement, Greyhound will acquire, in a merger,\nthree of the company's foodservice operations - Dobbs\nInternational Services, Dobbs Houses and Carson international")
# ('.', 'The company said the merger will be accounted for as a\ncorporate reorganization and be recorded at historical book\nvalues')
# ('.', "Both Rainbow's and Progressive's boards have approved the\nmerger proposal")
# ('.', 'The new offer, the second sweetened deal Redstone has\nproposed in his month-long bidding war with management, also\ncontains newly drawn up proposed merger documents, he said')
# ('.', 'One of the deals in which an insider profit was alleged was\nthe 1984 merger of K-Mart Corp &lt;KM> with &lt;Pay Less Drug\nStores>')
# ('.', "Ward said it was his idea to have a merger agreement with\nDistillers under which Distillers agreed to pay Guinness's bid\ncosts, the PA reported")
# ('.', '"Texaco has consistently maintained that Pennzoil did not\nhave a binding contract to Buy Getty Oil shares, since a press\nrelease announced only an \'agreement in principle\' which was\n\'subject to the execution of a definitive merger agreement\',"\naccording to Gayle')
# ('.', 'The company said it expects to proceed with a merger and\nhas advised Cyclops it intends to increas the per-share amount\nto be paid in the merger to 95 dlrs, form 90')
# ('.', 'It said the junior subordinated debentures to be issued in\nthe subsequent merger will carry a 13 pct annual interest rate,\npayable twice a year')
# ('.', 'The Appeals Court ruling surprised officials of\nAtlanta-based Delta, which had been preparing for the merger\nfor months and had already painted Delta logos on airplanes\nbelonging to Western, which has headquartera in Los Angeles')
# ('.', '89 dlrs\n    net loss 309,100,000\n    NOTE: No comparisons because company was formed in June\n1987 through merger of RepublicBank Corp and Interfirst Corp')
# ('.', 'T>, are\nconsidering a merger, company spokesmen said')
# ('.', 'The companies cited a combination of extraordinary market\nconditions and unresolved terms of the merger as contributing\nto the action')
# ('.', 'The Post and Telecommunications Ministry has urged the\nmerger of the two firms because it says the market can only\nsupport a single KDD competitor')
# ('.', 'The\ncompany said a merger of Rexnord and a subsidiary of Banner\nwill be completed before mid-May')
# ('.', "Financial Corp, parent of American Savings and Loan\nAssociation, the nation's largest thrift, has repeatedly said\nit would give serious consideration to a merger as a means of\nrapidly improving its capital position")
# ('.', 'The company said its merger last year with Associated Dry\nGoods, which was accounted for as a pooling of interests, is\n"going very well')
# ('.', 'O>\nin a merger agreement')
# ('.', 'The\ncompanies entered into a merger agreement on January 27, and\nmade their initial findings with the Department of Justice and\nthe Federal Trade Commission on February three')
# ('.', 'If the merger is consumated, S and P would rate the newly\nformed Baker Hughes Inc senior debt at A-minus, subordinated\ndebt at BBB-plus and commercial paper at A-2')
# ('.', 'FCS said merger\nnegotiations with this other company have been continuing since\nlate August')
# ('.', 'Wang said Haefner, the Swiss investor, would hold about 25\npct of Computer Associates stock after the merger')
# ('.', 'After the merger, Breast Centers shareholders would become\nthe majority shareholders of the combined company')
# ('.', "Canadian International, as earlier reported, was formed from\nthe merger of Pacific Western's Pacific Western Airlines Ltd\nunit and Canadian Pacific Airlines Ltd")
# ('.', '1987 results reflect the TBS merger agreement and operations of\nthe company as independent agent')
# ('.', 'He said that merging Southern with Kansas City will achieve\nthe benefits of an end-to-end merger while preseving the\nindependece of the Southern Pacific versus its existing prime\ncompetitor, Santa Fe')
# ('.', '"I don\'t think that a merger would solve regulatory\nproblems," CFTC chairman Susan Phillips told the House\nSubcommittee on Conservation, Credit and Rural Development')
# ('.', 'The merger is\nsubject to court approval of the settlement as well as to other\nconditions')
# ('.', '1986 net includes costs of 900,000 dlrs in quarter and\n1,200,000 dlrs in year from proposed merger')
# ('.', "Moody's said the anticipated merger of Baker and Hughes\nTool into Baker Hughes Inc would result in increased financial\nleverage at a time of weak demand for the combined company's\nproducts and services")
# ('.', 'Sorg said the group also agreed to vote as a body on any\nproposed merger or election of directors')
# ('.', "She noted that Chrysler Corp's &lt;C> announcement of a merger\nproposal for American Motors Corp &lt;AMO> should have no short\nterm effect on Ford but could cut into Ford's share of the\ntruck market in the long term")
# ('.', 'District Court for the Southern District of New York denied the\nmotion of &lt;Carsey-Werner Co> for a temporary injunction to\nblock the proposed merger of Viacom with a subsidiary of\n&lt;National Amusements Inc>')
# ('.', "Interstate Commerce Commission\nto reconsider its earlier rejection of the merger of the\nholding company's railroad assets")
# ('.', '"\n    Metzenbaum said Icahn had failed to file a pre-merger\nnotification form with the FTC prior to purchasing more than 15\nmln dlrs\' worth of USAir stock')
# ('.', 'Justice Department has announced that it will\nrequire divestiture of the product line for approval of the\nmerger')
# ('.', "The transaction is conditioned on  Allied's pending merger\nwith the Vons Cos Inc")
# ('.', 'The offer will be followed by a merger in which each\nremaining share will be converted into 19')
# ('.', "S and P cited a merger agreement between the two companies\nwhich it believes will improve both firms' market positions as\nwell as complement each other's products and distribution")
# ('.', 'He said the arguments cited\nby Hughes yesterday for not doing the merger "tend to be weak')
# ('.', "Uccel's Liemandt declined to say what he will do after the\nmerger, but he did not rule out working together with Wang")
# ('.', 'But it said investment banking firms should be allowed to\ncontinue to engage in both arbitrage and merger and acquisition\nactivities so long as those functions were kept separate')
# ('.', 'Late yesterday, Hughes said it had terminated the merger\nagreement because Baker would not agree to an alternative\ndivestiture plan devised by Hughes')
# ('.', 'Stevens &lt;STN> climbed 5/8 to 44-7/8, and Fieldcrest\nCannon Inc &lt;FLD>, the result of a merger of Fieldcrest and\nCannon, rose 1-1/8 to 39-3/4')
# ('.', 'Under a previously announced merger agreement, Amsouth\noffered 66 dlrs a share in Amsouth stock for First Tuskaloosa')
# ('.', 'Operations are dependent upon financing and efforts to\nobtain financing, including potential buyers and merger\ncandidates, have been unsuccessful, it said')
# ('.', "Redstone said the management group's investment bankers\nwill be paid what is due for termination of its merger\nagreement")
# ('.', 'He said he\nbelieves such a merger could create a stronger force in the\ntire industry')
# ('.', 'Industrial Equity (Pacific) added it is considering\nlaunching a tender offer for Calmat stock or making a merger\nproposal to the company, but said it has not decided whether it\nwill pursue a Calmat acquisition on a non-negotiated basis')
# ('.', 'The companies said the proposed merger would bring together\nbusinesses that were largely complementary')
# ('.', 'Following the merger, Balzac shareholders will hold 80 pct\nof the outstanding stock of Magellan, the company said')
# ('.', '" But he\nexpressed skepticism that this will necessarily lead to\nheightened merger or buyout activity in the oil group')
# ('.', 'Under terms of the merger agreement, Chatsworth said\nLotoquik shareholders would own a majority of the surviving\ncompany')
# ('.', 'However, the suggestion still recommended a merger between\nthe two consortia tendering for contracts and would give Cable\na five pct stake, more than the three pct originally proposed\nbut less than the 20 pct it holds in its original venture, he\nsaid')
# ('.', '"\n    Kistler also said that the law suit filed by Baker "was not\na factor" in the board\'s decision to keep its merger proposal\non the table')
# ('.', "N> may take part in a proposed\nmerger of two rival firms seeking to enter Japan's\ninternational telecommunications market, a senior industry\nofficial said")
# ('.', 'The company said the merger is expected to be completed\nafter mid-year, following regulatory approval')
# ('.', 'Revlon said its board of directors unanimously approved the\nmerger agreement')
# ('.', 'Comdata said WCAS and its affiliate investors would commit\n50 mln dlrs to buy the securities comprising the new entities\nunits of securities resulting from the merger in the same\nproportions and at the same price as the company shareholders')
# ('.', 'The merger involves the formation of a new company &lt;Astral\nPacific Corp Ltd> which will acquire all shares in both\ncompanies on a one-for-one share exchange basis')
# ('.', 'The Hughes board last week indicated that it might cancel\nthe merger because of the Department of Justice requirement')
# ('.', '6\n    NOTE: 1986 first quarter profits restated down one cent a\nshare as a result of previously reported pooling of interests\nmerger with Mid-Continent Life Insurance Co')
# ('.', 'TWA said the merger is subject to the USAir board redeeming\nthe preferred stock purchase rights (the poison pill) issued to\nshareholders last year and taking action so that the vote of a\nmajority of the outstanding common stock is required to approve\nits proposed move')
# ('.', 'Santa Fe in its petition outlines an array of\npro-competitive agreements with other railroads which would\npreserve the economic benefits of the merger for the merged\nrailroad and the public')
# ('.', "FMC had charged that Boesky received confidential\ninformation about FMC's planned recapitalization from Dennis\nLevine, a former merger specialist with Drexel Burnham Lambert\nInc")
# ('.', 'The analysts said Sumitomo will have to devote a lot of\ntime to digesting its most recent initiatives, including the\nmerger with ailing Heiwa Sogo')
# ('.', 'Under the terms of the merger, Sovereign stockholders\nwil receive, in a tax free exchange, 0')
# ('.', '1 pct of those\noutstanding, for 6,950,000 dlrs immediately prior to the\nconsummation of the merger')
# ('.', '"Unlike many recent combinations, this merger has no\nacquisition premium associated with it," Blampied said')
# ('.', "The merger will provide an\nopportunity for expansion in an area with favorable economic\ntrends, although it will lower trading margins by more than\nSainsbury's historic levels, S and P pointed out")
# ('.', "It said that Morgan Stanley and Co Inc and Salomon Brothers\nInc, hired in 1983 to advise Southern and Santa Fe in their\nmerger, appraised Southern as worth between 500 mln dlrs and\n800 mln dlrs less than Southern's own internal valuations")
# ('.', "The union's sugar beet committee met yesterday to consider\nthe implications of a government Monopolies and Merger\nCommission, MMC, report issued last week")
# ('.', 'The ministry has favoured the merger of the two rival\ngroups, arguing the market cannot support more than one\ncompetitor to Kokusai Denshin Denwa Co Ltd, which now\nmonopolizes the business')
# ('.', 'The Justice Department in January said it would block the\nHughes and Baker merger on anti-trust grounds unless both\ncompanies agreed to sign a consent decree that would provide\nfor the sale of the assets after the merger took place')
# ('.', 'A merger at the tender price that has been\napproved by the ARGOSystems board is to follow the offer')
# ('.', 'The group is currently looking for a possible partner after\na merger with &lt;Scovill Inc> of the U')
# ('.', 'Pennzoil said the merger\nviolated a prior agreement it had to buy Getty and sued Texaco')
# ('.', 'But a merger of the two deposit-insurance agencies could be\nan option as part of a general structural reform of the U')
# ('.', 'It had also proposed\na takeover of USAir, which at the time was negotiating its\nproposed merger with Piedmont Aviation Inc')
# ('.', 'Rainbow chairman Allan Hawkins said in a statement, "In our\nopinion BIL have deliberately tried to create anomalies in the\nmarket prices of Rainbow and Progressive shares since the\nmerger was announced')
# ('.', 'Note - Company was created in May 1986 by the merger of\n(Royale Belge Vie-Accidents) and (Royale Belge\nIncendie-Reassurance)')
# ('.', "CBC said the merger will not affect Citizens Banks' name,\nmanagement, board of directors or employees")
# ('.', 'After the merger, Viacom will be a subsidiary of National\nbut 17 pct of the company will be in public hands')
# ('.', 'Sosnoff said under the merger that would follow his tender,\neach of the 2,750,000 Caesars shares not covered by the offer,\nor 7')
# ('.', '"It\'s a very complex transaction, but basically what\nhappens is they ostensibly put up money but the fees recapture\nany investment they might have once the merger takes place,"\nGardner said')
# ('.', 'IDC said the merger agreement also provides for payment of\nan equivalent amount in respect of employee stock options to be\ncancelled in the merger')
# ('.', 'TWA said the agreement does not prevent it from commenting to\nregulatory agencies on the USAir, Piedmont merger')
# ('.', 'Hutton said in the merger shareholders would get 46 mln\ndlrs aggregate amount of guaranteed debentures due 2002 of PC\nAcquisition and warrants to buy 15 pct of the common stock of\nthe PC courier subsidiary')
# ('.', 'Cable and Wireless has a 20 pct stake in one of the two\ncompanies involved in the mooted merger')
# ('.', 'If approved, the merger will add another 3')
# ('.', 'The offer and withdrawal rights\nare to expire April Three unless extended, and the bid is to be\nfollowed by a merger at the same price')
# ('.', "ST> said the group to be\nformed by its merger with Switzerland's BBC AG Brown Boveri und\nCie &lt;BBCZ")
# ('.', '-- shares issued in connection with a merger, acquisition\nor recapitalization where the exchange of shares is accompanied\nby detailed proxy material')
# ('.', "The company said its merger agreement with Piedmont\nprovides that the offer is not to be amended without Piedmont's\nprior written consent in any way that would be adverse to\nPiedmont shareholders, but it said it could cut the number of\nshares to be bought without Piedmont's consent")
# ('.', 'We consider this to be a merger\nof equals')
# ('.', '"\n    Comsat, created by a 1962 act of Congress, and Contel, a\ncorporation of local telephone and communications firms, filed\nwith the Federal Communications Commission last November 3 an\napplication for merger')
# ('.', 'But no decision has been made on\nwhether or how to proceed with a merger attempt, he added')
# ('.', 'A merger approved by the Allegheny board in which remaining\ncommon, preference and preferred shares would be acquired at\nthe tender prices is to follow the offer')
# ('.', "She said KLM would like the two courier services to\ncooperate in future and did not exclude a future merger between\nthem to combine IML's strong world-wide network with XP's\nmainly European activities")
# ('.', '25 dlrs the amount per share paid in the merger of a\nDixons subsidiary with Cyclops')
# ('.', 'As a result of the merger, the former shareholders of\nScan-Graphics will become the majority shareholders of Captive\nVenture Capital')
# ('.', 'The complaint said Vaskevitch leaked information\nabout 12 companies that were involved in a merger or aquisition\nwhich resulted in more than four mln dlrs in profit for himself\nand others involved in the scheme')
# ('.', 'News Corp said if the merger agreement were terminated\nunder certain circumstances, News would be entitled to a 16 mln\ndlr cash payment')
# ('.', "The order was issued as part of a settlement of FTC charges\nthat Cooper's merger with Gardner-Denver Co would lessen\ncompetion and increase concentration in the gas compressor and\nindustrial air tool industries, the FTC said")
# ('.', 'United Security said it is anticipated that\nsuch stock would represent a substantial majority of the shares\noutstanding after the merger')
# ('.', 'It said its suit names as defendants Hughes and certain of\nits directors and seeks either an injunction forcing Hughes to\nlive up to the merger agreement or "substantial" monetary\ndamages it did not name')
# ('.', 'The voting trust agreement requires the bank to vote in\nfavor of any acquisition agreement between TWA and USAir and to\nopposed any other merger of USAir')
# ('.', 'The company said the transaction is subject to Hughes Tool\nCo &lt;HT> and Baker shareholder approval of the Baker/Hughes\nmerger')
# ('.', 'While the banks have been approached by securities firms\nseeking merger partners, they have not yet bought into\nbrokerages, choosing to build securities units from within')
# ('.', 'Completion of the merger transaction is expected in three\nto four months')
# ('.', 'TWA said it is filing an application with the Department of\nTransportation seeking approval of the merger as well as an\napplication for approval, on an expedited basis, of its\npurchase of up to 51 pct of USAir common and the deposit of the\nstock in a voting trust, pending DOT approval')
# ('.', "In a statement, the commission said Rover's &lt;Leyland\nTrucks> subsidiary would be financially and physically\nrestructured following a recently announced merger between\nLeyland Trucks and &lt;DAF> of the Netherlands")
# ('.', 'The BIFFEX board is expected to reach a decision on the\nmerger at its meeting at the end of this month, after members\nare consulted at a meeting on March 16')
# ('.', 'The company said Maryland Alliance wanted the merger\nblocked on the grounds that NCNB inadequately served the credit\nand financial needs of low-income and minority communities in\nits markets')
# ('.', 'Hanson said that promptly following the filing of the\ncertificate of merger Kaiser Cement common shares will be\ndelisted from the New York Stock Exchange')
# ('.', "USAir said it has been advised by Norfolk Southern that the\ncompany supports the proposed merger and intends to tender all\nof its remaining 1,477,829 Piedmont common shares in response\nto USAir's tender offer which began today")
# ('.', 'Advanced said it had suspended merger talks with other\nparties as a result of the exclusivity agreement')
# ('.', 'Two airlines, Sabena and Scandinavian Airlines System\n(SAS), are now discussing a merger')
# ('.', '25 dlrs each,\nexercisable if it should fail to meet any condition connected\nwith the transaction or if principal shareholders should accept\na merger offer from another party')
# ('.', '"\n    Narragansett said the offer is subject to negotiation of a\ndefinitive merger agreement and definitive financing agreements\nas well as approval by regulators, Taft\'s board and Taft\'s\nstockholders')
# ('.', "American's merger with AirCal, announced last November,\nreceived final approval from the Department of Transportation\nyesterday")
# ('.', 'USAir said it requested the dismissal because TWA avoided\npre-merger notification requirements, and also did not provide\na competitive and public interest analysis required under\nregulations')
# ('.', 'BIL chief executive Paul Collins said: "All Rainbow has done\nis to outlay a substantial amount of cash to purchase shares\nfrom parties who presumably were supportive of the merger')
# ('.', '50 dlr a\nshare takeover proposal last September, but subsequent merger\ntalks broke down in October')
# ('.', "Meese told the House Appropriations Subcommittee that\nconsideration would be part of the Justice Department's review\nof the proposed merger")
# ('.', 'The merger took place in December, and Western has\nbeen operated as a Delta subsidiary since then')
# ('.', 'The merger is expected to close on April 22')
# ('.', 'Chrysler, which bought Gulfstream Aerospace Corp in 1985,\nearlier said Electrospace agreed to be acquired in a friendly\nmerger for about 367 mln dlrs')
# ('.', "The exchange, they said, will be made on the effective date\nof the merger, which must be approved by both companies' boards\nand High Plains' shareholders")
# ('.', '5\nmln dlrs and First City Bancorporation &lt;FBT>, which is actively\nseeking a merger or other form of new capital, lost 402')
# ('.', 'The following results reflect the\noperations of the companies prior to the merger')
# ('.', 'The resulting merger would\ncreate the largest independent software company yet')
# ('.', 'The company said if the merger agreement is terminated\nunder certain circumstasnces, it will be entitled to receive 20\nmln dlrs in damages from ChemLawn')
# ('.', 'Both boards have approved the merger')
# ('.', "A Norfolk Southern Corp &lt;NSC> spokesman said the company\nhad no comment on TWA's offer for USAir or on its proposal to\nnegotiate a three-way merger between TWA, USAir and Piedmont")
# ('.', 'Charles Bundrant,\npresident of Trident before the merger, was named president of\nthe new company, Conagra said')
# ('.', 'This week Hughes seemed to back out of the merger but then\nsaid it was still interested in talking')
# ('.', 'It said it expects no change in its dividend policy -- it\nnow pays 29 cts per share on a regular quarterly basis -- and\nplans to continue current dividend payments until it completes\nits proposed merger into Security Pacific Corp &lt;SPC>')
# ('.', 'Department of Justice consent decree that would\nrequire Baker to sell its drilling bit operations and\nsubmersible pump business, met yesterday and threatened to\nterminate the proposed merger')
# ('.', 'Last night, Hughes said the planned merger with Baker was\noff')
# ('.', 'Airlines officials\ncould not be reached for comment on the ruling, which halts the\nmerger until arbitration on the dispute is completed')
# ('.', 'As part of the plan, the company will change its state of\nincorporation from Florida to Delaware by means of a merger of\nCaesars World into a wholly owned subsidiary of the company')
# ('.', 'That\nmeeting was called to act on a merger agreement calling for a\nbuyout by BCW Acquisitions Inc')
# ('.', 'The merger is to be made by Onyx buying LASMO Exploration,\nin a share swap')
# ('.', 'Her favorite is Baker International, which is involved in a\npossible merger with Hughes Tool Co')
# ('.', 'Under the merger agreement, remaining shareholders of\nHayes, a Jackson, Mich')
# ('.', 'He said if outside directors approve the management\nproposal, a merger plan could be put to a vote of shareholders\nwith proxy material going out late this week')
# ('.', "L> Plc said it has no\nintention of proceeding any further with talks on Williams\nHoldings Plc's suggestion that there would be benefits arising\nfrom a merger between the two groups")
# ('.', 'Santa Fe Southern Pacific owns the Santa Fe railroad and\nholds the Southern Pacific railroad assets in trust while\nawaiting federal approval of the merger plan')
# ('.', 'A merger at the tender price is to follow the offer, which\nhas been approved by the Harper and Row board')
# ('.', 'In response, Emery said it would renew its request for\na merger with the Basking Ridge, N')
# ('.', 'Asamera said its talks with Breakwater Resources Ltd\n&lt;BWRLF> on a possible merger of mining interests, including the\nCannon mine, have been terminated')
# ('.', 'Following the merger, the two companies saw significant\nopportunities for growth in brokerage income and considerable\nscope for improved operating efficiency')
# ('.', 'The offer, which has been approved by the\nHolly board and is to be followed by a merger in which\nremaining shares are to be exchanged for cumulative redeemable\nexchangeable preferred stock, is conditioned on receipt of at\nleast 664,400 shares, which would give Plum a two thirds\ninterest, and the receipt of financing')
# ('.', 'Last week three exchanges currently trading on the Baltic\nExchange, the London Potato Futures Association, the GAFTA Soya\nBean Meal Futures Association and the London Meat Futures\nExchange, instructed legal advisers to implement a merger')
# ('.', 'The\nAmerican Service board has approved the offer, which is to be\nfollowed by a merger at the same price')
# ('.', "The companies said they expect the merger will occur after\nthe declaration of effectiveness of an amendment to Magellan's\nregistration statement relating to its common stock purchase\nwarrants and the underlying shares")
# ('.', '1985 results reflect only six mths of mining operations due\nto merger of Erickson Gold Mines Ltd and Total Eastcan\nExploration Ltd on June 30, 1985')
# ('.', 'The merger of Uccel and Computer Associates combines the\ntwo biggest systems utilities suppliers other than IBM')
# ('.', '" Hughes said that Baker should\ninstead complete the sale of the disputed assets before the\nmerger is finalized and given government approval')
# ('.', "The merger is subject to approval by the companies' boards\nand shareholders and agreement of certain Strata creditors,\namong other things, said the companies")
# ('.', 'Rainbow has said the merger is soundly based')
# ('.', 'After Rorer announced its second bid for the company last\nThursday, analysts forecast that the Robins family, which holds\ncontrol of the company, would vigourously oppose any merger')
# ('.', '"\n    Gallo said FCS will stop actively seeking potential merger\npartners, but will respond to serious inquiries')
# ('.', 'The aim of a merger would not be for commercial banks to\nsubsidize ailing savings and loan associations but to improve\nofficial oversight of depository institutions, Volcker said')
# ('.', 'Such a merger would be complex and analysts said it would\nresult in an airline iwth an 18 pct market share')
# ('.', 'Analysts said the merger is virtually certain to go ahead')
# ('.', 'Analysts said the merger would dilute the holdings of\ncurrent Computer Associates shareholders by about 10 pct')
# ('.', 'subsidiary has not achieved this ownership\nwithin one year after the completion of the merger, the\nsubsidiary will have the right two years thereafter to request\nthat HRI commence a rights offering to HRI stockholders, the\ncompany said')
# ('.', 'The change affects 515 mln dlrs in debt and assumes a\nmerger of the two companies will be completed')
# ('.', "The company said Heck's Chapter 11 filing could, however,\naffect Viner's previously reported legal action to recover\ncosts from an aborted merger agreement with Heck's")
# ('.', "That merger was viewed by some analysts as reducing Rolm's\nindependence and relegating it to a role as a manufacturing and\nproduct development site within IBM")
# ('.', 'The spokesman said agency action on the proposed merger\napplication could take as long as six months')
# ('.', 'The deal is subject to completion of a definitive merger\nagreement, receipt of third party approvals and other\nconditions, the company said')
# ('.', 'He said the company had exceeded its goal of cutting costs\nby 150 mln dlrs in the first year after the merger, and reduced\ndebt by nearly two billion dlrs, more than the originally\nexpected 1')
# ('.', 'Captive had 2,649,500 common shares outstanding\nbefore the merger')
# ('.', 'Hughes yesterday adjourned the special meeting at which\nshareholders were to vote on the merger without permitting the\ncounting of votes on the deal')
# ('.', 'Under terms of the merger,\nwhich took effective today, Universal said its shareholders\nwill receive three dlrs a share in cash')
# ('.', 'The merger is\nexpected to be completed in June, they said')
# ('.', '25 dlrs to 95 dlrs the amount per share paid in the\nmerger of a Dixons subsidiary with Cyclops')
# ('.', "Interstate Commerce\nCommission (ICC) to reconsider its earlier rejection of the\nmerger of the holding company's railroad assets, a company\nspokesman said")
# ('.', 'The proposed merger that would create a 1')
# ('.', 'At midday today Hughes said\nit was still interested in the merger')
# ('.', 'Mark IV said it also agreed at the meeting that if it\ndecides to seek control of Baird, it would be through a\nnegotiated merger or business combination or through a tender\noffer in which Baird would have at least 24 hours notice')
# ('.', 'The company also said it will no longer actively seek out\npotential merger partners, but will respond to serious\ninquiries')
# ('.', 'Analysts said such a merger would be costly and\ncomplicated')
# ('.', 'The company said it will\ntreat the merger as a pooling of interests')
# ('.', "Rexnord's 50 mln dlrs of 12-3/4 pct debentures of 1994 were\ncut to B from A-minus to reflect the merger with Banner")
# ('.', 'The company said it expects to complete the\nmerger by June 17')
# ('.', 'Based on its financial\nexpectations, Fifth Third said the dilution in per share\nearnings for the merger will be negligible')
# ('.', 'It was "business as usual" yesterday at the American Motors\nheadquarters, one day after the proposed merger was unveiled by\nChrysler and AMC\'s French parent Renault, according to company\nspokesman Edd Snyder')
# ('.', 'Kistler estimated that the merger, which should be\ncompleted in about two weeks, will result in annual cost\nsavings of about 50 mln dlrs')
# ('.', 'Earlier today, Hughes adjourned a shareholders meeting\ncalled to vote on the proposed merger until March 11 and said\nit hoped to resume negotitations with Baker')
# ('.', 'The merger will be effective June 1, coinciding with the\nretirement of Utah International chairman and chief executive\nBud Wilson, BHP said in a statement')
# ('.', "But for flexibility purposes, Merrill Lynch said it is\nconsidering redistributing Borg-Warner's assets to a number of\nsubsdiaries of an entity it created to carry out the merger")
# ('.', 'Robins Co said its board\nhas concluded that the merger proposal submitted by Rorer Group\nInc &lt;ROR> merits further consideration')
# ('.', "Shearson said Stearns formerly was part of Merrill Lynch\nPierce, Fenner and Smith Inc's &lt;MER> merger and acquisitions\ndepartment")
# ('.', 'Earlier, Alpha Health Systems Corp, a unit of Pesch and Co,\nsaid it submitted a merger proposal to the board of REPH\nAcquisition Co, the parent of Republic Health')
# ('.', '"\n    The ruling in San Francisco came in a lawsuit that had been\nfiled in a Los Angeles federal court in which the Air Transport\nEmployees union sought to force Western\'s management to fulfill\na promise that it would honor union contracts if a merger took\nplace')
# ('.', "Pantera's also said it retained Drexel Burnham Lambert Inc\nto act as its financial advisor in connection with the merger")
# ('.', 'The suit also seeks to block a provision in the merger\nagreement for Dome to sell to Amoco its Primrose, Alberta,\nheavy oil properties for 79 mln dlrs if the takeover is not\ncompleted')
# ('.', 'Still, he has succeeded in holding up a merger of two\nairlines - both of which analysts said would fit well with TWA')
# ...
# ('.', 'It also said shareholders approved the merger of Morning\nStar Mine interests held by six corporations in exchange for\nissuing 2,098,602 shares of its common')
# ('.', '4 Dauphin shares\nfor each colonial share, depending on the market value of\nDauphin shares just before the merger takes place')
# ('.', 'Under the merger,\nshareholders in both Progressive and Rainbow will be issued\nshares in the new company on a one-for-one basis')
# ('.', '1 pct of the\noutstanding shares will be required to approve the merger,\nTender Loving Care said')
# ('.', "The ADS's will be valued at the average of their closing\nprices in the 10 trading days before the effective date of the\nmerger")
# ('.', 'If it buys more shares, Metropolitan\nsaid it would consider doing so in the open market, in private\ndeals, or through an exchange offer, tender offer or merger')
# ('.', 'in an attempt to block the merger')
# ('.', '9 common shares each, valued at\nabout 73 dlrs per share based on the average closing price of\nUSAir common during a period just before the merger')
# ('.', 'banking merger, can be completed by the beginning\nof 1988, according to an executive of Fleet')
# ('.', 'The companies said with the merger Nolan now will be known\nas Nolan, Norton and Co-partners, the information technology\narm of Peat Marwick')
# ('.', 'The company said the board decision to adopt its own\ndivestiture plan and terminate the merger agreement if Baker\ndid not accept was unanimous')
# ('.', "Cable and Wireless Director of Corporate Strategy, Jonathan\nSolomon, yesterday again told ministry officials he opposes a\nmerger proposal that would limit Cable and Wireless' share to\nless than three pct and total foreign participation to about 20\npct, the ministry official said")
# ('.', 'The company said also before the merger, San/Bar would\nBarry K')
# ('.', 'The merger is effective April one and is subject to\nshareholder approval')
# ('.', '"We think that\nin the third or fourth quarter after the merger we should see\nsomething close to breakeven," he said')
# ('.', 'MCO said one MAXXAM shareholder has filed an objection to\nthe proposed settlement of shareholder actions related to the\nmerger in the Delaware Court of Chancery')
# ('.', 'Hutton Group Inc EFH under\nwhich Hutton will terminate its merger agreement with Purolator\nCourier Corp and its pending 35-dlr-per-share tender offer,\neffective April 13')
# ('.', 'O> approved\nthe merger of the two companies')
# ('.', "The ministry's stance has outraged both London, which has\nthreatened to retaliate, and Washington, which says the merger\nplan is evidence of Japan's failure to honour pledges to open\nits telecommunications market")
# ('.', 'Britain opposes the proposed merger')
# ('.', 'With completion of the merger, Shefra changed its name to\nFlyfaire International Inc')
# ('.', 'The merger following the tender offer will be subject to\napproval by ARGOSystems shareholders, the companies said')
# ('.', "That topped the proposed merger of Los Angeles-based\nSecurity Pacific Corp &lt;SPC> and Seattle's Rainier Bancorpartion\n&lt;RBAN>")
# ('.', '"Business is\ncontinuing as usual," it said, adding that it is not engaged in\nany merger or acquisition discussions')
# ('.', 'TWA also agreed that it would not knowingly and willingly\ninterfere with the consummation of the merger between USAir and\nPiedmont Aviation Inc &lt;PIE>')
# ('.', "Moody's cited Fleet's announced merger with Norstar Bancorp\nInc &lt;NOR>")
# ('.', 'If the merger is approved by\nregulatory agencies and stockholders, it would create the 12th\nlargest bank holding company in the United States')
# ('.', 'Fumio Watanabe, a senior Keidanren (a leading business\norganization) official who has been trying to arrange the\nmerger, will present a new outline of his proposal on Thursday,\nthe ministry official said')
# ('.', 'The companies said they agreed not to pursue the merger\nbecause several actions recently taken by AmBrit would mean\nsubstantial delays in completing the deal')
# ('.', 'Emery said Purolator would operate as a wholly owned unit\nof the company after the merger')
# ('.', 'The Baker-Hughes merger, which would would create a 1')
# ('.', 'Two weeks ago before the study was completed, Contel\nannounced it would seek to terminate the proposed merger')
# ('.', 'The FDIC said it subsidized the merger of Central Bank and\nTrust Co, Glenmora, La')
# ('.', 'It added that the lawsuit will not affect the negotiations\non the merger transaction with Bristol-Meyers Co &lt;BMY>,\nannounced Monday')
# ('.', 'There was no comparable figure for the third quarter of\n1986 because the company was formed in June 1987 through the\nmerger of RepublicBank Corp and Interfirst Corp')
# ('.', 'In an attempt to hammer out an agreement, Solomon today met\nFumio Watanabe, the senior Keidanren officer trying to arrange\nthe merger')
# ('.', '5 mln dlrs\nfor the merger facility')
# ('.', "Kansas also said it argued in the ICC filing that Santa Fe\nhad not met the legal requirements justifying the Commission's\nreconsideration of the proposed merger of Santa Fe and Southern\nPacific, two railroads that it said basically parallel each\nother throughout their routes")
# ('.', 'The company said its previously-announced merger into\nInspectorate is still subject to approval by Network\nshareholders')
# ('.', 'First City, the big Texas bank hit hardest by the downturn\nin oil prices, lost a record 402 mln dlrs in fiscal year 1986\nand has said it is seeking a merger partner or some other\ncapital assistance')
# ('.', '1 billion\n    NOTE: Results restated for merger of Midlantic Banks Inc\nand Continental Bancorp Inc on January 30, 1987')
# ('.', 'Resorts said the offer from KSZ calls for a merger of\nResorts with RI Acquisition Co Inc, a newly formed Delaware\ncorporation')
# ('.', "DRS, a warfare systems producer, said it would make the\ntransaction through a cash tender offer for all, but not less\nthan 51 pct, of Rospatch's outstanding common stock followed by\na merger with Rospatch, a labels, high technology and wood\nproducer, at the same purchase price per share")
# ('.', "Allied legal advisor and director George Kern, who heads\nthe merger and acquisitions group at the New York law firm of\nSullivan and Cromwell, decided against amending Allied's SEC\nfiling to disclose the talks even though they had resulted in\nsales price of 405 mln dlrs for the shopping centers, it said")
# ('.', '9 mln dlrs in both periods of earlier\nyear from merger of divisions')
# ('.', '"The Transportation Department\'s antitrust enforcement has\nbeen disastrous, permitting rampant merger mania," Ohio\nDemocrat Howard Metzenbaum said in a statement')
# ('.', "The company said Penn Traffic is expected to hold a special\nshareholders' meeting later this month to approve a merger into\nMiller Tabak at the tender price")
# ('.', 'The acquisition would be a cash merger, with Progressive\nshareholders receiving up to three dlrs per share, the company\nsaid')
# ('.', 'Closing of the merger would occur immediately after\nthe filing, it said')
# ('.', 'The merger is still subject to approval by shareholders of\nboth companies')
# ('.', ",\nbusinessman and major shareholder of Kappa Networks Inc, said\nhe and Kappa's management are considering seeking a merger\nbetween Kappa and Radiation Systems Inc")
# ('.', 'The meeting would also be asked to approve a merger of two\nItalian subsidiaries, &lt;CM Italia Spa> and &lt;Societa\nAmministrazioni Turistiche Srl>')
# ('.', 'In a filing with the Securities and Exchange Commission,\nMerrill Lynch Capital Partners Inc said it would receive a 30\nmln dlr fee from the surviving company for acting as dealer\nmanager of the merger after the Borg-Warner deal is completed')
# ('.', 'Borg-Warner and Merrill said yesterday they entered a\ndefinitive merger agreement, under which a subsidiary of the\nnew company, &lt;AV Holdings Corp>, will begin a 48')
# ('.', 'Under terms of the merger, Fair Lanes said each of its\nshares of common stock will be converted into the right to\nreceive 1')
# ('.', '"\n    It said it planned to regularly review its investment and\nmay in the future recommend business strategies or an\nextraordinary corporate transaction such as a merger,\nreorganization, liquidation or asset sale')
# ('.', "Automaker, has said the\nmerger is motivated principally by its desire to acquire AMC's\nprofitable Jeep business and dealers, as well as a new modern\ncar assembly plant in Bramalea, Ontario")
# ('.', 'If the merger is approved, common stock still outstanding\nwill be converted into the right to receive 61')
# ('.', "Additionally, Dixon Group's rights to buy Cyclops common\nand its rights to fees or expenses if the Dixon-Cyclop merger\nagreement is broken must be rescinded, Cyacq said")
# ('.', 'The request to bar the merger was made by Samjens\nAcquisition Corp, a partnership formed by financier Asher B')
# ('.', 'Earlier this month the group said that tentative merger\ntalks with the high street pharmacist &lt;Underwoods Plc> had been\ncalled off and recently announced a 19')
# ('.', '8 pct of its stock and have agreed to vote in favor of\nthe merger')
# ('.', '1 billion vs 900 mln\n    Note: Year-ago results restated to reflect merger with\nColson Inc')
# ('.', 'Liemandt, who said he will leave the company after the\nmerger is completed, also turned to acquisitions for growth')
# ('.', "Moody's cited the significant increase in leverage and the\nreduction in coverages that will result from the merger of\nScott with Simmons Communications Merger Corp")
# ('.', "Without the merger, Hughes Tool's current ratings of B-plus\nfor senior debt, B-minus for subordinated debt and C for\ncommercial paper would be affirmed, S and P said")
# ('.', 'The companies said they expect to complete the merger,\nwhich will create a bank with 80 billion dlrs of assets, by the\nend of the second quarter')
# ('.', "In order for the other carriers to come down to TWA's wage\nscale in a merger, TWA would have to be the surviving entity,\nanalysts said")
# ('.', '86 dlrs per share on exchange of common of Pan America\nBanks Inc for common of NCNB Corp purusant to a merger of the\ncompanies')
# ('.', 'Mattson also declined to comment on whether the directors\nof Baker and Hughes have scheduled any meetings to discuss the\nmerger')
# ('.', '7 pct interest, and\nis the first step in a merger agreement that has been approved\nby the Purolator board')
# ('.', '4 pct stake, have both\nagreed not to buy more shares of the company until a merger is\ncompleted, unless the purchases are part of a tender offer for\nat least half of the outstanding stock')
# ('.', 'The DOT had given tentative approval to the merger plan\nFeb')
# ('.', "The merger will bring Suburban's assets to\n661 mln dlrs and its total banks to 13")
# ('.', "The group has drafted its own merger guidelines to bring\nuniformity to the attorney generals' efforts to enforce the\nlaws at the state level")
# ('.', "BIL Chief Executive Paul Collins said last week that he\nopposes the Rainbow/Progressive merger because BIL sees\nProgressive shares as being worth twice as much as Rainbow's")
# ('.', 'Seton said its board of directors unanimously approved the\nmerger in a meeting held today')
# ('.', 'Viacom said earlier today it received revised takeover bids\nfrom Redstone and MCV Holdings Inc, a group led by Viacom\nmanagement which is competing with Redstone for control of the\ncompany and already has a formal merger agreement with Viacom')
# ('.', 'Appeals court last night\nblocked the 860 mln dlr merger of Delta Airlines Inc &lt;DAL')
# ('.', "Redstone's newest plan raised the amount of interest he\nwould pay on the cash portion of his offer for every day beyond\nApril 30 that a merger with Arsenal is not consummated")
# ('.', 'The financial terms of the merger are unchanged, a Hughes\nspokesman said')
# ('.', '"I think one of the things that has to be recognized in that\nmerger is that it appears, at least, that a good portion of the\nownership of American Motors, which has been in overseas hands\nwill be put back in American hands," Meese told the\nsubcommittee')
# ('.', 'Watanabe said progress was being made towards a merger\nagreement and added that Japanese industry agreed with the\ngovernment on having only one private consortium as two\ncompanies might invest "excessive" amounts')
# ('.', 'The company said a definitive merger agreement is expected\nto be negotiated within six weeks and shareholders are expected\nto vote on the deal at a meeting expected to be held in June or\nJuly')
# ('.', 'The merger calls for an unspecified amount of stock to be\npaid for Nucell, the company said')
# ('.', 'Banner said it expects to complete the merger with Rexnord\nwithin 60 days')
# ('.', 'Harcourt Brace said it will only pursue the acquisition if\na mutually-satisfactory merger agreement can be negotiated')
# ('.', "But it left open that it might make other changes in\nGenCorp's operations after it completes the merger")
# ('.', "6 pct of Modulaire's common\nstock that could be voted in favor of the merger")
# ('.', 'Secretary of State George Schultz have\nwritten to the Japanese government about the planned merger')
# ('.', "Moody's said it is also examining\nthe potential use of the airline's borrowing capacity to\nfinance the merger")
# ('.', 'Under a merger agreement entered into in November, Reuters\ntendered for up to 5')
# ('.', 'Progressive is currently involved in a proposed merger with\n&lt;Rainbow Corp Ltd>')
# ('.', 'The merger would give American control of 37 pct of the\nauthorized takeoff and landing slots at the Orange County\nterminal, where environmental concerns and a small terminal\nbuilding limit future opportunities for expansion')
# ('.', '"\n    Weber added that Contel is holding discussions with\n&lt;Comsat> on an agreement to terminate the previosuly proposed\nmerger between the two companies')
# ('.', 'It added that the B-3 rating recognizes operating\nefficiencies that will result from the merger')
# ('.', 'It said Quest Blood expects to complete the merger within\nthe next several weeks')
# ('.', "Supreme Court Justice Sandra Day\nO'Connor early this morning lifted an Appeals Court injunction\nblocking the planned merger of Delta &lt;DAL> Airlines\nInc and Western Airlines &lt;WAL>, the Court said")
# ('.', 'He said the department considers the effect each merger\nwill have on competition over all the routes involved and will\nnot approve a merger which will reduce competition')
# ('.', 'Bere, who serves on the\nHughes board, is believed to favor the merger with Baker')
# ('.', "However, Moody's noted that the combined company would\nbenefit from cost reductions and consolidations made possible\nby the merger")
# ('.', "But Redstone turned the situation into a spirited bidding\ncontest which was capped by the announcement this morning that\nViacom's independent directors on behalf of Viacom entered into\na defintive merger agreement with National")
# ('.', 'Baker said today it would withdraw the one billion dlr\nlawsuit it had filed to force Hughes to follow through with the\nmerger')
# ('.', '"It\'s a merger of equals," said analyst John Rooney of\nMoseley Securities Corp')
# ('.', 'Canadian Airlines was recently\nformed through the merger of Canadian Pacific Airlines and\nPacific Western Airlines')
# ('.', 'The Japanese\nside is saying that the decision on such a plan should be left\nwith the new firm, after the merger')
# ('.', 'L> has\ncompleted its merger with Standard Oil Co of the U')
# ('.', "The merger is\nsubject to GGHF's receiving financing for the plan, Datron\nsaid")
# ('.', 'The Banco Pan de Azucar after being taken over by the\nBanco de la Republic in 1985 carried out a similar merger\noperation with the Banco de Italia')
# ('.', 'Members of the three exchanges have been consulted,\nAgricultural Futures Exchange secretary Bill Englebright told\nReuters, and no objections have been raised to the merger')
# ('.', '"I think the merger is not going through," said Phil Pace,\nanalyst at Kidder, Peabody and Co')

# %% [markdown]
# Using the strip helps to seperate a sentence in  a tuple

# %%
all_matches = []

for article in train_dataset:
    pattern = r'([.!?])\s*([^.!?]*?\bmerger\b[^.!?]*?)[.!?]'
    
    ### COMPLETE THE CODE HERE
    matches = re.findall(pattern, article['text'], re.IGNORECASE)
    
    if matches:
        # Extract only the sentence containing "merger" (second group in the tuple)
        all_matches.extend([match[1].strip() for match in matches])
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 530
# It said Quest Blood expects to complete the merger within
# the next several weeks
# The company said it will hold a special meeting on July 10
# for a vote on approval of a merger at the tender price
# Carroll also noted that since the merger accord was first
# signed "the outlook for the industry has improved materially
# It said its suit names as defendants Hughes and certain of
# its directors and seeks either an injunction forcing Hughes to
# live up to the merger agreement or "substantial" monetary
# damages it did not name
# Manufacturers Hanover Trust Co and CIT Group/Business
# Credit Inc increased its tender offer commitment to 197 mln
# dlrs from 166 mln dlrs and its merger commitment to 275 mln
# dlrs from 250 mln dlrs
# Closing of the merger would occur immediately after
# the filing, it said
# -- shares issued in connection with a merger, acquisition
# or recapitalization where the exchange of shares is accompanied
# by detailed proxy material
# The Baker-Hughes merger, which would would create a 1
# In a statement, the commission said Rover's &lt;Leyland
# Trucks> subsidiary would be financially and physically
# restructured following a recently announced merger between
# Leyland Trucks and &lt;DAF> of the Netherlands
# Quest also said its signed a merger agreement with &lt;Hunt
# Research Corp> and its affiliate &lt;ICAS Corp>
# Progressive is currently involved in a proposed merger with
# &lt;Rainbow Corp Ltd>
# Analyst Thaddeus Paluszek of Merrill Lynch and Co said
# Fleet's earnings would have been diluted about two pct in 1986
# on the basis of the merger terms announced today
# subsidiary has not achieved this ownership
# within one year after the completion of the merger, the
# subsidiary will have the right two years thereafter to request
# that HRI commence a rights offering to HRI stockholders, the
# company said
# 25 dlrs to 95 dlrs the amount per share paid in the
# merger of a Dixons subsidiary with Cyclops
# OII said the New York Stock Exchange said the securities
# will be delisted as a result of the merger
# It was the fourth federally-assisted merger or acquisition
# of a troubled savings institution this year, the FHLBB said
# 19 billion dlr merger with Chemical
# The merger following the tender offer will be subject to
# approval by ARGOSystems shareholders, the companies said
# Completion of the merger transaction is expected in three
# to four months
# 7 pct interest, and
# is the first step in a merger agreement that has been approved
# by the Purolator board
# Keycorp said the merger is expected to become effective as
# soon as possible after December 31, 1987, the date Utah's
# interstate banking law becomes operational
# ,
# will serve in that capacity for the new subsidiary resulting
# from the merger
# The company said also before the merger, San/Bar would
# Barry K
# Department of Justice consent decree that would
# require Baker to sell its drilling bit operations and
# submersible pump business, met yesterday and threatened to
# terminate the proposed merger
# However, the suggestion still recommended a merger between
# the two consortia tendering for contracts and would give Cable
# a five pct stake, more than the three pct originally proposed
# but less than the 20 pct it holds in its original venture, he
# said
# The Rainbow merger involves shareholders in
# both Rainbow and Progressive being issued shares in a new
# company, &lt;Astral Pacific Corp Ltd>, on a one-for-one basis
# O> approved
# the merger of the two companies
# It was "business as usual" yesterday at the American Motors
# headquarters, one day after the proposed merger was unveiled by
# Chrysler and AMC's French parent Renault, according to company
# spokesman Edd Snyder
# Based on its financial
# expectations, Fifth Third said the dilution in per share
# earnings for the merger will be negligible
# KPMG was created as part of the merger announced last
# September of Peat Marwick International Klynveld Main Goerdeler
# to form Klynveld Peat Marwick Goerdeler
# Under the merger agreement, remaining shareholders of
# Hayes, a Jackson, Mich
# Hoechst Celanese was formed Feb 27 by the merger of
# Celanese Corp and American Hoechst Corp
# The DOT had given tentative approval to the merger plan
# Feb
# 75 dlrs a
# share in connection with the merger with Hemdale, Computer
# Memories said
# 5
# mln dlrs and First City Bancorporation &lt;FBT>, which is actively
# seeking a merger or other form of new capital, lost 402
# department of justice, resolving the department's objections to
# their merger
# The merger would create the nation's second-longest railroad
# -Air-Piedmont Airlines merger would have on
# service, especially at Dayton, Ohio, a major Piedmont hub
# Great Western noted the conversion merger recently won the
# approval of 94 pct of SunPoint's members -- a group comprising
# the depositors and borrowers of that company
# American's merger with AirCal, announced last November,
# received final approval from the Department of Transportation
# yesterday
# A merger at the tender price is to follow the offer, which
# has been approved by the Harper and Row board
# If approved, the merger will add another 3
# However, the agency pointed out that the
# merger is a unique opportunity for RepublicBank to expand its
# already strong market position
# Discussions with NBC on the merger of the two companies'
# radio units were suspended in December
# Justice Department has announced that it will
# require divestiture of the product line for approval of the
# merger
# The letter from Gardner said he resigned the board because
# the merger agreement with Hutton barred directors from
# soliciting new offers and he believes shareholders might get a
# better deal
# Circuit Court of Appeals in San Francisco had
# blocked the merger until a dispute over union representation
# had been settled by arbitration
# He said if outside directors approve the management
# proposal, a merger plan could be put to a vote of shareholders
# with proxy material going out late this week
# She said KLM would like the two courier services to
# cooperate in future and did not exclude a future merger between
# them to combine IML's strong world-wide network with XP's
# mainly European activities
# The company also said it will no longer actively seek out
# potential merger partners, but will respond to serious
# inquiries
# The FDIC said it subsidized the merger of Central Bank and
# Trust Co, Glenmora, La
# "I think one of the things that has to be recognized in that
# merger is that it appears, at least, that a good portion of the
# ownership of American Motors, which has been in overseas hands
# will be put back in American hands," Meese told the
# subcommittee
# The
# ChemLawn board has approved the tender and a merger at the same
# price that is to follow
# Pennzoil said the merger
# violated a prior agreement it had to buy Getty and sued Texaco
# "It's silly not to take a look (at making a merger or
# acquisition)
# Interstate Commerce
# Commission (ICC) to reconsider its earlier rejection of the
# merger of the holding company's railroad assets, a company
# spokesman said
# BIL Chief Executive Paul Collins said last week that he
# opposes the Rainbow/Progressive merger because BIL sees
# Progressive shares as being worth twice as much as Rainbow's
# The
# offer, which has been approved by the Auxton board and is to be
# followed by a merger at the same price, is conditioned on
# receipt of a majority of Auxton's voting stock on a fully
# diluted basis
# The change affects 515 mln dlrs in debt and assumes a
# merger of the two companies will be completed
# The executive said the merger would not alter his target of
# maintaining sales and earnings growth of 30 pct to 35 pct
# The companies said they expect the merger will occur after
# the declaration of effectiveness of an amendment to Magellan's
# registration statement relating to its common stock purchase
# warrants and the underlying shares
# USAir said it has been advised by Norfolk Southern that the
# company supports the proposed merger and intends to tender all
# of its remaining 1,477,829 Piedmont common shares in response
# to USAir's tender offer which began today
# Emery said it had tried unsuccessfully to open merger
# discussions with Purolator before the company accepted the
# management-led buyout offer
# The two groups have also begun exploratory talks on a
# possible merger of the Holmes business with the compatible
# businesses of Wormald, comprising some or all of its fire
# protection and security businesses in the Americas and Europe,
# Wormald said in a statement
# Co &lt;CMCO> merger negotiations to determine the source of rumors
# that caused the stocks to rise prior to a public announcement
# in January
# The company said it is seriously considering the new offer
# but has also received an expression of interest for a possible
# merger into a Fortune 500 company it did not identify that will
# be investigated at meetings to be held later this week
# The Banco Pan de Azucar after being taken over by the
# Banco de la Republic in 1985 carried out a similar merger
# operation with the Banco de Italia
# senator said a corporate merger wave was harming the
# economy and blamed the Reagan administration for laxness in
# enforcing the federal antitrust laws
# Stressing that company growth would be internal, McGough
# told reporters "that our game plan does not call for an
# acquisition," saying Bache recently rejected merger overtures
# from three other investment dealers in Canada
# Under a previously announced merger agreement, Amsouth
# offered 66 dlrs a share in Amsouth stock for First Tuskaloosa
# Late yesterday, Hughes said it had terminated the merger
# agreement because Baker would not agree to an alternative
# divestiture plan devised by Hughes
# This week Hughes seemed to back out of the merger but then
# said it was still interested in talking
# "
#     BIL has said it is against the merger because it sees
# Progressive shares as being worth twice as as much as
# Rainbow's
# Wall Street analysts said the merger accord between Fleet
# and Albany, N
# "Our goal is for a merger to occur
# The merger involves the formation of a new company &lt;Astral
# Pacific Corp Ltd> which will acquire all shares in both
# companies on a one-for-one share exchange basis
# 50 dlr a
# share exercise price before the merger is effective, it said
# Redstone's newest plan raised the amount of interest he
# would pay on the cash portion of his offer for every day beyond
# April 30 that a merger with Arsenal is not consummated
# Airlines officials
# could not be reached for comment on the ruling, which halts the
# merger until arbitration on the dispute is completed
# While the banks have been approached by securities firms
# seeking merger partners, they have not yet bought into
# brokerages, choosing to build securities units from within
# The complaint said Vaskevitch leaked information about 12
# companies involved in a merger or acquisition which resulted in
# more than four mln dlrs in profit for himself and others
# involved in the scheme
# "The frenzy and disruption created by merger mania
# is particularly distressing
# "We have left the door open and GE is reassessing the
# merger and so are we," Westinghouse chairman Douglas Danforth
# told Reuters at the conclusion of a meeting before analysts
# 1985 results reflect only six mths of mining operations due
# to merger of Erickson Gold Mines Ltd and Total Eastcan
# Exploration Ltd on June 30, 1985
# , which seeks an
# injunction against Allegheny's proposed merger into Sunter
# We consider this to be a merger
# of equals
# Hoechst and Celanese completed their merger last month
# &lt;Brierley Investments Ltd>, which has been a frequent
# critic of the merger, launched a full bid for Progressive at
# 4
# DRS, a warfare systems producer, said it would make the
# transaction through a cash tender offer for all, but not less
# than 51 pct, of Rospatch's outstanding common stock followed by
# a merger with Rospatch, a labels, high technology and wood
# producer, at the same purchase price per share
# The company said its merger last year with Associated Dry
# Goods, which was accounted for as a pooling of interests, is
# "going very well
# Cable and Wireless has a 20 pct stake in one of the two
# companies involved in the mooted merger
# That merger was viewed by some analysts as reducing Rolm's
# independence and relegating it to a role as a manufacturing and
# product development site within IBM
# A merger at the tender price that has been
# approved by the ARGOSystems board is to follow the offer
# Metrobanc said the merger is still subject to regulatory
# approval
# The 1987 pro forma first quarter results include
# nonrecurring merger expenses of 4
# The exchange, they said, will be made on the effective date
# of the merger, which must be approved by both companies' boards
# and High Plains' shareholders
# Revlon said its board of directors unanimously approved the
# merger agreement
# "  The
# consolidation follows the merger of Foley's and Sanger Harris
# in January
# The merger would give American control of 37 pct of the
# authorized takeoff and landing slots at the Orange County
# terminal, where environmental concerns and a small terminal
# building limit future opportunities for expansion
# In order for the other carriers to come down to TWA's wage
# scale in a merger, TWA would have to be the surviving entity,
# analysts said
# 9 common shares each, valued at
# about 73 dlrs per share based on the average closing price of
# USAir common during a period just before the merger
# Under the merger, H
# The merger plan has been criticised for excluding foreign
# firms from a meaningful position in the market
# Her favorite is Baker International, which is involved in a
# possible merger with Hughes Tool Co
# The offer and withdrawal rights
# are to expire April Three unless extended, and the bid is to be
# followed by a merger at the same price
# The group has drafted its own merger guidelines to bring
# uniformity to the attorney generals' efforts to enforce the
# laws at the state level
# The Japanese
# side is saying that the decision on such a plan should be left
# with the new firm, after the merger
# 4 pct stake, have both
# agreed not to buy more shares of the company until a merger is
# completed, unless the purchases are part of a tender offer for
# at least half of the outstanding stock
# Hughes yesterday adjourned the special meeting at which
# shareholders were to vote on the merger without permitting the
# counting of votes on the deal
# A merger approved by the Allegheny board in which remaining
# common, preference and preferred shares would be acquired at
# the tender prices is to follow the offer
# The proposal is also subject to a due diligence review,
# execution of a merger agreement, arrangement of financing and
# receipt of government approvals, all of which Gabelli and Co
# said could be completed within 60 days
# textile maker focused
# on its own business as its competitors found merger partners,
# but now Burlington Industries Inc may have restructured itself
# into an attractive takeover candidate, analysts said
# Rexnord's 50 mln dlrs of 12-3/4 pct debentures of 1994 were
# cut to B from A-minus to reflect the merger with Banner
# Financial Corp, parent of American Savings and Loan
# Association, the nation's largest thrift, has repeatedly said
# it would give serious consideration to a merger as a means of
# rapidly improving its capital position
# In connection with the acquisition, shareholders will be
# requested to approval the merger of CarePlus into its newly
# formed Delaware subsidiary, CarePlus said
# Under a merger agreement entered into in November, Reuters
# tendered for up to 5
# 1986 net includes costs of 900,000 dlrs in quarter and
# 1,200,000 dlrs in year from proposed merger
# The union's sugar beet committee met yesterday to consider
# the implications of a government Monopolies and Merger
# Commission, MMC, report issued last week
# S and P cited the adjournment of a special shareholder
# meeting in which Hughes objected to certain conditions for the
# merger of the companies set by the U
# "We simply regard Progressive Enterprises shares to be worth
# approximately twice as much as Rainbow shares and do not think
# the merger, as proposed, is soundly based," BIL chief executive
# Paul Collins said in an interview in the weekly National
# Business Review newspaper published today
# The companies said the proposed merger would bring together
# businesses that were largely complementary
# " But he
# expressed skepticism that this will necessarily lead to
# heightened merger or buyout activity in the oil group
# Earlier this month the group said that tentative merger
# talks with the high street pharmacist &lt;Underwoods Plc> had been
# called off and recently announced a 19
# But a merger of the two deposit-insurance agencies could be
# an option as part of a general structural reform of the U
# CBC said the merger will not affect Citizens Banks' name,
# management, board of directors or employees
# In an attempt to hammer out an agreement, Solomon today met
# Fumio Watanabe, the senior Keidanren officer trying to arrange
# the merger
# Valhi said these results were prepared as if the merger had
# occurred July 1, 1986, and on substantially the same basis as
# the pro-forma financial information in LLC's and Amalgamated's
# joint proxy statement dated February 10
# Peripheral said its increased involvement in the
# development of Nucell's nuclear battery technology made the
# merger practical
# The new offer, the second sweetened deal Redstone has
# proposed in his month-long bidding war with management, also
# contains newly drawn up proposed merger documents, he said
# Entertainment Marketing, a Houston-based firm involved in
# electronics wholesaling and televised home shopping sales,
# proposed an eight dlr a share merger acquisition of Crazy Eddie
# on May 29, and modified the proposal on June 9 to include the
# possible participation of Crazy Eddie management
# For Computer Associates, the merger with Uccel caps a
# six-year acquisition campaign that has vaulted the Garden City,
# N
# Advanced said it had suspended merger talks with other
# parties as a result of the exclusivity agreement
# Members of the three exchanges have been consulted,
# Agricultural Futures Exchange secretary Bill Englebright told
# Reuters, and no objections have been raised to the merger
# Both boards have approved the merger
# USAir said it requested the dismissal because TWA avoided
# pre-merger notification requirements, and also did not provide
# a competitive and public interest analysis required under
# regulations
# "We think that
# in the third or fourth quarter after the merger we should see
# something close to breakeven," he said
# The Appeals Court ruling surprised officials of
# Atlanta-based Delta, which had been preparing for the merger
# for months and had already painted Delta logos on airplanes
# belonging to Western, which has headquartera in Los Angeles
# The merger agreement was announced earlier this week
# It said it would leave open a range of options regarding
# the debentures, including buying more, selling some or all of
# their current stake in the market or in negotiated deals,
# talking with other Harcourt security holders, surrendering the
# debentures if there were a merger or tender offer or converting
# them into stock
# Charter said the merger is subject to approval of the
# Federal Home Loan Bank Board
# Appeals court last night
# blocked the 860 mln dlr merger of Delta Airlines Inc &lt;DAL
# He said that merging Southern with Kansas City will achieve
# the benefits of an end-to-end merger while preseving the
# independece of the Southern Pacific versus its existing prime
# competitor, Santa Fe
# The company said Maryland Alliance wanted the merger
# blocked on the grounds that NCNB inadequately served the credit
# and financial needs of low-income and minority communities in
# its markets
# The merger was approved following completion on Jan 27 of a
# tender offer valued at approximately 55 mln dlrs, the company
# said
# She noted that Chrysler Corp's &lt;C> announcement of a merger
# proposal for American Motors Corp &lt;AMO> should have no short
# term effect on Ford but could cut into Ford's share of the
# truck market in the long term
# Stevens &lt;STN> climbed 5/8 to 44-7/8, and Fieldcrest
# Cannon Inc &lt;FLD>, the result of a merger of Fieldcrest and
# Cannon, rose 1-1/8 to 39-3/4
# ST> said the group to be
# formed by its merger with Switzerland's BBC AG Brown Boveri und
# Cie &lt;BBCZ
# The
# company said a merger of Rexnord and a subsidiary of Banner
# will be completed before mid-May
# The investment company said after the merger the combined
# company will have 15 mln shares outstanding
# However, Moody's noted that the combined company would
# benefit from cost reductions and consolidations made possible
# by the merger
# "If you look at the whole merger mania, and look at the
# scale some of these dealers, it's going to be very hard to
# resist taking them public," said another analyst
# Santa Fe Southern Pacific owns the Santa Fe railroad and
# holds the Southern Pacific railroad assets in trust while
# awaiting federal approval of the merger plan
# Comdata said WCAS and its affiliate investors would commit
# 50 mln dlrs to buy the securities comprising the new entities
# units of securities resulting from the merger in the same
# proportions and at the same price as the company shareholders
# Shearson said Stearns formerly was part of Merrill Lynch
# Pierce, Fenner and Smith Inc's &lt;MER> merger and acquisitions
# department
# It added that the B-3 rating recognizes operating
# efficiencies that will result from the merger
# The Post and Telecommunications Ministry has urged the
# merger of the two firms because it says the market can only
# support a single KDD competitor
# Justice's opposition to quick federal approval of a bid by
# Greyhound Lines Inc to take immediate control Trailways Corp
# prompted Greyhound to threaten -- in a brief filed with the
# Interstate Commerce Commission (ICC) -- to drop the merger
# plan
# Mattson also declined to comment on whether the directors
# of Baker and Hughes have scheduled any meetings to discuss the
# merger
# Their merger would not
# alter American's third-place ranking, according to data
# compiled by Aviation Daily, a leading industry trade magazine
# The company said if the merger agreement is terminated
# under certain circumstasnces, it will be entitled to receive 20
# mln dlrs in damages from ChemLawn
# The acquisition would be a cash merger, with Progressive
# shareholders receiving up to three dlrs per share, the company
# said
# S and P cited the completion of the firm's merger with PNC
# Financial Corp &lt;PNCF>, saying PNC has shown solid earnings,
# excellent liquidity and a conservative capital position
# The companies said with the merger Nolan now will be known
# as Nolan, Norton and Co-partners, the information technology
# arm of Peat Marwick
# Has also attacked the original merger plans,
# saying that both rival consortia should be licensed
# Cable and Wireless Director of Corporate Strategy, Jonathan
# Solomon, yesterday again told ministry officials he opposes a
# merger proposal that would limit Cable and Wireless' share to
# less than three pct and total foreign participation to about 20
# pct, the ministry official said
# Gardner noted that the terms of the merger agreement in
# which the company would bought out by a group of its managers
# and E
# 53 billion
# dlrs in damages from Texaco in connection with Pennzoil's
# proposed merger with Getty Oil Co, which was later taken over
# by Texaco
# The company said it will
# treat the merger as a pooling of interests
# "We're working very hard on this merger
# Hughes said it proposed to Baker that the companies ask the
# Justice Department to allow them to proceed with the merger on
# condition that they find a buyer approved by the  Department
# for the domestic oilfield tricine rock bit assets of Baker's
# Reed subsidiary, its Singapore plant and Baker Lift's domestic
# electrical submersible pump business by April 22, the last date
# the merger of Baker and Hughes could occur under their
# agreement
# 5
# pct of Harper and Row, had offered to discuss a merger with
# Harper and Row
# Figures for last
# year are unavailable as the bank was formed in June this year
# after a merger of two Dallas-based banks, RepublicBank Corp and
# InterFirst Corp
# "Following announcement of the merger agreement, the company
# was informed by the Enforcement Division of the (SEC) that it
# intends to seek authority from the commission to institute a
# proceeding against the company," Allegheny said
# Senate committee, Commerce Secretary Malcolm
# Baldrige and Trade Representative Clayton Yeutter have also
# expressed opposition to the merger, he said
# The financial terms of the merger are unchanged, a Hughes
# spokesman said
# Baker said today it would withdraw the one billion dlr
# lawsuit it had filed to force Hughes to follow through with the
# merger
# Local time (1600 GMT) to discuss the proposed merger
# And European firms will be
# falling prey to Japanese corporations bulging with cash and
# eager to extend their reach further overseas, according to
# merger and acquisitions specialists polled by Reuters
# Paues said the merger was a direct result of the sharp fall
# in oil prices 18 months ago which led oil firms to cut back
# exploration activities
# Allied legal advisor and director George Kern, who heads
# the merger and acquisitions group at the New York law firm of
# Sullivan and Cromwell, decided against amending Allied's SEC
# filing to disclose the talks even though they had resulted in
# sales price of 405 mln dlrs for the shopping centers, it said
# "
#     Narragansett said the offer is subject to negotiation of a
# definitive merger agreement and definitive financing agreements
# as well as approval by regulators, Taft's board and Taft's
# stockholders
# 89 dlrs
#     net loss 309,100,000
#     NOTE: No comparisons because company was formed in June
# 1987 through merger of RepublicBank Corp and Interfirst Corp
# The ruling came in a lawsuit in which the Air Transport
# Employees union said Western's management should fulfil a
# promise to honour union contracts if a merger took place
# The Justice Department in January said it would block the
# Hughes and Baker merger on anti-trust grounds unless both
# companies agreed to sign a consent decree that would provide
# for the sale of the assets after the merger took place
# Pay N' Pak said the second proposal is structured as a
# merger in which each holder would receive a combination of
# 17
# Yesterday Citicorp &lt;CCI>, with Audio/Video Affiliates
# Inc &lt;AVA> an owner of CYACQ, said it had offered to acquire
# from Dixons after the merger of Cyclops into Dixons Cyclops'
# industrial businesses for 12
# Mattson told Reuters that Baker still believed a merger was
# possible between the two giant oilfield service companies
# Emery said Purolator would operate as a wholly owned unit
# of the company after the merger
# According to a copy of Perelman's letter released by
# Gillette, he would be prepared to sign a defnitive merger
# agreement without any financing condition
# 6 pct of Modulaire's common
# stock that could be voted in favor of the merger
# In the merger, holders of remaining Instinet shares will
# receive 8
# United Security said it is anticipated that
# such stock would represent a substantial majority of the shares
# outstanding after the merger
# It said the shareholders had called for the resignation of
# all but one of Computer Identics' directors and suggested that
# a new board pursue merger talks with Imtec
# TWA also agreed that it would not knowingly and willingly
# interfere with the consummation of the merger between USAir and
# Piedmont Aviation Inc &lt;PIE>
# REPH's board has appointed a special committee to negotiate
# terms of the proposed merger, Pesch said
# It called for limiting variations of equal voting rights to
# situations involving complete disclosure such as -
#     (1) shares in a registerd public offering where all facts
# connected with the company's capital structure are clearly
# spelled out in the prospectus and -
#     (2) shares issued in connection with a merger, acquisition
# or recapitalization where the exchange of shares is accompanied
# by detailed proxy material
# ANova said it created Duvel to act as a blind pool and will
# seek an operating private company to merger with Duvel
# Baker International has proposed a merger with Hughes Tool
# which could create a 1
# "
#     Weber added that Contel is holding discussions with
# &lt;Comsat> on an agreement to terminate the previosuly proposed
# merger between the two companies
# Under the agreement, Greyhound will acquire, in a merger,
# three of the company's foodservice operations - Dobbs
# International Services, Dobbs Houses and Carson international
# banking merger, can be completed by the beginning
# of 1988, according to an executive of Fleet
# 50 dlrs on NASDAQ,
# while Pizza Inn's stock was quoted at 12 dlrs when the Amex
# halted trading pending the announcement of the proposed merger
# The ministry's stance has outraged both London, which has
# threatened to retaliate, and Washington, which says the merger
# plan is evidence of Japan's failure to honour pledges to open
# its telecommunications market
# Analysts said the merger is virtually certain to go ahead
# News Corp said if the merger agreement were terminated
# under certain circumstances, News would be entitled to a 16 mln
# dlr cash payment
# But it left open that it might make other changes in
# GenCorp's operations after it completes the merger
# Kistler estimated that the merger, which should be
# completed in about two weeks, will result in annual cost
# savings of about 50 mln dlrs
# Opposition
# to the planned merger of two rival firms seeking to compete
# with the current monopoly &lt;Kokusai Denwa Denshin Co Ltd>, and
# to reduce the share held in any KDD rival by U
# He said the tender would be the first step in acquiring all
# of Caesars' shares and if successful would be followed by a
# merger transaction
# After the merger, Viacom will be a subsidiary of National
# but 17 pct of the company will be in public hands
# Note - Company was created in May 1986 by the merger of
# (Royale Belge Vie-Accidents) and (Royale Belge
# Incendie-Reassurance)
# Rosenfeld joined Salomon in 1979 and has been a member of
# Salomon Brothers' merger and acquisitions group
# The company said its board recommended that shareholders
# approve the merger of the oilfield service companies
# Genetic Laboratories said one of the reasons for the move
# was to "facilitate the sale or merger" of the business "with
# other companies specializing in plastic surgery
# "It's a merger of equals," said analyst John Rooney of
# Moseley Securities Corp
# The transaction is conditioned on  Allied's pending merger
# with the Vons Cos Inc
# S and P said the reviews reflect its perception of the
# implications of a proposed merger involving the two firms
# Earlier this year, Williams suggested holding talks with
# Norcros on a possible merger but was rebuffed by Norcros which
# replied that any benefits that could be achieved could also
# result from normal trading
# The rating agency cited USAir Group's proposed acquisition
# of Piedmont Aviation Inc &lt;PIE>, as well as Trans World Airlines
# Inc's &lt;TWA> proposed cash merger with USAir
# Last night, Hughes said the planned merger with Baker was
# off
# , has approved a
# merger into CB and T for an undisclosed amount of stock,
# subject to approval by regulatory agencies and Carrolton
# shareholders
# Yesterday Citicorp &lt;CCI>, with Audio/Video Affiliates Inc
# &lt;AVA> an owner of CYACQ, said it had offered to acquire from
# Dixons after the merger of Cyclops into Dixons, Cyclops'
# industrial businesses for 12
# Upon clearance of the revised proxy
# statement by the commission and its distribution to Staff
# Builders' shareholders, that company's management will continue
# to solicit proxies for approval of the merger
# A Norstar spokesman said that a press release containing
# further details on the merger would be issued shortly
# Depending on its evaluation of the company, including
# actions by Crazy Eddie's board and any possible third party
# bids for the company, Entertainment Marketing and its president
# said they may hold their present stake in the company, sell
# some of their shares, or purchase more shares on the open
# market, through private purchases or in connection with a
# merger or tender offer
# In response, Emery said it would renew its request for
# a merger with the Basking Ridge, N
# The boards of both companies have approved the merger,
# which will be accomplished through a tender offer by a Boeing
# subsidiary of 37 dlrs a share cash for all of ARGOSystems'
# shares, the companies said
# 978825 shares of Amsouth stock for each First Tuskaloosa
# share held when the merger is effected April 17
# TWA said it is filing an application with the Department of
# Transportation seeking approval of the merger as well as an
# application for approval, on an expedited basis, of its
# purchase of up to 51 pct of USAir common and the deposit of the
# stock in a voting trust, pending DOT approval
# O>
# in a merger agreement
# If it buys more shares, Metropolitan
# said it would consider doing so in the open market, in private
# deals, or through an exchange offer, tender offer or merger
# In a newspaper advertisement, the company said the offer,
# which has been approved by the BPI board and is to be followed
# by a merger at the same price, is conditioned on receipt of at
# least 1,813,742 shares
# The company said Penn Traffic is expected to hold a special
# shareholders' meeting later this month to approve a merger into
# Miller Tabak at the tender price
# The company said if the merger is approved by shareholders
# of both companies, the shareholders of John Paul Richards would
# become majority shareholders, owning 60 pct of the common
# stock, of the new public company
# "
#     Gallo said FCS will stop actively seeking potential merger
# partners, but will respond to serious inquiries
# The company said its previously-announced merger into
# Inspectorate is still subject to approval by Network
# shareholders
# Baker said the new terms that Hughes proposed for the
# merger, as an alternative to the consent decree, were "more
# burdensome" than those of the consent decree themselves
# "
#     Kistler also said that the law suit filed by Baker "was not
# a factor" in the board's decision to keep its merger proposal
# on the table
# The deal is subject to completion of a definitive merger
# agreement, receipt of third party approvals and other
# conditions, the company said
# The analysts said Sumitomo will have to devote a lot of
# time to digesting its most recent initiatives, including the
# merger with ailing Heiwa Sogo
# Industries said it would
# be willing to start a cash tender for Clevite's shares within
# five days after agreeing upon a definitive merger and
# confirmation of Clevite's financial results and condition
# The company also said it was advised that Dixons'
# shareholders approved the merger, satisfying that condition of
# the agreement
# Moody's said the merger should strengthen the bank's
# earnings potential through the acquired access to PNC's product
# lines
# T> is certain to
# lose its status as Japan's most profitable bank as a result of
# its merger with the Heiwa Sogo Bank, financial analysts said
# Under the terms of the merger, Dixons said the remaining
# public Cyclops shareholders are to receive 95 dlrs a share
# He said the department considers the effect each merger
# will have on competition over all the routes involved and will
# not approve a merger which will reduce competition
# "Schlumberger's management shift, asset restructuring,
# including a pending merger of Fairchild Semiconductor, and its
# considerable cash horde sets the stage for the company to
# maximize its significant industry advantage and capitalize on
# the project upturn in exploration and development activity,"
# according to a report by George Gaspar, first vice president at
# Robert W
# Redstone said the management group's investment bankers
# will be paid what is due for termination of its merger
# agreement
# The company said its merger agreement with Piedmont
# provides that the offer is not to be amended without Piedmont's
# prior written consent in any way that would be adverse to
# Piedmont shareholders, but it said it could cut the number of
# shares to be bought without Piedmont's consent
# TWA said the agreement does not prevent it from commenting to
# regulatory agencies on the USAir, Piedmont merger
# One of the deals in which an insider profit was alleged was
# the 1984 merger of K-Mart Corp &lt;KM> with &lt;Pay Less Drug
# Stores>
# OII said each common share still outstanding at the time of
# the merger has been converted into the right to receive 60
# The
# American Service board has approved the offer, which is to be
# followed by a merger at the same price
# Independence
# said the merger will be accounted for as a pooling of
# interests
# In its offer, TWA said as an alternative to a merger with
# USAir, it would be interested in discussing a three-way
# combination among USAir, Piedmont and TWA
# Under terms of the merger agreement, Chatsworth said
# Lotoquik shareholders would own a majority of the surviving
# company
# 2 pct of the total, and left open
# the possibility that it might acquire more through a merger
# But Redstone turned the situation into a spirited bidding
# contest which was capped by the announcement this morning that
# Viacom's independent directors on behalf of Viacom entered into
# a defintive merger agreement with National
# Ward said it was his idea to have a merger agreement with
# Distillers under which Distillers agreed to pay Guinness's bid
# costs, the PA reported
# "I think the merger is not going through," said Phil Pace,
# analyst at Kidder, Peabody and Co
# But a Cable spokesman said it still believed a merger of
# the two consortia would be impracticable
# The group is currently looking for a possible partner after
# a merger with &lt;Scovill Inc> of the U
# In a filing with the Securities and Exchange Commission,
# Merrill Lynch Capital Partners Inc said it would receive a 30
# mln dlr fee from the surviving company for acting as dealer
# manager of the merger after the Borg-Warner deal is completed
# Meese told the House Appropriations Subcommittee that
# consideration would be part of the Justice Department's review
# of the proposed merger
# First City, the big Texas bank hit hardest by the downturn
# in oil prices, lost a record 402 mln dlrs in fiscal year 1986
# and has said it is seeking a merger partner or some other
# capital assistance
# The merger of Rexnord with a subsidiary of Banner will be
# copmleted before mid-May, the company said
# The merger will be effective June 1, coinciding with the
# retirement of Utah International chairman and chief executive
# Bud Wilson, BHP said in a statement
# industries; any differences are not
# significant for the purpose of merger analysis," Andewelt said
# He said that while the merger will initially reduce
# Sumitomo's profitability and efficiency, it will vastly expand
# Sumitomo's branch network in the Tokyo metropolitan area where
# it has been relatively weak
# The company, a maker of mobile homes, said it terminated
# merger discussions with &lt;Nursing Centers of America>
# It added that the lawsuit will not affect the negotiations
# on the merger transaction with Bristol-Meyers Co &lt;BMY>,
# announced Monday
# He said a merger would significantly enhance the financial
# turnaround that Purolator's management had previously forecast
# Securities and
# Exchange Commission to complete its review of the filing of
# merger proxy materials, which Instinet expects to make before
# the end of March
# A statement by Williams said it was confident of the merits
# of the proposed merger and it had therefore taken care to
# propose from the outset the right terms, including a full cash
# alternative
# The directors of Baker immediately after receiving the
# counter proposal filed a law suit in Texas in a Texas state
# court to force to Hughes to complete the merger
# At midday today Hughes said
# it was still interested in the merger
# Britain opposes the proposed merger
# The interest rate to be used to increase the cash value of the
# merger, if delayed beyond April 30, was raised to nine pct from
# eight pct and 12 pct after May 31
# As a result of the merger, the former shareholders of
# Scan-Graphics will become the majority shareholders of Captive
# Venture Capital
# The following results reflect the
# operations of the companies prior to the merger
# "Texaco has consistently maintained that Pennzoil did not
# have a binding contract to Buy Getty Oil shares, since a press
# release announced only an 'agreement in principle' which was
# 'subject to the execution of a definitive merger agreement',"
# according to Gayle
# District Court for the Southern District of New York denied the
# motion of &lt;Carsey-Werner Co> for a temporary injunction to
# block the proposed merger of Viacom with a subsidiary of
# &lt;National Amusements Inc>
# 25 dlrs each,
# exercisable if it should fail to meet any condition connected
# with the transaction or if principal shareholders should accept
# a merger offer from another party
# The merger is to be made by Onyx buying LASMO Exploration,
# in a share swap
# There was no comparable figure for the third quarter of
# 1986 because the company was formed in June 1987 through the
# merger of RepublicBank Corp and Interfirst Corp
# "
#     Metzenbaum said Icahn had failed to file a pre-merger
# notification form with the FTC prior to purchasing more than 15
# mln dlrs' worth of USAir stock
# It had also proposed
# a takeover of USAir, which at the time was negotiating its
# proposed merger with Piedmont Aviation Inc
# Two airlines, Sabena and Scandinavian Airlines System
# (SAS), are now discussing a merger
# Bradt was referring to a merger among the four exchanges at
# the Commodity Exchange Center, an idea that has been discussed
# intermittently for several years
# With completion of the merger, Shefra changed its name to
# Flyfaire International Inc
# 50 dlr a
# share takeover proposal last September, but subsequent merger
# talks broke down in October
# American Motors said it received a letter from Chrysler
# Corp "advising us of their proposal to enter into a merger
# transaction with American Motors Corp
# Resorts said the offer from KSZ calls for a merger of
# Resorts with RI Acquisition Co Inc, a newly formed Delaware
# corporation
# Analysts said the merger would dilute the holdings of
# current Computer Associates shareholders by about 10 pct
# Earlier this week, ChemLawn agreed to accept a merger
# proposal at 36
# 69 billion
#     NOTE: figures reflect the merger of Sea-Land Corp completed
# Feb 11, 1987
# The company said the start of the tender offer and the
# calling of the special meeting are conditions of the
# settlement, and completion of the tender and merger are
# conditioned on final approval of the settlement
# for the year 1986, the provisions for mergers and
# restructuring expenses brought non-recurring expenses to
# 40,292,000 before tax gains, of which 8,863,000 represented
# merger costs and 31,429,000 related to restructuring of the
# combine operations
# He said the company had exceeded its goal of cutting costs
# by 150 mln dlrs in the first year after the merger, and reduced
# debt by nearly two billion dlrs, more than the originally
# expected 1
# The meeting would also be asked to approve a merger of two
# Italian subsidiaries, &lt;CM Italia Spa> and &lt;Societa
# Amministrazioni Turistiche Srl>
# The merger is
# subject to GGHF's receiving financing for the plan, Datron
# said
# The company said the merger will be accounted for as a
# corporate reorganization and be recorded at historical book
# values
# The suit also seeks to block a provision in the merger
# agreement for Dome to sell to Amoco its Primrose, Alberta,
# heavy oil properties for 79 mln dlrs if the takeover is not
# completed
# Comdata said in the merger each share of the company's
# stock would be converted at the holders election into either 15
# dlrs in cash or a combination of 10 dlrs in cash and a unit of
# securities including common stock
# Robins Co said its board
# has concluded that the merger proposal submitted by Rorer Group
# Inc &lt;ROR> merits further consideration
# The company said it expects to complete the
# merger by June 17
# Analysts said they foresaw no major complications that
# would abort a combination which historians said would be the
# auto industry's biggest merger since American Motors was formed
# in 1954
# The merger will provide an
# opportunity for expansion in an area with favorable economic
# trends, although it will lower trading margins by more than
# Sainsbury's historic levels, S and P pointed out
# He said he
# believes such a merger could create a stronger force in the
# tire industry
# The company said a definitive merger agreement is expected
# to be negotiated within six weeks and shareholders are expected
# to vote on the deal at a meeting expected to be held in June or
# July
# But for flexibility purposes, Merrill Lynch said it is
# considering redistributing Borg-Warner's assets to a number of
# subsdiaries of an entity it created to carry out the merger
# When the merger is completed, each of the 50,000 shares of
# the Bank of Sissonville common stock outstanding will be
# converted into 2
# Chrysler, which bought Gulfstream Aerospace Corp in 1985,
# earlier said Electrospace agreed to be acquired in a friendly
# merger for about 367 mln dlrs
# "I don't think that a merger would solve regulatory
# problems," CFTC chairman Susan Phillips told the House
# Subcommittee on Conservation, Credit and Rural Development
# Allied's first disclosure of the DeBartolo takeover was
# made on Oct 8, even though its board approved the merger on Oct
# 3 and the merger agreement was executed on Oct 7, the complaint
# said
# Under a previously announced merger agreement, each share
# of Second National's common stock will be converted into 25
# shares of Union National common
# Interstate Commerce Commission
# to reconsider its earlier rejection of the merger of the
# holding company's railroad assets
# A Chemlawn spokesman said further details on the merger
# would be issued later
# Boston Five said the planned merger with Newworld Bank for
# Savings Will create the largest savings bank in Massachusetts
# and the third largest in New England with combined assets of
# 3
# Industrial Equity (Pacific) added it is considering
# launching a tender offer for Calmat stock or making a merger
# proposal to the company, but said it has not decided whether it
# will pursue a Calmat acquisition on a non-negotiated basis
# Hutton added that PC Acquisition also terminated its merger
# agreement with Purolator
# "It's a very complex transaction, but basically what
# happens is they ostensibly put up money but the fees recapture
# any investment they might have once the merger takes place,"
# Gardner said
# The merger is subject to approval by the companies' boards
# and shareholders and agreement of certain Strata creditors,
# among other things, said the companies
# The agency cited Western Air's merger with Delta and
# Delta's assumption of Western's debt
# "
#     Comsat, created by a 1962 act of Congress, and Contel, a
# corporation of local telephone and communications firms, filed
# with the Federal Communications Commission last November 3 an
# application for merger
# L> Plc said it has no
# intention of proceeding any further with talks on Williams
# Holdings Plc's suggestion that there would be benefits arising
# from a merger between the two groups
# Hutton said in the merger shareholders would get 46 mln
# dlrs aggregate amount of guaranteed debentures due 2002 of PC
# Acquisition and warrants to buy 15 pct of the common stock of
# the PC courier subsidiary
# Watanabe said progress was being made towards a merger
# agreement and added that Japanese industry agreed with the
# government on having only one private consortium as two
# companies might invest "excessive" amounts
# A Norfolk Southern Corp &lt;NSC> spokesman said the company
# had no comment on TWA's offer for USAir or on its proposal to
# negotiate a three-way merger between TWA, USAir and Piedmont
# Under the merger's terms, Strata shareholders will receive
# 5
# Under the terms of the merger, each Liebert shareholder
# will receive
# Automaker, has said the
# merger is motivated principally by its desire to acquire AMC's
# profitable Jeep business and dealers, as well as a new modern
# car assembly plant in Bramalea, Ontario
# "The Transportation Department's antitrust enforcement has
# been disastrous, permitting rampant merger mania," Ohio
# Democrat Howard Metzenbaum said in a statement
# "
#     The ruling in San Francisco came in a lawsuit that had been
# filed in a Los Angeles federal court in which the Air Transport
# Employees union sought to force Western's management to fulfill
# ...
# the new company, Conagra said
# The merger is expected to close on April 22
# Such a merger would be complex and analysts said it would
# result in an airline iwth an 18 pct market share
# Canadian Airlines was recently
# formed through the merger of Canadian Pacific Airlines and
# Pacific Western Airlines
# IDC said the merger agreement also provides for payment of
# an equivalent amount in respect of employee stock options to be
# cancelled in the merger
# The rating agency said the actions reflected the firm's
# merger with what it termed a stronger Maryland National Corp,
# as well as American's improving performance
# Following a meeting yesterday with Borg-Warner officials
# and investment bankers, GAF said, it is today delivering a
# letter to the Borg-Warner board outling the terms of the
# proposal that would be made by tender offer, pursuant to a
# mutually acceptable merger agreement to be approved by the
# Borg-Warner board and conditioned on that board's
# recommendation of the tender offer and merger
# If the merger is approved by
# regulatory agencies and stockholders, it would create the 12th
# largest bank holding company in the United States
# Sorg said the group also agreed to vote as a body on any
# proposed merger or election of directors
# The BIFFEX board is expected to reach a decision on the
# merger at its meeting at the end of this month, after members
# are consulted at a meeting on March 16
# The ADS's will be valued at the average of their closing
# prices in the 10 trading days before the effective date of the
# merger
# FCS said merger
# negotiations with this other company have been continuing since
# late August
# Pearson, coordinator of the
# airline's merger activities, will become chairman and chief
# executive officer of AirCal during the period up to completion
# of the merger
# Earlier today, Hughes adjourned a shareholders meeting
# called to vote on the proposed merger until March 11 and said
# it hoped to resume negotitations with Baker
# 1 pct of the
# outstanding shares will be required to approve the merger,
# Tender Loving Care said
# Bastian said alternatives being considered include an
# attempt to acquire Cosmo through a merger, tender or exchange
# offer, seeking to influence the company's management and
# policies, and seeking representation on Cosmo's board of
# directors through a proxy contest or otherwise
# The DOT said the merger was unlikely to substantially
# reduce competition on the four routes on which both carriers
# provide either nonstop or single-plane service
# Mark IV said it also agreed at the meeting that if it
# decides to seek control of Baird, it would be through a
# negotiated merger or business combination or through a tender
# offer in which Baird would have at least 24 hours notice
# The Hughes board last week indicated that it might cancel
# the merger because of the Department of Justice requirement
# Analysts said such a merger would be costly and
# complicated
# Still, he has succeeded in holding up a merger of two
# airlines - both of which analysts said would fit well with TWA
# Earlier this year, a Texas court of appeals upheld
# Pennzoil's claim against Texaco, ruling that Texaco unlawfully
# interfered with Pennzoil's merger agreement with Getty Oil
# The spokesman said agency action on the proposed merger
# application could take as long as six months
# Hanson said that promptly following the filing of the
# certificate of merger Kaiser Cement common shares will be
# delisted from the New York Stock Exchange
# Modulaire has scheduled a special shareholders meeting for
# July 15 to vote on the merger
# It said the junior subordinated debentures to be issued in
# the subsequent merger will carry a 13 pct annual interest rate,
# payable twice a year
# As announced February 26, the Staff Builders shareholders
# meeting to vote on the merger, originally convened and
# adjourned December 23, will be reconvened on April 22
# Sosnoff said under the merger that would follow his tender,
# each of the 2,750,000 Caesars shares not covered by the offer,
# or 7
# GAF said it would make a tender
# offer following a merger agreement approved by the Borg-WArner
# board and conditioned on the board's recommendation of the
# tender offer and merger
# This is because an SAS-Sabena merger could be a test case
# to determine whether countries are willing to allow landing
# rights to be transferred from one carrier to another, he said
# Kistler
# said its counter proposal to merge with Baker International
# Corp was still under consideration and that a merger was in the
# best interests of both companies
# 6
#     NOTE: 1986 first quarter profits restated down one cent a
# share as a result of previously reported pooling of interests
# merger with Mid-Continent Life Insurance Co
# The company said the shares are being offered in connection
# with the conversion of SunPoint Savings Bank FSB of Lake Worth
# Fla to stock from mutual form and its simultaneous merger into
# Great Western Bank, a federal savings bank owned by Great
# Western Financial
# Moody's said it is also examining
# the potential use of the airline's borrowing capacity to
# finance the merger
# " The stock has risen more on merger speculation
# than on fundamentals, the opinion continued
# The merger of Uccel and Computer Associates combines the
# two biggest systems utilities suppliers other than IBM
# Moody's cited Fleet's announced merger with Norstar Bancorp
# Inc &lt;NOR>
# TWA said the merger is subject to the USAir board redeeming
# the preferred stock purchase rights (the poison pill) issued to
# shareholders last year and taking action so that the vote of a
# majority of the outstanding common stock is required to approve
# its proposed move
# Bere, who serves on the
# Hughes board, is believed to favor the merger with Baker
# Fumio Watanabe, a senior Keidanren (a leading business
# organization) official who has been trying to arrange the
# merger, will present a new outline of his proposal on Thursday,
# the ministry official said
# Vernitron said that it currently expects the special
# shareholder meeting concerning the merger will be held in
# August
# in an attempt to block the merger
# 1987 results reflect the TBS merger agreement and operations of
# the company as independent agent
# Moody's said the anticipated merger of Baker and Hughes
# Tool into Baker Hughes Inc would result in increased financial
# leverage at a time of weak demand for the combined company's
# products and services
# Suggesting that the total cost of completing the merger
# would be 190 mln dlrs, Cross said he would use 20 mln dlrs of
# his own money for the deal and up to 170 mln dlrs which would
# be borrowed from the First National Bank of Boston under a
# revolving credit facility the bank has agreed to provide
# If the merger is approved, common stock still outstanding
# will be converted into the right to receive 61
# The merger is effective April one and is subject to
# shareholder approval
# 86 dlrs per share on exchange of common of Pan America
# Banks Inc for common of NCNB Corp purusant to a merger of the
# companies
# BIL opposes the Rainbow merger and
# analysts say BIL needs a 25 pct stake in Progressive to prevent
# it occurring
# Terms of the merger called for each share of Arrays to be
# exchange for a share of Haba in a transaction valued at 4
# 19 billion dlr merger
# After Rorer announced its second bid for the company last
# Thursday, analysts forecast that the Robins family, which holds
# control of the company, would vigourously oppose any merger
# Hutton Group Inc EFH under
# which Hutton will terminate its merger agreement with Purolator
# Courier Corp and its pending 35-dlr-per-share tender offer,
# effective April 13
# It also said shareholders approved the merger of Morning
# Star Mine interests held by six corporations in exchange for
# issuing 2,098,602 shares of its common
# The merger is
# subject to court approval of the settlement as well as to other
# conditions
# That
# meeting was called to act on a merger agreement calling for a
# buyout by BCW Acquisitions Inc
# Pantera's also said it retained Drexel Burnham Lambert Inc
# to act as its financial advisor in connection with the merger
# The rating adjustments are based on the likelihood that the
# proposed merger of the two Texas banks will be consummated
# "
#     Under the merger terms, announced Nov
# But no decision has been made on
# whether or how to proceed with a merger attempt, he added
# 5 mln
# dlrs in costs mainly associated with an unsuccessful merger
# attempt
# Following the merger, Balzac shareholders will hold 80 pct
# of the outstanding stock of Magellan, the company said
# As a result of the merger, Borg-Warner will become a wholly
# owned subsidiary of AV Holdings
# The merger plan was announced in a midday news release that
# said the deal, worth about 1
# At the meeting, stockholders will be asked to approve a
# merger with Newell Co, to elect directors and decide related
# matters
# The resulting merger would
# create the largest independent software company yet
# The company said its was served the suit in Minneapolis on
# March 31, the day after it announced its definitive merger
# agreement with Bristol-Myers
# Kansas said Santa Fe in petitioning
# for reconsideration now argues that the trackage agreements
# with the Union Pacific, the Denver and Rio Grande Western and
# other railroads, adds to the value of the merger
# "Business is
# continuing as usual," it said, adding that it is not engaged in
# any merger or acquisition discussions
# Computer Associates' Wang and Uccel's Liemandt said at a
# news conference that the merger would give computer users a
# single source for a wide range of software products
# After the merger, Breast Centers shareholders would become
# the majority shareholders of the combined company
# But a spokeswoman pointed out that Financial Corp has said
# publicly for nearly two years that in the company's view a
# merger would be one method of increasing the company's capital
# Progressive is currently the subject of both a proposed
# merger with Rainbow and a full takeover bid from &lt;Brierley
# Investments Ltd> (BIL)
# Santa Fe in its petition outlines an array of
# pro-competitive agreements with other railroads which would
# preserve the economic benefits of the merger for the merged
# railroad and the public
# 5 mln dlrs
# for the merger facility
# It said that Morgan Stanley and Co Inc and Salomon Brothers
# Inc, hired in 1983 to advise Southern and Santa Fe in their
# merger, appraised Southern as worth between 500 mln dlrs and
# 800 mln dlrs less than Southern's own internal valuations
# Borg-Warner and Merrill said yesterday they entered a
# definitive merger agreement, under which a subsidiary of the
# new company, &lt;AV Holdings Corp>, will begin a 48
# The companies said that after the proposed merger, the
# combined banking holding wil be among the 25 largest in the
# country
# The voting trust agreement requires the bank to vote in
# favor of any acquisition agreement between TWA and USAir and to
# opposed any other merger of USAir
# Under the merger,
# shareholders in both Progressive and Rainbow will be issued
# shares in the new company on a one-for-one basis
# Seton said its board of directors unanimously approved the
# merger in a meeting held today
# The ministry has favoured the merger of the two rival
# groups, arguing the market cannot support more than one
# competitor to Kokusai Denshin Denwa Co Ltd, which now
# monopolizes the business
# The companies said they expect to complete the merger,
# which will create a bank with 80 billion dlrs of assets, by the
# end of the second quarter
# Hawkins said the merger has been assessed by independent
# consultants and declared fair in all respects, with benefits to
# all shareholders
# As part of the plan, the company will change its state of
# incorporation from Florida to Delaware by means of a merger of
# Caesars World into a wholly owned subsidiary of the company
# Rainbow has said the merger is soundly based
# The bank said Community State Bank's shareholders approved
# the merger at a meeting last Saturday, while Monday the
# directors of 1st Source also approved the move
# Canadian International, as earlier reported, was formed from
# the merger of Pacific Western's Pacific Western Airlines Ltd
# unit and Canadian Pacific Airlines Ltd
# After a failed first attempt earlier this year, Rorer's
# latest merger plan calls for a share swap worth about 720 mln
# dlrs
# The merger took place in December, and Western has
# been operated as a Delta subsidiary since then
# Captive had 2,649,500 common shares outstanding
# before the merger
# Fleet and Norstar in a joint statement billed the proposed
# merger as "a partnership of two companies
# Development Corp of America, whose board approved the
# acquisition last November for 90 mln dlrs, said the merger was
# effective today and its stock now represents the right to
# receive 15 dlrs a share
# " Hughes said that Baker should
# instead complete the sale of the disputed assets before the
# merger is finalized and given government approval
# Wang said Haefner, the Swiss investor, would hold about 25
# pct of Computer Associates stock after the merger
# Entertainment said the offer would be conducted through a
# negotiated merger with a new corporation to be formed by
# Entertainment Marketing
# The merger calls for an unspecified amount of stock to be
# paid for Nucell, the company said
# Operations are dependent upon financing and efforts to
# obtain financing, including potential buyers and merger
# candidates, have been unsuccessful, it said
# Under the terms of the merger, Sovereign stockholders
# wil receive, in a tax free exchange, 0
# But the company said that it would
# take more than five billion dlrs to consummate the merger and
# retire certain company debt
# The merger will bring Suburban's assets to
# 661 mln dlrs and its total banks to 13
# Others argue the merger
# was more cost effective than creating a comparable branch
# network from scratch
# Jacy Mendonca, industrial relations director of Autolatina,
# a merger of Volkswagen and Ford in Brazil and Argentina, said
# last week this would be the worst year ever for Brazil's auto
# industry
# Two weeks ago before the study was completed, Contel
# announced it would seek to terminate the proposed merger
# The Texas Commerce-Chemical merger is the only acquisition
# by a major out-of-state bank since Texas lawmakers approved
# interstate banking effective January 1
# Earlier, Alpha Health Systems Corp, a unit of Pesch and Co,
# said it submitted a merger proposal to the board of REPH
# Acquisition Co, the parent of Republic Health
# 4 Dauphin shares
# for each colonial share, depending on the market value of
# Dauphin shares just before the merger takes place
# Liemandt, who said he will leave the company after the
# merger is completed, also turned to acquisitions for growth
# Interco said the merger becomes effective April 14
# The company said under the terms, Great Western has agreed
# not to acquire or seek to acquire any voting securities of
# Citadel or propose a merger with Citadel for five years, and
# Citadel has paid Great Western six mln dlrs
# The size of
# the combined staffs of the two banks has been cut by 12 pct so
# far this year, and Fronterhouse said the bank is ahead of the
# schedule it set for achieving savings through the merger
# Moody's cited the significant increase in leverage and the
# reduction in coverages that will result from the merger of
# Scott with Simmons Communications Merger Corp
# The order was issued as part of a settlement of FTC charges
# that Cooper's merger with Gardner-Denver Co would lessen
# competion and increase concentration in the gas compressor and
# industrial air tool industries, the FTC said
# He said the arguments cited
# by Hughes yesterday for not doing the merger "tend to be weak
# Harcourt Brace said it will only pursue the acquisition if
# a mutually-satisfactory merger agreement can be negotiated
# The junior subordinated discount debentures to be issued in
# the merger will carry a 13 pct coupon and will begin paying
# cash interest after five years
# The company said it expects to proceed with a merger and
# has advised Cyclops it intends to increas the per-share amount
# to be paid in the merger to 95 dlrs, form 90
# Uccel's Liemandt declined to say what he will do after the
# merger, but he did not rule out working together with Wang

# %% [markdown]
# Did your improvement return more matching sentences?
#
# Are there any problems in our sentence segmentation?
#
# There are lots more special characters that you can use to form really powerful regular expressions. If you are interested, you can find a complete list [here](https://docs.python.org/3/library/re.html#regular-expression-syntax).

# %% [markdown]
# ## 2.2 Substitution
#
# We can also use regular expressions during _preprocessing_ to clean up text and prepare it for further analysis. For this, we use regular expression _substitution_, which finds a matching string within a larger piece of text, and replaces it with another string.
#
# Let us use this to clean up the text by removing the line break characters.
#
# In Python, we can use the re.sub() function, which takes three arguments:
# 1. The expression to match.
# 2. The pattern we should replace it with
# 3. The text to apply the subtitution to.
#
# To remove the line breaks, the expression in argument 1 can be set to match any non-new line characters with the disjunction `[^\n]*`.
#
# Here, we will also put the disjunctions inside parentheses, like this: `([^\n]*)`. This specifies that the matching characters are a _group_. This allows the second argument (the replacement pattern) to refer to each _group_ of characters matched by the first argument.
#
# Look at the code below to see how this is done, then run it to get the result:

# %%
print('ORIGINAL TEXT: ')
print(train_dataset[3]['text'])
    
clean_article = re.sub(r'([^\n]*)\n([^\n]*)', r'\1 \2', train_dataset[3]['text'])
    
print('CLEAN TEXT: ')
print(clean_article)
# Out:
# ORIGINAL TEXT:
# BankAmerica Corp is not under
# pressure to act quickly on its proposed equity offering and
# would do well to delay it because of the stock's recent poor
# performance, banking analysts said.
#     Some analysts said they have recommended BankAmerica delay
# its up to one-billion-dlr equity offering, which has yet to be
# approved by the Securities and Exchange Commission.
#     BankAmerica stock fell this week, along with other banking
# issues, on the news that Brazil has suspended interest payments
# on a large portion of its foreign debt.
#     The stock traded around 12, down 1/8, this afternoon,
# after falling to 11-1/2 earlier this week on the news.
#     Banking analysts said that with the immediate threat of the
# First Interstate Bancorp &lt;I> takeover bid gone, BankAmerica is
# under no pressure to sell the securities into a market that
# will be nervous on bank stocks in the near term.
#     BankAmerica filed the offer on January 26. It was seen as
# one of the major factors leading the First Interstate
# withdrawing its takeover bid on February 9.
#     A BankAmerica spokesman said SEC approval is taking longer
# than expected and market conditions must now be re-evaluated.
#     "The circumstances at the time will determine what we do,"
# said Arthur Miller, BankAmerica's Vice President for Financial
# Communications, when asked if BankAmerica would proceed with
# the offer immediately after it receives SEC approval.
#     "I'd put it off as long as they conceivably could," said
# Lawrence Cohn, analyst with Merrill Lynch, Pierce, Fenner and
# Smith.
#     Cohn said the longer BankAmerica waits, the longer they
# have to show the market an improved financial outlook.
#     Although BankAmerica has yet to specify the types of
# equities it would offer, most analysts believed a convertible
# preferred stock would encompass at least part of it.
#     Such an offering at a depressed stock price would mean a
# lower conversion price and more dilution to BankAmerica stock
# holders, noted Daniel Williams, analyst with Sutro Group.
#     Several analysts said that while they believe the Brazilian
# debt problem will continue to hang over the banking industry
# through the quarter, the initial shock reaction is likely to
# ease over the coming weeks.
#     Nevertheless, BankAmerica, which holds about 2.70 billion
# dlrs in Brazilian loans, stands to lose 15-20 mln dlrs if the
# interest rate is reduced on the debt, and as much as 200 mln
# dlrs if Brazil pays no interest for a year, said Joseph
# Arsenio, analyst with Birr, Wilson and Co.
#     He noted, however, that any potential losses would not show
# up in the current quarter.
#     With other major banks standing to lose even more than
# BankAmerica if Brazil fails to service its debt, the analysts
# said they expect the debt will be restructured, similar to way
# Mexico's debt was, minimizing losses to the creditor banks.
#  Reuter
#
# CLEAN TEXT:
# BankAmerica Corp is not under pressure to act quickly on its proposed equity offering and would do well to delay it because of the stock's recent poor performance, banking analysts said.     Some analysts said they have recommended BankAmerica delay its up to one-billion-dlr equity offering, which has yet to be approved by the Securities and Exchange Commission.     BankAmerica stock fell this week, along with other banking issues, on the news that Brazil has suspended interest payments on a large portion of its foreign debt.     The stock traded around 12, down 1/8, this afternoon, after falling to 11-1/2 earlier this week on the news.     Banking analysts said that with the immediate threat of the First Interstate Bancorp &lt;I> takeover bid gone, BankAmerica is under no pressure to sell the securities into a market that will be nervous on bank stocks in the near term.     BankAmerica filed the offer on January 26. It was seen as one of the major factors leading the First Interstate withdrawing its takeover bid on February 9.     A BankAmerica spokesman said SEC approval is taking longer than expected and market conditions must now be re-evaluated.     "The circumstances at the time will determine what we do," said Arthur Miller, BankAmerica's Vice President for Financial Communications, when asked if BankAmerica would proceed with the offer immediately after it receives SEC approval.     "I'd put it off as long as they conceivably could," said Lawrence Cohn, analyst with Merrill Lynch, Pierce, Fenner and Smith.     Cohn said the longer BankAmerica waits, the longer they have to show the market an improved financial outlook.     Although BankAmerica has yet to specify the types of equities it would offer, most analysts believed a convertible preferred stock would encompass at least part of it.     Such an offering at a depressed stock price would mean a lower conversion price and more dilution to BankAmerica stock holders, noted Daniel Williams, analyst with Sutro Group.     Several analysts said that while they believe the Brazilian debt problem will continue to hang over the banking industry through the quarter, the initial shock reaction is likely to ease over the coming weeks.     Nevertheless, BankAmerica, which holds about 2.70 billion dlrs in Brazilian loans, stands to lose 15-20 mln dlrs if the interest rate is reduced on the debt, and as much as 200 mln dlrs if Brazil pays no interest for a year, said Joseph Arsenio, analyst with Birr, Wilson and Co.     He noted, however, that any potential losses would not show up in the current quarter.     With other major banks standing to lose even more than BankAmerica if Brazil fails to service its debt, the analysts said they expect the debt will be restructured, similar to way Mexico's debt was, minimizing losses to the creditor banks.  Reuter

# %% [markdown]
# #### Correction

# %%
all_matches = []

for article in train_dataset:
    
    ### WRITE YOUR CODE HERE
    # no space after 'merger' so we can catch instances where 'merger' is at the end of the sentence.
    # Put a '?' after the first punctuation mark because it is optional.
    matches = re.findall(r'[\.\!\?]?[^\.\!\?]* merger[^\.\!\?]*[\.\!\?]', article['text'])  
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(f'<MATCH> {match}')
# Out:
# 711
# <MATCH> .
#     Hoechst Celanese was formed Feb 27 by the merger of
# Celanese Corp and American Hoechst Corp.
# <MATCH> .
#     The companies said they agreed not to pursue the merger
# because several actions recently taken by AmBrit would mean
# substantial delays in completing the deal.
# <MATCH> .
#     Ward said it was his idea to have a merger agreement with
# Distillers under which Distillers agreed to pay Guinness's bid
# costs, the PA reported.
# <MATCH> .
#     The Baker-Hughes merger, which would would create a 1.
# <MATCH> . The size of
# the combined staffs of the two banks has been cut by 12 pct so
# far this year, and Fronterhouse said the bank is ahead of the
# schedule it set for achieving savings through the merger.
# <MATCH> . Under terms of the merger,
# which took effective today, Universal said its shareholders
# will receive three dlrs a share in cash.
# <MATCH> .
#     American's merger with AirCal, announced last November,
# received final approval from the Department of Transportation
# yesterday.
# <MATCH> .
#     Emery said it had tried unsuccessfully to open merger
# discussions with Purolator before the company accepted the
# management-led buyout offer.
# <MATCH> .
#     Paues said the merger was a direct result of the sharp fall
# in oil prices 18 months ago which led oil firms to cut back
# exploration activities.
# <MATCH> .
#     That merger was viewed by some analysts as reducing Rolm's
# independence and relegating it to a role as a manufacturing and
# product development site within IBM.
# <MATCH> Trans World Airlines said it has
# proposed a cash merger of USAir Group with TWA in which the
# holders of USAir common would receive 52 dlrs in cash in
# exchange for their stock.
# <MATCH> .
#     A Chemlawn spokesman said further details on the merger
# would be issued later.
# <MATCH> .
#     The Appeals Court ruling surprised officials of
# Atlanta-based Delta, which had been preparing for the merger
# for months and had already painted Delta logos on airplanes
# belonging to Western, which has headquartera in Los Angeles.
# <MATCH> Bank of New England Corp reported
# that pro forma first quarter earnings, which reflect its
# combined operations under a pending merger with the Conifer
# Group, rose to 60 mln dlrs, or 89 cts a share, from 49 mln
# dlrs, or 75 cts a share in 1986.
# <MATCH> .
#     He added takeovers and mergers had an important role to
# play in furthering economies of scale, integration and more
# efficient market penetration.
# <MATCH> .
#     The ruling came in a lawsuit in which the Air Transport
# Employees union said Western's management should fulfil a
# promise to honour union contracts if a merger took place.
# <MATCH> Kingsbridge Holdings Ltd, said it signed
# a letter of intent for a merger with &lt;Masco Sports Inc>.
# <MATCH> . Emery
# said as a result it is renewing its request that Purolatr enter
# into merger negotiations with it.
# <MATCH>
#     The companies also said the Securities and Exchange
# Commission declared effective as of March 24 the registration
# statement covering the securities Chemical will issue to Texas
# Bancshares shareholders as part of the merger.
# <MATCH> . Pennzoil said the merger
# violated a prior agreement it had to buy Getty and sued Texaco.
# <MATCH>  Under the merger,
# shareholders in both Progressive and Rainbow will be issued
# shares in the new company on a one-for-one basis.
# <MATCH>
#     Despite the Hughes statement that it is interested in a
# merger, and Baker's response that a merger is still possibile,
# analysts said no one could be certain where the situation was
# going.
# <MATCH> .
#     Kim said mergers of some financial companies and the
# upgrading of others to merchant banks or full banks were being
# considered by the financial development committee of the
# finance ministry.
# <MATCH>
#      It said it and the Toussie-Viner group, with which it made
# the merger offer, were assessing their options regarding the
# Heck's investment.
# <MATCH> .
#     The merger was approved following completion on Jan 27 of a
# tender offer valued at approximately 55 mln dlrs, the company
# said.
# <MATCH> .,
# have approved a merger into First Union for 40 dlrs per share,
# or about 5,100,000 dlrs.
# <MATCH> .
#     Earlier this month the group said that tentative merger
# talks with the high street pharmacist &lt;Underwoods Plc> had been
# called off and recently announced a 19.
# <MATCH> . textile maker focused
# on its own business as its competitors found merger partners,
# but now Burlington Industries Inc may have restructured itself
# into an attractive takeover candidate, analysts said.
# <MATCH> .
#     OII said each common share still outstanding at the time of
# the merger has been converted into the right to receive 60.
# <MATCH> .
#     A merger approved by the Allegheny board in which remaining
# common, preference and preferred shares would be acquired at
# the tender prices is to follow the offer.
# <MATCH> .
#     The transaction is structured as a merger of Liberty with a
# duly-formed unit of Equimark, the company said.
# <MATCH> Seton Co said its board of
# directors unanimously approved an agreement and plan of merger
# providing for the merger of Seton with a unit of S Acquisition
# Corp, a New Jersey company.
# <MATCH> 1st Source Bank said it
# completed its merger with &lt;Community State Bank> of North
# Liberty, Ind.
# <MATCH> .
#     TWA said the merger is subject to the USAir board redeeming
# the preferred stock purchase rights (the poison pill) issued to
# shareholders last year and taking action so that the vote of a
# majority of the outstanding common stock is required to approve
# its proposed move.
# <MATCH> .
# TWA said the agreement does not prevent it from commenting to
# regulatory agencies on the USAir, Piedmont merger.
# <MATCH> Chrysler Corp said Electrospace Systems
# Inc agreed to be acquired under a merger agreement in which
# Chrysler will tender 27 dlrs a share for 100 pct of the
# Richardson, Texas-based defense electronics contractor.
# <MATCH> .
#     After the merger, Viacom will be a subsidiary of National
# but 17 pct of the company will be in public hands.
# <MATCH> .
#     Analyst Thaddeus Paluszek of Merrill Lynch and Co said
# Fleet's earnings would have been diluted about two pct in 1986
# on the basis of the merger terms announced today.
# <MATCH>
#     ICC voted four to one last summer to reject the merger as
# inherently anticompetitive.
# <MATCH>
#     The request to bar the merger was made by Samjens
# Acquisition Corp, a partnership formed by financier Asher B.
# <MATCH> .
#     S and P cited a merger agreement between the two companies
# which it believes will improve both firms' market positions as
# well as complement each other's products and distribution.
# <MATCH> .
#     It said it would leave open a range of options regarding
# the debentures, including buying more, selling some or all of
# their current stake in the market or in negotiated deals,
# talking with other Harcourt security holders, surrendering the
# debentures if there were a merger or tender offer or converting
# them into stock.
# <MATCH>
#     In the merger, Lane's stockholders will receive 1.
# <MATCH> . Department of Justice consent decree that would
# require Baker to sell its drilling bit operations and
# submersible pump business, met yesterday and threatened to
# terminate the proposed merger.
# <MATCH> .
#     Bastian said alternatives being considered include an
# attempt to acquire Cosmo through a merger, tender or exchange
# offer, seeking to influence the company's management and
# policies, and seeking representation on Cosmo's board of
# directors through a proxy contest or otherwise.
# <MATCH> .
#     The acquisition would be a cash merger, with Progressive
# shareholders receiving up to three dlrs per share, the company
# said.
# <MATCH> .
#     A statement by Williams said it was confident of the merits
# of the proposed merger and it had therefore taken care to
# propose from the outset the right terms, including a full cash
# alternative.
# <MATCH> .
#     The statement, issued yesterday, did not say how close the
# bank was to a merger or recapitalisation program.
# <MATCH> .69 billion
#     NOTE: figures reflect the merger of Sea-Land Corp completed
# Feb 11, 1987.
# <MATCH> .
#     DRS, a warfare systems producer, said it would make the
# transaction through a cash tender offer for all, but not less
# than 51 pct, of Rospatch's outstanding common stock followed by
# a merger with Rospatch, a labels, high technology and wood
# producer, at the same purchase price per share.
# <MATCH>
#     Santa Fe Southern Pacific owns the Santa Fe railroad and
# holds the Southern Pacific railroad assets in trust while
# awaiting federal approval of the merger plan.
# <MATCH> .4 Dauphin shares
# for each colonial share, depending on the market value of
# Dauphin shares just before the merger takes place.
# <MATCH> .O> approved
# the merger of the two companies.
# <MATCH> Security Pacific Corp and
# &lt;Users Inc>, a credit union data processing concern, said they
# have mutually agreed to withdraw from further merger
# negotiations.
# <MATCH>
#     The merger involves the formation of a new company &lt;Astral
# Pacific Corp Ltd> which will acquire all shares in both
# companies on a one-for-one share exchange basis.
# <MATCH> .L> Plc said it has no
# intention of proceeding any further with talks on Williams
# Holdings Plc's suggestion that there would be benefits arising
# from a merger between the two groups.
# <MATCH>
#     Valhi said these results were prepared as if the merger had
# occurred July 1, 1986, and on substantially the same basis as
# the pro-forma financial information in LLC's and Amalgamated's
# joint proxy statement dated February 10.
# <MATCH> .
#     The deal is subject to completion of a definitive merger
# agreement, receipt of third party approvals and other
# conditions, the company said.
# <MATCH> .
#     While the banks have been approached by securities firms
# seeking merger partners, they have not yet bought into
# brokerages, choosing to build securities units from within.
# <MATCH> .1 billion dlrs
# and there have been several bank mergers in the southeast
# valued in the 700-800 mln dlr range.
# <MATCH>
#     Without the merger, Hughes Tool's current ratings of B-plus
# for senior debt, B-minus for subordinated debt and C for
# commercial paper would be affirmed, S and P said.
# <MATCH>
#     Under a merger agreement entered into in November, Reuters
# tendered for up to 5.
# <MATCH> .
#     The order was issued as part of a settlement of FTC charges
# that Cooper's merger with Gardner-Denver Co would lessen
# competion and increase concentration in the gas compressor and
# industrial air tool industries, the FTC said.
# <MATCH> .86 dlrs per share on exchange of common of Pan America
# Banks Inc for common of NCNB Corp purusant to a merger of the
# companies.
# <MATCH> .
#     The company said if the merger is approved by shareholders
# of both companies, the shareholders of John Paul Richards would
# become majority shareholders, owning 60 pct of the common
# stock, of the new public company.
# <MATCH> . If approved, the merger will add another 3.
# <MATCH> .  The
# ChemLawn board has approved the tender and a merger at the same
# price that is to follow.
# <MATCH> Vernitron Corp said it has set a
# new record date of July 10 for shareholders entitled to vote on
# the proposed merger of Vernitron with &lt;SB Holding Corp>.
# <MATCH> .
#     Hughes' Kistler, speaking to reporters after 85 pct of
# Hughes' shareholders approved the merger, said the revised
# terms of the agreement give the companies six months to find a
# buyer for the Reed drilling bit business.
# <MATCH> American Motors Corp said its directors
# reviewed a Chrysler Corp merger proposal but took no action on
# it.
# <MATCH> &lt;Hoechst Celanese Corp>,
# recently formed from the merger of the Celanese Corp with
# American Hoechst Corp, a unit of &lt;Hoechst AG>, said Juergen
# Dormann, former member of Hoechts AG's management board, has
# been named chairman and chief executive officer of Hoechst
# Celanese.
# <MATCH> .
#     She noted that Chrysler Corp's &lt;C> announcement of a merger
# proposal for American Motors Corp &lt;AMO> should have no short
# term effect on Ford but could cut into Ford's share of the
# truck market in the long term.
# <MATCH> .
#     TWA also agreed that it would not knowingly and willingly
# interfere with the consummation of the merger between USAir and
# Piedmont Aviation Inc &lt;PIE>.
# <MATCH> .
#     The junior subordinated discount debentures to be issued in
# the merger will carry a 13 pct coupon and will begin paying
# cash interest after five years.
# <MATCH> . We consider this to be a merger
# of equals.
# <MATCH> The Department of Transportation
# said it will allow USAIR Group to acquire up to 51 pct of
# Piedmont Aviation &lt;PIE> voting stocks pending final approval of
# the proposed merger of the two airlines.
# <MATCH> Lifestyle Restaurants Inc said it
# reduced the number of Bombay Palace Restaurants inc common
# shares to be received in its previously announced merger
# agreement.
# <MATCH> .
#     Russo filled orders for David Sofer, an Israeli citizen,
# who allegedly traded on inside information from Nahum
# Vaskevitch, head of Merrill Lynch and Co's &lt;MER> London mergers
# office.
# <MATCH> .
#     Cable and Wireless has a 20 pct stake in one of the two
# companies involved in the mooted merger.
# <MATCH> .
#     FMC had charged that Boesky received confidential
# information about FMC's planned recapitalization from Dennis
# Levine, a former merger specialist with Drexel Burnham Lambert
# Inc.
# <MATCH> .
#     Industrial Equity (Pacific) added it is considering
# launching a tender offer for Calmat stock or making a merger
# proposal to the company, but said it has not decided whether it
# will pursue a Calmat acquisition on a non-negotiated basis.
# <MATCH> FCS Laboratories said its
# investment banker, Butcher and Singer Inc, received a
# preliminary merger proposal from another company in the
# healthcare field.
# <MATCH> .
#     The meeting would also be asked to approve a merger of two
# Italian subsidiaries, &lt;CM Italia Spa> and &lt;Societa
# Amministrazioni Turistiche Srl>.
# <MATCH> Berry Petroleum Co said its board
# and the Norris Oil Co board approved a merger agreement that
# calls for Norris to become a wholly-owned Berry subsidiary.
# <MATCH> Universal Resources Corp said it
# is holding a special shareholders meeting this morning to vote
# on the previously-proposed merger between it and Questar Corp
# &lt;STR>.
# <MATCH> Merrill Lynch and Co &lt;MER> said the
# head of its mergers and acquisitions department in London,
# accused by U.
# <MATCH> Fair Lanes Inc said its shareholders
# approved the previously announced merger with Maricorp Inc, a
# unit of &lt;Northern Pacific Corp>.
# <MATCH> .
#     Asamera said its talks with Breakwater Resources Ltd
# &lt;BWRLF> on a possible merger of mining interests, including the
# Cannon mine, have been terminated.
# <MATCH> .
#     Under the agreement, Greyhound will acquire, in a merger,
# three of the company's foodservice operations - Dobbs
# International Services, Dobbs Houses and Carson international.
# <MATCH> Standard and Poor's Corp said the
# merger agreement between Fleet Financial Group and Norstar
# Bancorp Inc would not affect the firms' current ratings because
# the merger cannot take place until July 1988.
# <MATCH>
#     The merger involves shareholders in Progressive and Rainbow
# both receiving shares in a new company &lt;Astral Pacific Corp
# Ltd> on a one-for-one exchange basis.
# <MATCH> .
#     If the merger is approved, common stock still outstanding
# will be converted into the right to receive 61.
# <MATCH>
#     Two airlines, Sabena and Scandinavian Airlines System
# (SAS), are now discussing a merger.
# <MATCH> .
#     The transaction is conditioned on  Allied's pending merger
# with the Vons Cos Inc.
# <MATCH> .
#     First City, the big Texas bank hit hardest by the downturn
# in oil prices, lost a record 402 mln dlrs in fiscal year 1986
# and has said it is seeking a merger partner or some other
# capital assistance.
# <MATCH> .
#     Earlier, Alpha Health Systems Corp, a unit of Pesch and Co,
# said it submitted a merger proposal to the board of REPH
# Acquisition Co, the parent of Republic Health.
# <MATCH> .
#     Emery said Purolator would operate as a wholly owned unit
# of the company after the merger.
# <MATCH> Manhattan Federal Court Judge Shirley
# Wohl Kram said she would rule Monday on whether to grant a
# request to block a 78 dlr per share merger agreement between
# Burlington Industries Inc and Morgan Stanely Group Inc &lt;MS>.
# <MATCH> .
#     The company said the start of the tender offer and the
# calling of the special meeting are conditions of the
# settlement, and completion of the tender and merger are
# conditioned on final approval of the settlement.
# <MATCH> .
#     Under the merger's terms, Strata shareholders will receive
# 5.
# <MATCH> .
#     Sosnoff said under the merger that would follow his tender,
# each of the 2,750,000 Caesars shares not covered by the offer,
# or 7.
# <MATCH> .
#     The merger following the tender offer will be subject to
# approval by ARGOSystems shareholders, the companies said.
# <MATCH> .
#     In the mergers and acquisitions area, the association
# advocated a ban on greenmail payments or poison pill takeover
# protection plans without prior shareholder approval.
# <MATCH> First Data Management co Inc said
# it has completed a merger into Firsst Data MAnagement Holding
# co following sharehoplder approval.
# <MATCH> ."
#     It said it planned to regularly review its investment and
# may in the future recommend business strategies or an
# extraordinary corporate transaction such as a merger,
# reorganization, liquidation or asset sale.
# <MATCH> . subsidiary has not achieved this ownership
# within one year after the completion of the merger, the
# subsidiary will have the right two years thereafter to request
# that HRI commence a rights offering to HRI stockholders, the
# company said.
# <MATCH> .
#     He said the company continues to look at mergers and
# acquisitions.
# <MATCH> Computer Associates International Inc
# and UCCEL Corp &lt;UCE> said they have signed a definitive merger
# agreement under which Computer Associates will pay about 800
# mln dlrs in stock for all outstanding UCCEL shares.
# <MATCH> .
#     Following the merger, Balzac shareholders will hold 80 pct
# of the outstanding stock of Magellan, the company said.
# <MATCH> .
#     Suggesting that the total cost of completing the merger
# would be 190 mln dlrs, Cross said he would use 20 mln dlrs of
# his own money for the deal and up to 170 mln dlrs which would
# be borrowed from the First National Bank of Boston under a
# revolving credit facility the bank has agreed to provide.
# <MATCH> .
#     The exchange, they said, will be made on the effective date
# of the merger, which must be approved by both companies' boards
# and High Plains' shareholders.
# <MATCH> Genova Inc said its shareholders
# approved a merger into &lt;Genova Products Inc>, which will be
# consumated within a few days.
# <MATCH> . The resulting merger would
# create the largest independent software company yet.
# <MATCH>
#     This week Hughes seemed to back out of the merger but then
# said it was still interested in talking.
# <MATCH> . If it buys more shares, Metropolitan
# said it would consider doing so in the open market, in private
# deals, or through an exchange offer, tender offer or merger.
# <MATCH> Mid-State Federal Savings and Loan
# Association said it and First Federal Savings and Loan
# Association of Brooksville &lt;FFBV> reached a definitive merger
# agreement.
# <MATCH> "
#     Rainbow has proposed a merger with Progressive to form a
# new company, &lt;Astral Pacific Corp Ltd>.
# <MATCH> .
# 1987 results reflect the TBS merger agreement and operations of
# the company as independent agent.
# <MATCH> .
#     The DOT said the merger was unlikely to substantially
# reduce competition on the four routes on which both carriers
# provide either nonstop or single-plane service.
# <MATCH> .
#     He also testified a committee of directors had hired
# Goldman Sachs and Co to consider alternatives to the Hutton
# offer and also to consider a discussion of possible mergers
# with other companies including Emery and Federal Express Corp
# &lt;FDX>.
# <MATCH> .
#     for the year 1986, the provisions for mergers and
# restructuring expenses brought non-recurring expenses to
# 40,292,000 before tax gains, of which 8,863,000 represented
# merger costs and 31,429,000 related to restructuring of the
# combine operations.
# <MATCH> .
#     &lt;Brierley Investments Ltd>, which has been a frequent
# critic of the merger, launched a full bid for Progressive at
# 4.
# <MATCH> .T> is certain to
# lose its status as Japan's most profitable bank as a result of
# its merger with the Heiwa Sogo Bank, financial analysts said.
# <MATCH> . That
# meeting was called to act on a merger agreement calling for a
# buyout by BCW Acquisitions Inc.
# <MATCH>
#     "Our goal is for a merger to occur.
# <MATCH> . But no decision has been made on
# whether or how to proceed with a merger attempt, he added.
# <MATCH> .Former managing director of the mergers and
# acquisitions department of the London office of Merrill Lynch
# and Co.
# <MATCH> .O>
# in a merger agreement.
# <MATCH> Society for Savings said it has
# completed a merger into newly formed holding company Society
# for Savings Bancorp Inc on a share-for-share basis.
# <MATCH> .
#     The ministry has favoured the merger of the two rival
# groups, arguing the market cannot support more than one
# competitor to Kokusai Denshin Denwa Co Ltd, which now
# monopolizes the business.
# <MATCH> .
#     The rating adjustments are based on the likelihood that the
# proposed merger of the two Texas banks will be consummated.
# <MATCH> Whippany Paper Board Co Inc said
# shareholders at a special meeting approved a merger into NPN
# Inc for 2.
# <MATCH>
#     Scocozza said even with the recent mergers, such as Texas
# Air Corp's acquisition of Eastern Air Lines and People Express,
# more airlines were flying now in the United States than before
# the 1978 airline deregulation act.
# <MATCH> . The merger will bring Suburban's assets to
# 661 mln dlrs and its total banks to 13.
# <MATCH> .
#     In a filing with the Securities and Exchange Commission,
# Merrill Lynch Capital Partners Inc said it would receive a 30
# mln dlr fee from the surviving company for acting as dealer
# manager of the merger after the Borg-Warner deal is completed.
# <MATCH> .
#     Banner said last Friday that it had arranged bank credit to
# finance most of the tender offer and the subsequent merger with
# Rexnord, under which remaining Rexnord holders may receive
# 26.
# <MATCH> .
#     It was the fourth federally-assisted merger or acquisition
# of a troubled savings institution this year, the FHLBB said.
# <MATCH> . Their merger would not
# alter American's third-place ranking, according to data
# compiled by Aviation Daily, a leading industry trade magazine.
# <MATCH> . in an attempt to block the merger.
# <MATCH> .
#     Moody's cited the significant increase in leverage and the
# reduction in coverages that will result from the merger of
# Scott with Simmons Communications Merger Corp.
# <MATCH> &lt;Pacific Western Airlines Corp>
# said it integrated the senior management of Pacific Western and
# recently acquired Canadian Pacific Air Lines Ltd in preparation
# for the companies' merger this summer.
# <MATCH> . Upon clearance of the revised proxy
# statement by the commission and its distribution to Staff
# Builders' shareholders, that company's management will continue
# to solicit proxies for approval of the merger.
# <MATCH> .,
# will serve in that capacity for the new subsidiary resulting
# from the merger.
# <MATCH> Dixons Group Plc said shareholders at a
# special meeting of Cyclops Corp approved the previously
# announced merger of Cyclops with Dixons.
# <MATCH> .
# Canadian International, as earlier reported, was formed from
# the merger of Pacific Western's Pacific Western Airlines Ltd
# unit and Canadian Pacific Airlines Ltd.
# <MATCH>
#     But, the analysts added, that Robins desire to emerge
# independent from two years of bankruptcy proceedings may be
# thwarted by some Robins' shareholders who perceive a merger as
# a more expedient way of dealing with the company's Dalkon
# Shield related liabilities.
# <MATCH> .
#     Analysts said the merger continues a trend in the
# automobile industry of diversification away from carmaking.
# <MATCH> .
#     Resorts said the offer from KSZ calls for a merger of
# Resorts with RI Acquisition Co Inc, a newly formed Delaware
# corporation.
# <MATCH> .8 pct of its stock and have agreed to vote in favor of
# the merger.
# <MATCH> Westinghouse Electric Corp &lt;WX> said
# it is still open to a merger of its radio operations with
# General Electrics Co's &lt;GE> NBC radio operations.
# <MATCH>
#     The Texas Commerce-Chemical merger is the only acquisition
# by a major out-of-state bank since Texas lawmakers approved
# interstate banking effective January 1.
# <MATCH> .
#     One of the deals in which an insider profit was alleged was
# the 1984 merger of K-Mart Corp &lt;KM> with &lt;Pay Less Drug
# Stores>.
# <MATCH>
#     The board of directors of the California-based Baker had
# approved the merger.
# <MATCH> .
#     Comdata said in the merger each share of the company's
# stock would be converted at the holders election into either 15
# dlrs in cash or a combination of 10 dlrs in cash and a unit of
# securities including common stock.
# <MATCH> .
#     USAir said it has been advised by Norfolk Southern that the
# company supports the proposed merger and intends to tender all
# of its remaining 1,477,829 Piedmont common shares in response
# to USAir's tender offer which began today.
# <MATCH> Cyclops Corp said its board has
# been restructured under the terms of the company's merger
# agreement with &lt;Dixons Group plc> following the British
# company's acquisition of 54 pct of Cyclops' stock.
# <MATCH> .
#     Jacy Mendonca, industrial relations director of Autolatina,
# a merger of Volkswagen and Ford in Brazil and Argentina, said
# last week this would be the worst year ever for Brazil's auto
# industry.
# <MATCH>
#     "It's a merger of equals," said analyst John Rooney of
# Moseley Securities Corp.
# <MATCH> . But the company said that it would
# take more than five billion dlrs to consummate the merger and
# retire certain company debt.
# <MATCH>
#     Baker said it believes the merger to be in the best
# interests of shareholders of both companies.
# <MATCH> Computer Associates International Inc's
# 800 mln dlr merger with Uccel Corp &lt;UCE> will eliminate its
# strongest rival, but the company still faces stiff competition
# from International Business Machines Corp &lt;IBM>, Wall Street
# analysts said.
# <MATCH> . Appeals court last night
# blocked the 860 mln dlr merger of Delta Airlines Inc &lt;DAL.
# <MATCH> .
# The merger would create the nation's second-longest railroad.
# <MATCH> .
#     Meese told the House Appropriations Subcommittee that
# consideration would be part of the Justice Department's review
# of the proposed merger.
# <MATCH> &lt;Metro Funding Corp> said its
# shareholders approved its merger into &lt;Maxcom Corp> and its
# change of incorporation from Nevada to Delaware.
# <MATCH> .5 billion dlrs for the Federal Savings and Loan Insurance
# Corp and give federal regulators more power to arrange
# out-of-state mergers for failed or failing banks with 500 mln
# dlrs or more in assets.
# <MATCH> . senator said a corporate merger wave was harming the
# economy and blamed the Reagan administration for laxness in
# enforcing the federal antitrust laws.
# <MATCH> . Canadian Airlines was recently
# formed through the merger of Canadian Pacific Airlines and
# Pacific Western Airlines.
# <MATCH> ." The stock has risen more on merger speculation
# than on fundamentals, the opinion continued.
# <MATCH> &lt;Chatsworth Enterprises
# Inc>, a publicly held shell corporation, said it signed a
# letter of intent to merger with &lt;Lotoquik International Ltd>, a
# Nassau, Bahamas-based maker of video lottery machines.
# <MATCH>
#     The companies also said the signing cleared the way for
# their merger completed today.
# <MATCH> .
#     But a merger of the two deposit-insurance agencies could be
# an option as part of a general structural reform of the U.
# <MATCH> .
#     Carroll also noted that since the merger accord was first
# signed "the outlook for the industry has improved materially.
# <MATCH> .
#     After the merger, Breast Centers shareholders would become
# the majority shareholders of the combined company.
# <MATCH> .4 mln
#     NOTE: Prior year figures restated to reflect merger in
# March 1986 with Amtron Corp.
# <MATCH> .
#     The merger of Uccel and Computer Associates combines the
# two biggest systems utilities suppliers other than IBM.
# <MATCH> .
#     In an attempt to hammer out an agreement, Solomon today met
# Fumio Watanabe, the senior Keidanren officer trying to arrange
# the merger.
# <MATCH> (Suburban Bancorp Inc) and
# (Woodstock State Bancorp Inc) said they agreed to a merger
# under which Suburban will purchase Woodstock's shares for a
# total of more than 18 mln dlrs in cash and Suburban Bancorp
# shares.
# <MATCH> .
#     Vernitron said that it currently expects the special
# shareholder meeting concerning the merger will be held in
# August.
# <MATCH>
#     Under its merger agreement, Hutton has the right to
# unilaterally terminate the merger agreement under certain
# circumstances, including its receipt of less than 66-2/3 pct of
# Purolator shares or the start of a higher competing tender
# offer, such as Emery's competing 40 dlr per share offer for
# Purolator stock.
# <MATCH> .
#     Hughes said it proposed to Baker that the companies ask the
# Justice Department to allow them to proceed with the merger on
# condition that they find a buyer approved by the  Department
# for the domestic oilfield tricine rock bit assets of Baker's
# Reed subsidiary, its Singapore plant and Baker Lift's domestic
# electrical submersible pump business by April 22, the last date
# the merger of Baker and Hughes could occur under their
# agreement.
# <MATCH>  Kansas said Santa Fe in petitioning
# for reconsideration now argues that the trackage agreements
# with the Union Pacific, the Denver and Rio Grande Western and
# other railroads, adds to the value of the merger.
# <MATCH> .
#     1985 results reflect only six mths of mining operations due
# to merger of Erickson Gold Mines Ltd and Total Eastcan
# Exploration Ltd on June 30, 1985.
# <MATCH> Fleet Financial Group hopes its
# proposed merger with Norstar Bancorp &lt;NOR>, ranked as the
# largest U.
# <MATCH> . "We think that
# in the third or fourth quarter after the merger we should see
# something close to breakeven," he said.
# <MATCH> .
#     The new offer, the second sweetened deal Redstone has
# proposed in his month-long bidding war with management, also
# contains newly drawn up proposed merger documents, he said.
# <MATCH>
#     TWA said that in respect to USAir's recent offer for
# Piedmont Aviation &lt;PIE> it believes that USAir's shareholders
# would prefer a cash merger proposal for USAir over its proposed
# acquisition of Piedmont.
# <MATCH> Commonwealth Realty Trust said
# preliminary merger talks with Bay Financial Corp have been
# terminated due to a failure to agree on terms.
# <MATCH> .
#     Justice's opposition to quick federal approval of a bid by
# Greyhound Lines Inc to take immediate control Trailways Corp
# prompted Greyhound to threaten -- in a brief filed with the
# Interstate Commerce Commission (ICC) -- to drop the merger
# plan.
# <MATCH> .
#     In its offer, TWA said as an alternative to a merger with
# USAir, it would be interested in discussing a three-way
# combination among USAir, Piedmont and TWA.
# <MATCH> .
#     But for flexibility purposes, Merrill Lynch said it is
# considering redistributing Borg-Warner's assets to a number of
# subsdiaries of an entity it created to carry out the merger.
# <MATCH>
#     "He wanted to take some personal time off," she said,
# adding that Paboojian had taken part in the merger decision.
# <MATCH> ." But he
# expressed skepticism that this will necessarily lead to
# heightened merger or buyout activity in the oil group.
# <MATCH>
#     Hanson said that promptly following the filing of the
# certificate of merger Kaiser Cement common shares will be
# delisted from the New York Stock Exchange.
# <MATCH> Chemlawn Corp and Ecolab Inc
# said they signed a definitive merger agreement under which
# Ecolab will buy all outstanding Chemlawn common stock for 36.
# <MATCH> . BIL opposes the Rainbow merger and
# analysts say BIL needs a 25 pct stake in Progressive to prevent
# it occurring.
# <MATCH> .
#     Greyhound announced June 19 that it wanted the ICC to let
# it begin operating Trailways immediately while continuing to
# evaluate the merger for possible antitrust problems.
# <MATCH> Wesbanco Inc said its board
# executed a merger agreement with the &lt;Bank of Sissonville>.
# <MATCH> . "The frenzy and disruption created by merger mania
# is particularly distressing.
# <MATCH> .
#     The offer will be followed by a merger in which each
# remaining share will be converted into 19.
# <MATCH> Ranco Inc said shareholders at a
# special meeting approved a merger into &lt;Siebe PLC> for 40 dlrs
# per share.
# <MATCH> Allegheny International Inc,
# the consumer products concern that today announced a merger
# agreement with a First Boston Corp &lt;FBC> affiliate in a deal
# worth about 500 mln dlrs, said it intends to divest more units
# as a way to increase profits.
# <MATCH> .
#     While mergers and acquisitions among U.
# <MATCH> The directors of Hughes Tool Co
# &lt;HT> said they would recommend to shareholders that they reject
# a merger with Baker International Corp &lt;BKO> today.
# <MATCH> .
#     Under the merger agreement, remaining shareholders of
# Hayes, a Jackson, Mich.
# <MATCH> .
# Local time (1600 GMT) to discuss the proposed merger.
# <MATCH> .
#     In order for the other carriers to come down to TWA's wage
# scale in a merger, TWA would have to be the surviving entity,
# analysts said.
# <MATCH> . Closing of the merger would occur immediately after
# the filing, it said.
# <MATCH> .
# Her favorite is Baker International, which is involved in a
# possible merger with Hughes Tool Co.
# <MATCH> . The merger is
# subject to court approval of the settlement as well as to other
# conditions.
# <MATCH>
#     The ICC had rejected in July the merger of the Santa Fe and
# Southern Pacific Railroads on the grounds that it would reduce
# competition.
# <MATCH> .25 dlrs each,
# exercisable if it should fail to meet any condition connected
# with the transaction or if principal shareholders should accept
# a merger offer from another party.
# <MATCH> .
#     Rosenfeld joined Salomon in 1979 and has been a member of
# Salomon Brothers' merger and acquisitions group.
# <MATCH> .
#     The ministry's stance has outraged both London, which has
# threatened to retaliate, and Washington, which says the merger
# plan is evidence of Japan's failure to honour pledges to open
# its telecommunications market.
# <MATCH> .
#     The spokesman said agency action on the proposed merger
# application could take as long as six months.
# <MATCH> North American Communications Corp
# said it is considering several options to maximize shareholder
# value, including a possible sale, merger, corporate
# restructuring, or leveraged buyout.
# <MATCH> . which conducted the survey, said the study
# grew out of concern that mergers and acquisitions had seriously
# hurt the economic climate of northern California.
# <MATCH> .
#     The company said it expects to proceed with a merger and
# has advised Cyclops it intends to increas the per-share amount
# to be paid in the merger to 95 dlrs, form 90.
# <MATCH>
#     Under terms of the merger, Fair Lanes said each of its
# shares of common stock will be converted into the right to
# receive 1.
# <MATCH> Tender Loving Care Health Care
# Services Inc said it and Staff Buildiers Inc have extended the
# term of their merger agreement until May 31.
# <MATCH> .
#     As part of the plan, the company will change its state of
# incorporation from Florida to Delaware by means of a merger of
# Caesars World into a wholly owned subsidiary of the company.
# <MATCH> .
#     "Analysts are picking up British Airways because it's a
# major airline, and because they have fewer companies to work
# with after all the mergers," said Merrill Lynch analyst Edmund
# Greenslet.
# <MATCH> .
#     Kansas also said it argued in the ICC filing that Santa Fe
# had not met the legal requirements justifying the Commission's
# reconsideration of the proposed merger of Santa Fe and Southern
# Pacific, two railroads that it said basically parallel each
# other throughout their routes.
# <MATCH> PLM Cos Inc said its PLM Power Co
# unit broke off merger discussions with Sunlaw Energy Corp of
# Beverly Hills, Calif.
# <MATCH> .
#     The Hughes board last week indicated that it might cancel
# the merger because of the Department of Justice requirement.
# <MATCH> .
#     The company said the merger is expected to be completed
# after mid-year, following regulatory approval.
# <MATCH>
#     The ICC had rejected in July, on grounds it would reduce
# competition, the merger of the Santa Fe and Southern Pacific
# Railroads.
# <MATCH> .5
# pct of Harper and Row, had offered to discuss a merger with
# Harper and Row.
# <MATCH> .
#     REPH's board has appointed a special committee to negotiate
# terms of the proposed merger, Pesch said.
# <MATCH> .
#     The aim of the merger is to seek Recognised Investment
# Exchange status as required by the 1986 Financial Services Act.
# <MATCH> "
#     Comsat, created by a 1962 act of Congress, and Contel, a
# corporation of local telephone and communications firms, filed
# with the Federal Communications Commission last November 3 an
# application for merger.
# <MATCH>
#     Shearson said Stearns formerly was part of Merrill Lynch
# Pierce, Fenner and Smith Inc's &lt;MER> merger and acquisitions
# department.
# <MATCH> . The merger will provide an
# opportunity for expansion in an area with favorable economic
# trends, although it will lower trading margins by more than
# Sainsbury's historic levels, S and P pointed out.
# <MATCH> .
#     The merger is effective April one and is subject to
# shareholder approval.
# <MATCH>
#     Citadel said it is continuing to pursue its claims against
# Salomon Inc &lt;SB>, which represented it in connection with the
# disputed proposed merger with Great Western that was the
# subject of the litigation.
# <MATCH>
#     The companies said the previously announced merger has been
# approved by TI-CARO's board and is expected to close by early
# April.
# <MATCH> Kansas City Southern
# Industries Inc said an attempt by Santa Fe Southern Pacific Co
# &lt;SFX> to reopen the proposed merger of the Atchison, Topeka and
# Santa Fe Railway Co and the Southern Pacific Transportation Co
# offers "nothing truly new.
# <MATCH> .
#     The company said Heck's Chapter 11 filing could, however,
# affect Viner's previously reported legal action to recover
# costs from an aborted merger agreement with Heck's.
# <MATCH> .1 pct of those
# outstanding, for 6,950,000 dlrs immediately prior to the
# consummation of the merger.
# <MATCH> Development Corp of America
# said its merger with Lennar Corp &lt;LEN> was completed and its
# stock no longer existed.
# <MATCH>
#     The companies said they expect to complete the merger,
# which will create a bank with 80 billion dlrs of assets, by the
# end of the second quarter.
# <MATCH> .
#     Hoechst and Celanese completed their merger last month.
# <MATCH> .
#     With completion of the merger, Shefra changed its name to
# Flyfaire International Inc.
# <MATCH> .
#     The voting trust agreement requires the bank to vote in
# favor of any acquisition agreement between TWA and USAir and to
# opposed any other merger of USAir.
# <MATCH>
#     Under the terms of the merger, Sovereign stockholders
# wil receive, in a tax free exchange, 0.
# <MATCH> .
#     Earlier this week, ChemLawn agreed to accept a merger
# proposal at 36.
# <MATCH> . Interstate Commerce Commission
# to reconsider its earlier rejection of the merger of the
# holding company's railroad assets.
# <MATCH> The Chubb Corp said it completed the
# previously-announced merger of its subsidiary with and into
# Sovereign Corp &lt;SOVR>, a life insurance holding company.
# <MATCH>
#     The merger would add Community Bank's 20 mln dlrs in assets
# to 1st Source's more than one billion dlrs in assets, 1st
# Source said.
# <MATCH> .
#     USG also said shareholders will be asked to approve an
# amendment to its restated certificate of incorporation that
# includes staggered election of directors and the requirement of
# an 80 pct vote on certain mergers and asset sales or leases.
# <MATCH> ."
#     The merger, announced in February, involves the formation
# of a new company, &lt;Astral Pacific Corp Ltd>, which Rainbow and
# Progressive shareholders will enter into on a one-for-one share
# basis.
# <MATCH> .
# Supreme Court decided in mid-1985 to permit the mergers.
# <MATCH> .2 pct of the total, and left open
# the possibility that it might acquire more through a merger.
# <MATCH> . The merger is
# subject to GGHF's receiving financing for the plan, Datron
# said.
# <MATCH> .
#     Borg-Warner and Merrill said yesterday they entered a
# definitive merger agreement, under which a subsidiary of the
# new company, &lt;AV Holdings Corp>, will begin a 48.
# <MATCH> .
#     Redstone said the management group's investment bankers
# will be paid what is due for termination of its merger
# agreement.
# <MATCH>
#     So far few deals have become reality, however, despite a
# swirl of rumors and merger talks.
# <MATCH> .
#     Hutton said in the merger shareholders would get 46 mln
# dlrs aggregate amount of guaranteed debentures due 2002 of PC
# Acquisition and warrants to buy 15 pct of the common stock of
# the PC courier subsidiary.
# <MATCH> Shearson Lehman Brothers, a unit of
# American Express Co &lt;AXP>, said Robert Stearns has joined the
# company as managing director of its merger and acquisition
# department.
# <MATCH> .
#     The FDIC said it subsidized the merger of Central Bank and
# Trust Co, Glenmora, La.
# <MATCH> Grease Monkey Holding Corp said it has
# received and rejected an unsolicited merger offer from Jiffy
# Lube International Inc &lt;LUBE>.
# <MATCH> ."
#     Kistler also said that the law suit filed by Baker "was not
# a factor" in the board's decision to keep its merger proposal
# on the table.
# <MATCH> .
#     Charter said the merger is subject to approval of the
# Federal Home Loan Bank Board.
# <MATCH> .
#     Members of the three exchanges have been consulted,
# Agricultural Futures Exchange secretary Bill Englebright told
# Reuters, and no objections have been raised to the merger.
# <MATCH> . The
# offer, which has been approved by the Auxton board and is to be
# followed by a merger at the same price, is conditioned on
# receipt of a majority of Auxton's voting stock on a fully
# diluted basis.
# <MATCH> .
#     The company said a definitive merger agreement is expected
# to be negotiated within six weeks and shareholders are expected
# to vote on the deal at a meeting expected to be held in June or
# July.
# <MATCH> .
#     Marshall said deregulation will spawn more European
# airlines, possibly to be followed by a spate of mergers, as is
# happening in the United States.
# <MATCH> .
#     A Norfolk Southern Corp &lt;NSC> spokesman said the company
# had no comment on TWA's offer for USAir or on its proposal to
# negotiate a three-way merger between TWA, USAir and Piedmont.
# <MATCH>
#     "Our hope is that we can come to a mutual agreement that is
# good for both companies," Kistler said of the proposed merger
# that would result in a 1.
# <MATCH> . As such, it will be active in equity trading and will
# advise on new issues, listings, mergers and acquisitions.
# <MATCH> Standard and Poor's Corp said it
# downgraded Baker International Corp and upgraded Hughes Tool Co
# to reflect the companies' merger into Baker Hughes Inc.
# <MATCH> .
#     Keycorp said the merger is expected to become effective as
# soon as possible after December 31, 1987, the date Utah's
# interstate banking law becomes operational.
# <MATCH> .
#     The merger agreement was announced earlier this week.
# <MATCH> Independence Bancorp Inc said
# it completed its merger with Scranton, Penn.
# <MATCH>  Both boards have approved the merger.
# <MATCH> .  Captive had 2,649,500 common shares outstanding
# before the merger.
# <MATCH> .
#     Operations are dependent upon financing and efforts to
# obtain financing, including potential buyers and merger
# candidates, have been unsuccessful, it said.
# <MATCH> Universal Resources Corp said its
# shareholders approved the merger of the company with Questar
# Corp &lt;STR>.
# <MATCH> .
#     A MITI official told Reuters he did not rule out the
# possibility of further mergers within the Japanese oil industry
# in the event of the relaxation of oil controls.
# <MATCH>
#     Scocozza said most of the recent mergers involved airlines
# in financial difficulty being taken over by other carriers.
# <MATCH> .
#     Rainbow has said the merger is soundly based.
# <MATCH> .
#     Instinet said it expects the merger to become effective as
# soon as possible after shareholder approval at the special
# meeting.
# <MATCH> . He said if outside directors approve the management
# proposal, a merger plan could be put to a vote of shareholders
# with proxy material going out late this week.
# <MATCH> .
#     Bradt was referring to a merger among the four exchanges at
# the Commodity Exchange Center, an idea that has been discussed
# intermittently for several years.
# <MATCH> .
#     S and P cited the completion of the firm's merger with PNC
# Financial Corp &lt;PNCF>, saying PNC has shown solid earnings,
# excellent liquidity and a conservative capital position.
# <MATCH> .
#     Instinet said the filing of the preliminary merger proxy
# materials is tied to the finalization of audited financial
# statements of Instinet and Reuters for 1986.
# <MATCH> .
#     The investment company said after the merger the combined
# company will have 15 mln shares outstanding.
# <MATCH> MCO Holdings Inc said its
# shareholders and those of MAXXAM Group Inc have approved the
# proposed merger of the two companies.
# <MATCH> .1 billion vs 900 mln
#     Note: Year-ago results restated to reflect merger with
# Colson Inc.
# <MATCH> Hoechst Celanese Corp, a recently
# formed subsidiary of Hoechst AG of Frankfurt, West Germany,
# filed with the Securities and Exchange Commission for a 500 mln
# dlr debt offering to repay part of its merger debt.
# <MATCH> Corporate mergers and acquisitions
# in and around San Francisco over the past seven years have had
# only a modest effect on the metropolitan area's economy, a
# leading business-backed organization said.
# <MATCH> . Based on its financial
# expectations, Fifth Third said the dilution in per share
# earnings for the merger will be negligible.
# <MATCH> . The offer, which has been approved by the
# Holly board and is to be followed by a merger in which
# remaining shares are to be exchanged for cumulative redeemable
# exchangeable preferred stock, is conditioned on receipt of at
# least 664,400 shares, which would give Plum a two thirds
# interest, and the receipt of financing.
# <MATCH> . It had also proposed
# a takeover of USAir, which at the time was negotiating its
# proposed merger with Piedmont Aviation Inc.
# <MATCH>
#     The tender offer and merger are subject to customary
# conditions and expiration of the Hart-Scott-Rodino notification
# waiting period, they said.
# <MATCH> "
#     Hughes' board today again adjourned a shareholders meeting
# to vote on the proposed merger and rescheduled it for March 11
# to give Baker more time to consider the counter proposal.
# <MATCH> .
#     The 1987 pro forma first quarter results include
# nonrecurring merger expenses of 4.
# <MATCH> .
#     For Computer Associates, the merger with Uccel caps a
# six-year acquisition campaign that has vaulted the Garden City,
# N.
# <MATCH> .,
# businessman and major shareholder of Kappa Networks Inc, said
# he and Kappa's management are considering seeking a merger
# between Kappa and Radiation Systems Inc.
# <MATCH> . The
# firm has long been at the leading edge of the mergers business
# and had ties to now-disgraced speculator Ivan Boesky.
# <MATCH> .
#     The government plans to help the industry shed 20 pct of
# current capacity within two years through mergers and
# regrouping under legislation put before Parliament this month
# and likely to be approved by May or June, the sources said.
# <MATCH> .
#     However, the suggestion still recommended a merger between
# the two consortia tendering for contracts and would give Cable
# a five pct stake, more than the three pct originally proposed
# but less than the 20 pct it holds in its original venture, he
# said.
# <MATCH> Delta Air Lines &lt;DAL> said a court
# order requiring Western Air Lines &lt;WAL> to arbitrate with two
# ...
# any merger or acquisition discussions.
# <MATCH> . The company said it will
# treat the merger as a pooling of interests.
# <MATCH> .
#     Stressing that company growth would be internal, McGough
# told reporters "that our game plan does not call for an
# acquisition," saying Bache recently rejected merger overtures
# from three other investment dealers in Canada.
# <MATCH> .
#     CBC said the merger will not affect Citizens Banks' name,
# management, board of directors or employees.
# <MATCH> Caremark Inc and Baxter
# Travenol Laboratories Inc jointly announced that Caremark
# shareholders will vote on July 31 to approve the previously
# announced merger with Baxter.
# <MATCH> Richmond Hill Savings Bank and
# &lt;Riverhead Savings Bank FSB> said they terminated their
# previously announced merger negotiations.
# <MATCH> .
#     Moody's said the anticipated merger of Baker and Hughes
# Tool into Baker Hughes Inc would result in increased financial
# leverage at a time of weak demand for the combined company's
# products and services.
# <MATCH> . He said he
# believes such a merger could create a stronger force in the
# tire industry.
# <MATCH>
#     Last night, Hughes said the planned merger with Baker was
# off.
# <MATCH> .
#     The proposed merger has sparked an international row, with
# British government sources threatening retaliatory action
# against Japan for what they see as discriminatory practices
# against foreign firms.
# <MATCH> .
#     "Unlike many recent combinations, this merger has no
# acquisition premium associated with it," Blampied said.
# <MATCH> .
#     Financial Corp, parent of American Savings and Loan
# Association, the nation's largest thrift, has repeatedly said
# it would give serious consideration to a merger as a means of
# rapidly improving its capital position.
# <MATCH> .
#     "Texaco has consistently maintained that Pennzoil did not
# have a binding contract to Buy Getty Oil shares, since a press
# release announced only an 'agreement in principle' which was
# 'subject to the execution of a definitive merger agreement',"
# according to Gayle.
# <MATCH> .
#     1986 net includes costs of 900,000 dlrs in quarter and
# 1,200,000 dlrs in year from proposed merger.
# <MATCH> . Has also attacked the original merger plans,
# saying that both rival consortia should be licensed.
# <MATCH> Baker International corp said it has
# filed suit in state court in Houston to compel Hughes Tool Co
# to complete its proposed merger with Baker.
# <MATCH> .
#     Following the merger, the two companies saw significant
# opportunities for growth in brokerage income and considerable
# scope for improved operating efficiency.
# <MATCH>
#     "The Transportation Department's antitrust enforcement has
# been disastrous, permitting rampant merger mania," Ohio
# Democrat Howard Metzenbaum said in a statement.
# <MATCH>
#     "The company's position is we would like to see the merger
# be completed, which is in the best interests of our
# shareholders and their shareholders," Mattson said.
# <MATCH> Liebert Corp said its shareholders
# approved the merger of a wholly-owned subsidiary of Emerson
# Electric Co &lt;EMR>.
# <MATCH> . industries; any differences are not
# significant for the purpose of merger analysis," Andewelt said.
# <MATCH> . Bere, who serves on the
# Hughes board, is believed to favor the merger with Baker.
# <MATCH> .
#     Analysts said the merger is virtually certain to go ahead.
# <MATCH> .
#     As announced February 26, the Staff Builders shareholders
# meeting to vote on the merger, originally convened and
# adjourned December 23, will be reconvened on April 22.
# <MATCH> .  Yesterday Citicorp &lt;CCI>, with Audio/Video Affiliates
# Inc &lt;AVA> an owner of CYACQ, said it had offered to acquire
# from Dixons after the merger of Cyclops into Dixons Cyclops'
# industrial businesses for 12.
# <MATCH> Valhi Inc, formed by the March 10 merger
# of Amalgamated Sugar Co into LLC Corp, said it had unaudited
# pro-forma earnings of 72 mln dlrs, or 61 cts a share, for the
# six months ended December 31.
# <MATCH> .
#     He said a merger would significantly enhance the financial
# turnaround that Purolator's management had previously forecast.
# <MATCH> .
#     Kistler estimated that the merger, which should be
# completed in about two weeks, will result in annual cost
# savings of about 50 mln dlrs.
# <MATCH> .
#     Danforth said he continues to see value in a merger between
# Westinghouse's radio operation and those of NBC.
# <MATCH> .
#     The company said it will hold a special meeting on July 10
# for a vote on approval of a merger at the tender price.
# <MATCH>
#     Late yesterday, Hughes said it had terminated the merger
# agreement because Baker would not agree to an alternative
# divestiture plan devised by Hughes.
# <MATCH> Merrill Lynch and Co Inc fired the
# head of the mergers department in its London office today,
# saying he had been unable to provide a "satisfactory
# explanation" in response to insider trading charges filed
# yesterday by the Securities and Exchange Commission.
# <MATCH> .
#     The merger of Rexnord with a subsidiary of Banner will be
# copmleted before mid-May, the company said.
# <MATCH> . In response, Emery said it would renew its request for
# a merger with the Basking Ridge, N.
# <MATCH> .
#     A Norstar spokesman said that a press release containing
# further details on the merger would be issued shortly.
# <MATCH> Interco Inc said its shareholders and
# those of Lane Co approved a merger of the two companies at
# special meetings.
# <MATCH> .
#     The company said the merger will be accounted for as a
# corporate reorganization and be recorded at historical book
# values.
# <MATCH> .
#     The merger is to be made by Onyx buying LASMO Exploration,
# in a share swap.
# <MATCH> .
#     Quest also said its signed a merger agreement with &lt;Hunt
# Research Corp> and its affiliate &lt;ICAS Corp>.
# <MATCH> ."
#     Gallo said FCS will stop actively seeking potential merger
# partners, but will respond to serious inquiries.
# <MATCH> .
#     Entertainment said the offer would be conducted through a
# negotiated merger with a new corporation to be formed by
# Entertainment Marketing.
# <MATCH>  The merger still requires
# shareholder approval.
# <MATCH> .
#     The DOT had given tentative approval to the merger plan
# Feb.
# <MATCH> .
#     OII said the New York Stock Exchange said the securities
# will be delisted as a result of the merger.
# <MATCH> Peat Marwick and KMG Main Hurdman said
# their merger will be completed tomorrow.
# <MATCH> .
#     He said the department considers the effect each merger
# will have on competition over all the routes involved and will
# not approve a merger which will reduce competition.
# <MATCH> Waste Management Inc said it
# sent a letter to the ChemLawn Corp board, saying it is prepared
# to increase its bid for ChemLawn to 33 dlrs a share,
# from 27 dlrs, if ChemLawn promptly negotiates and executes a
# simple two-step merger agreement containing only essential
# covenants and conditions.
# <MATCH> Prime Medical Services Inc said merger
# talks with National HMO Corp &lt;NHMO> have been terminated.
# <MATCH> . Stevens &lt;STN> climbed 5/8 to 44-7/8, and Fieldcrest
# Cannon Inc &lt;FLD>, the result of a merger of Fieldcrest and
# Cannon, rose 1-1/8 to 39-3/4.
# <MATCH>  He said the merger "lost a
# lot of its appeal" when the U.
# <MATCH> .
#     The financial terms of the merger are unchanged, a Hughes
# spokesman said.
# <MATCH> .9 common shares each, valued at
# about 73 dlrs per share based on the average closing price of
# USAir common during a period just before the merger.
# <MATCH> . The following results reflect the
# operations of the companies prior to the merger.
# <MATCH> . Britain opposes the proposed merger.
# <MATCH> .
#     However, political differences make a merger of the two
# federal funds unlikely, Isaac, now president of the Secura
# Group, a consulting firm, said.
# <MATCH> Quest Biotechnology Inc said its new
# subsidiary, Quest Blood Substitute Inc, signed the agreement
# and plan of merger with Hunt Research Corp and its affiliate,
# ICAS Corp.
# <MATCH> Hanson Trust PLC said Kaiser Cement
# shareholders today approved the previously announced merger
# agreement making Kaiser Cement an indirect wholly owned unit of
# Hanson Trust.
# <MATCH> .
#     Allied legal advisor and director George Kern, who heads
# the merger and acquisitions group at the New York law firm of
# Sullivan and Cromwell, decided against amending Allied's SEC
# filing to disclose the talks even though they had resulted in
# sales price of 405 mln dlrs for the shopping centers, it said.
# <MATCH> .
#     The company said its merger agreement with Piedmont
# provides that the offer is not to be amended without Piedmont's
# prior written consent in any way that would be adverse to
# Piedmont shareholders, but it said it could cut the number of
# shares to be bought without Piedmont's consent.
# <MATCH> .
#     The company said if the merger agreement is terminated
# under certain circumstasnces, it will be entitled to receive 20
# mln dlrs in damages from ChemLawn.
# <MATCH> Crazy Eddie Inc said its board has
# adopted a defensive shareholder rights plan and said it has
# reacived inquiries on a friendly merger.
# <MATCH> .
#     It said its suit names as defendants Hughes and certain of
# its directors and seeks either an injunction forcing Hughes to
# live up to the merger agreement or "substantial" monetary
# damages it did not name.
# <MATCH>
#     "I think the merger is not going through," said Phil Pace,
# analyst at Kidder, Peabody and Co.
# <MATCH> .
#     It said the agreement, under which it owns 50 pct of the
# partnership, enables it to move into the mergers and
# acquisitions business.
# <MATCH>
#     The study by the non partisan Congressional Research
# Service (CRS) said "the proposed merger appears to comply,
# technically, with the mandates or letter of statutes, if may
# nevertheless violate the spirit of the law.
# <MATCH> .
#     The proposal is also subject to a due diligence review,
# execution of a merger agreement, arrangement of financing and
# receipt of government approvals, all of which Gabelli and Co
# said could be completed within 60 days.
# <MATCH> .
#     Earlier this year, Williams suggested holding talks with
# Norcros on a possible merger but was rebuffed by Norcros which
# replied that any benefits that could be achieved could also
# result from normal trading.
# <MATCH> .
#     But it said investment banking firms should be allowed to
# continue to engage in both arbitrage and merger and acquisition
# activities so long as those functions were kept separate.
# <MATCH> &lt;Magellan Corp> said its shareholders
# approved the merger of Magellan with &lt;Balzec Investments Inc>,
#  a privately held company based in Dallas.
# <MATCH> The chiefs of Viacom International Inc
# and &lt;National Amusements Inc> said they met and agreed to work
# together to complete the previously announced merger of the two
# companies "as expeditiously as possible.
# <MATCH> .
#     It also said shareholders approved the merger of Morning
# Star Mine interests held by six corporations in exchange for
# issuing 2,098,602 shares of its common.
# <MATCH> .50 dlr a
# share takeover proposal last September, but subsequent merger
# talks broke down in October.
# <MATCH> .
#     Under a previously announced merger agreement, Amsouth
# offered 66 dlrs a share in Amsouth stock for First Tuskaloosa.
# <MATCH> . Figures for last
# year are unavailable as the bank was formed in June this year
# after a merger of two Dallas-based banks, RepublicBank Corp and
# InterFirst Corp.
# <MATCH> . The merger is
# expected to be completed in June, they said.
# <MATCH>
#     It said the price to be paid in the tender and merger could
# be reduced by any fees and expenses the court may award to
# counsel for the plaintiffs in the class action suit brought
# against it in Delaware Chancery Court by Ronda Inc.
# <MATCH> Marketing Systems of America Inc
# said it has retained Richter, Cohen and Co to assist in efforts
# to redirect its business through merger or acquisition.
# <MATCH> .
#     The company said its board recommended that shareholders
# approve the merger of the oilfield service companies.
# <MATCH> .
#     But a Cable spokesman said it still believed a merger of
# the two consortia would be impracticable.
# <MATCH> .
#     The company said its previously-announced merger into
# Inspectorate is still subject to approval by Network
# shareholders.
# <MATCH>
#     "Our plans were to finalize the merger at midnight tonight,"
# Delta spokesman Bill Berry told the Atlanta Constitution late
# last night.
# <MATCH> .
#     As a result of the merger, the former shareholders of
# Scan-Graphics will become the majority shareholders of Captive
# Venture Capital.
# <MATCH> .
#     The merger would give American control of 37 pct of the
# authorized takeoff and landing slots at the Orange County
# terminal, where environmental concerns and a small terminal
# building limit future opportunities for expansion.
# <MATCH>
#     A Supreme Court spokesman said O'Connor granted a stay of
# the injuction, allowing the merger, worth nearly 860 mln dlrs,
# to go through as planned later today.
# <MATCH> .
#     Under the merger, H.
# <MATCH> .
#     Analysts said that the drop in bank stock prices is likely
# to depress the level of mergers and acquisition in the banking
# industry.
# <MATCH> .T>, are
# considering a merger, company spokesmen said.
# <MATCH> .
#     The company said also before the merger, San/Bar would
# Barry K.
# <MATCH>  At midday today Hughes said
# it was still interested in the merger.
# <MATCH> .
#     Advanced said it had suspended merger talks with other
# parties as a result of the exclusivity agreement.
# <MATCH> .
#     The company said its merger last year with Associated Dry
# Goods, which was accounted for as a pooling of interests, is
# "going very well.
# <MATCH> ." Both will continue
# to operate existing headquarters after the merger.
# <MATCH>
#     Greyhound officials told Reuters late today the company
# hoped for ICC action on the merger by tomorrow.
# <MATCH> .
#     Around the auto industry there is talk of mergers and
# buyouts among dealerships, and there are rumors that the
# largest are considering offering shares to the public, analysts
# say.
# <MATCH> .
# Co &lt;CMCO> merger negotiations to determine the source of rumors
# that caused the stocks to rise prior to a public announcement
# in January.
# <MATCH> First Savings Bank of
# Florida said it expects a special shareholder meeting to be
# held around May 21 to consider the proposed merger into
# Gibraltar Financial Corp &lt;GFC>.
# <MATCH> .  The
# American Service board has approved the offer, which is to be
# followed by a merger at the same price.
# <MATCH>  Several firms had protested the
# proposed merger.
# <MATCH> . Industrial
# competitiveness, high labour costs and government restrictions
# on mergers, added little to the problem, it said.
# <MATCH> .
#     He said the company had exceeded its goal of cutting costs
# by 150 mln dlrs in the first year after the merger, and reduced
# debt by nearly two billion dlrs, more than the originally
# expected 1.
# <MATCH> . The SEC charged
# Nahum Vaskevitch, a managing director of Merrill Lynch, Pierce,
# Fenner and Smith Ltd, with profiting from inside information
# about 12 companies involved in mergers.
# <MATCH> ."
#     The study concluded that Chevron, which mergered with Gulf
# Oil in 1984, would benefit in the long run from the
# restructuring activity.
# <MATCH> . banking merger, can be completed by the beginning
# of 1988, according to an executive of Fleet.
# <MATCH> .
#     The executive said the merger would not alter his target of
# maintaining sales and earnings growth of 30 pct to 35 pct.
# <MATCH> . The
# company said a merger of Rexnord and a subsidiary of Banner
# will be completed before mid-May.
# <MATCH> .
#     The complaint said Vaskevitch leaked information about 12
# companies involved in a merger or acquisition which resulted in
# more than four mln dlrs in profit for himself and others
# involved in the scheme.
# <MATCH> . The Banco Pan de Azucar after being taken over by the
# Banco de la Republic in 1985 carried out a similar merger
# operation with the Banco de Italia.
# <MATCH> . Charles Bundrant,
# president of Trident before the merger, was named president of
# the new company, Conagra said.

# %% [markdown]
# # 3. Text Normalisation
#
# For most text analytics tasks, we will first need to transform the raw text to a suitable format for input to method such as a classifier. This process is called _text normalisation_ and is part of the _preprocessing_ stage. There are three common steps:
#
# 1. Sentence segmentation, which we have already been doing with regular expressions.
# 2. Tokenisation, in which the sentences are split into a sequence of tokens, which include words, numbers and punctuation marks.
# 3. Word normalisation, in which different forms of a word are replaced by a root form.
#
# We are now going to see how to perform these steps using the NLTK library.
#
# ## 3.1 Sentence Segmentation
#
# Let us start by using NLTK to split a document into sentences. This should give better results than our regular expressions above.
#
# You may get some errors from NLTK when you try to use sent_tokenize or word_tokenize further down. This is usually because you need to download and install some NLTK data. Please check the error message to find out which package is required. You probably need to install a package called 'punkt'. You can install this package by running `nltk.download('punkt')` and repeating for any other missing packages that you need.

# %%
# nltk.download('punkt')

# %%
import nltk

article = train_dataset[3]['text']

sents = nltk.sent_tokenize(article)

for sent in sents[:5]:
    print("<SENTENCE>")
    print(sent)  # print the first five sentences of this document
# Out:
# <SENTENCE>
# BankAmerica Corp is not under
# pressure to act quickly on its proposed equity offering and
# would do well to delay it because of the stock's recent poor
# performance, banking analysts said.
# <SENTENCE>
# Some analysts said they have recommended BankAmerica delay
# its up to one-billion-dlr equity offering, which has yet to be
# approved by the Securities and Exchange Commission.
# <SENTENCE>
# BankAmerica stock fell this week, along with other banking
# issues, on the news that Brazil has suspended interest payments
# on a large portion of its foreign debt.
# <SENTENCE>
# The stock traded around 12, down 1/8, this afternoon,
# after falling to 11-1/2 earlier this week on the news.
# <SENTENCE>
# Banking analysts said that with the immediate threat of the
# First Interstate Bancorp &lt;I> takeover bid gone, BankAmerica is
# under no pressure to sell the securities into a market that
# will be nervous on bank stocks in the near term.

# %% [markdown]
# TODO 4: Use the regular expression substitution code from section 2.2 to remove the new line characters from the sentences displayed above and print the results.

# %%
clean_sents = []

for sent in sents[:5]:
    
    ### COMPLETE YOUR CODE HERE
    sent = re.sub(r'\n+',' ',sent)
    
    print("<SENTENCE>")
    print(sent)  # print the first five sentences of this document
    
    clean_sents.append(sent)  # save the cleaned sentences for later
# Out:
# <SENTENCE>
# BankAmerica Corp is not under pressure to act quickly on its proposed equity offering and would do well to delay it because of the stock's recent poor performance, banking analysts said.
# <SENTENCE>
# Some analysts said they have recommended BankAmerica delay its up to one-billion-dlr equity offering, which has yet to be approved by the Securities and Exchange Commission.
# <SENTENCE>
# BankAmerica stock fell this week, along with other banking issues, on the news that Brazil has suspended interest payments on a large portion of its foreign debt.
# <SENTENCE>
# The stock traded around 12, down 1/8, this afternoon, after falling to 11-1/2 earlier this week on the news.
# <SENTENCE>
# Banking analysts said that with the immediate threat of the First Interstate Bancorp &lt;I> takeover bid gone, BankAmerica is under no pressure to sell the securities into a market that will be nervous on bank stocks in the near term.

# %% [markdown]
# ## 3.2 Tokenisation
#
# NLTK provides a similar function for tokenizing the text at the word level. You can find the documentation [here](https://www.nltk.org/api/nltk.tokenize.html).
#
# TODO 5: Use word_tokenize() to tokenize each of the sentences from the last cell.

# %%
tokenized_sents = []

for sent in clean_sents:
    ### WRITE YOUR OWN CODE HERE
    tokens = nltk.word_tokenize(sent)
    
    print("<TOKENS>")
    print(tokens)
    
    tokenized_sents.append(tokens)
# Out:
# <TOKENS>
# ['BankAmerica', 'Corp', 'is', 'not', 'under', 'pressure', 'to', 'act', 'quickly', 'on', 'its', 'proposed', 'equity', 'offering', 'and', 'would', 'do', 'well', 'to', 'delay', 'it', 'because', 'of', 'the', 'stock', "'s", 'recent', 'poor', 'performance', ',', 'banking', 'analysts', 'said', '.']
# <TOKENS>
# ['Some', 'analysts', 'said', 'they', 'have', 'recommended', 'BankAmerica', 'delay', 'its', 'up', 'to', 'one-billion-dlr', 'equity', 'offering', ',', 'which', 'has', 'yet', 'to', 'be', 'approved', 'by', 'the', 'Securities', 'and', 'Exchange', 'Commission', '.']
# <TOKENS>
# ['BankAmerica', 'stock', 'fell', 'this', 'week', ',', 'along', 'with', 'other', 'banking', 'issues', ',', 'on', 'the', 'news', 'that', 'Brazil', 'has', 'suspended', 'interest', 'payments', 'on', 'a', 'large', 'portion', 'of', 'its', 'foreign', 'debt', '.']
# <TOKENS>
# ['The', 'stock', 'traded', 'around', '12', ',', 'down', '1/8', ',', 'this', 'afternoon', ',', 'after', 'falling', 'to', '11-1/2', 'earlier', 'this', 'week', 'on', 'the', 'news', '.']
# <TOKENS>
# ['Banking', 'analysts', 'said', 'that', 'with', 'the', 'immediate', 'threat', 'of', 'the', 'First', 'Interstate', 'Bancorp', '&', 'lt', ';', 'I', '>', 'takeover', 'bid', 'gone', ',', 'BankAmerica', 'is', 'under', 'no', 'pressure', 'to', 'sell', 'the', 'securities', 'into', 'a', 'market', 'that', 'will', 'be', 'nervous', 'on', 'bank', 'stocks', 'in', 'the', 'near', 'term', '.']

# %% [markdown]
# Run the code below to see how NLTK has handled the non-letter characters.
# * What does it do with most punctuation marks?
# * When does it not split tokens based on punctuation?

# %%
for sent in tokenized_sents:
    for tok in sent:
        if re.search(r'[^a-zA-Z0-9]', tok):  # find the non-letter and non-digit characters
            print(tok)
# Out:
# 's
# ,
# .
# one-billion-dlr
# ,
# .
# ,
# ,
# .
# ,
# 1/8
# ,
# ,
# 11-1/2
# .
# &
# ;
# >
# ,
# .

# %% [markdown]
# ## 3.3 Word Normalisation
#
# Many words can appear in different forms, including:
# * Conjugated verbs
# * Plural and singular nouns
# * Common abbrevations and synonyms like "USA" and "US".
#
# Mapping all of these surface forms to a single root form reduces the size of the vocabulary that we have to deal with and can therefore improve the performance of text classifiers or topic models.
#
# The two most widely used tools for this task in English are the Porter Stemmer and WordNet Lemmatizer. These tools apply a series of regular expression substitutions to tokenised text to convert words to a standard format.
# * The Porter stemmer is much faster but just removes word prefixes and endings, which leads to some errors. It is often used when real-time or high-volume text processing is needed.
# * As well as applying regular expressions, lemmatizers look words up in a dictionary to find their root forms, so are more accurate but much slower.
#
# Let's start by applying the [Porter Stemmer class](https://www.nltk.org/_modules/nltk/stem/porter.html) to our tokenised text by calling the stem() method:

# %%
stemmer = nltk.PorterStemmer() 
stemmed_sents = []

for sent in tokenized_sents:
    stemmed_sent = [stemmer.stem(tok) for tok in sent]
    
    stemmed_sents.append(stemmed_sent)
    
    print("<STEMMED TOKENS>")
    print(stemmed_sent)
# Out:
# <STEMMED TOKENS>
# ['bankamerica', 'corp', 'is', 'not', 'under', 'pressur', 'to', 'act', 'quickli', 'on', 'it', 'propos', 'equiti', 'offer', 'and', 'would', 'do', 'well', 'to', 'delay', 'it', 'becaus', 'of', 'the', 'stock', "'s", 'recent', 'poor', 'perform', ',', 'bank', 'analyst', 'said', '.']
# <STEMMED TOKENS>
# ['some', 'analyst', 'said', 'they', 'have', 'recommend', 'bankamerica', 'delay', 'it', 'up', 'to', 'one-billion-dlr', 'equiti', 'offer', ',', 'which', 'ha', 'yet', 'to', 'be', 'approv', 'by', 'the', 'secur', 'and', 'exchang', 'commiss', '.']
# <STEMMED TOKENS>
# ['bankamerica', 'stock', 'fell', 'thi', 'week', ',', 'along', 'with', 'other', 'bank', 'issu', ',', 'on', 'the', 'news', 'that', 'brazil', 'ha', 'suspend', 'interest', 'payment', 'on', 'a', 'larg', 'portion', 'of', 'it', 'foreign', 'debt', '.']
# <STEMMED TOKENS>
# ['the', 'stock', 'trade', 'around', '12', ',', 'down', '1/8', ',', 'thi', 'afternoon', ',', 'after', 'fall', 'to', '11-1/2', 'earlier', 'thi', 'week', 'on', 'the', 'news', '.']
# <STEMMED TOKENS>
# ['bank', 'analyst', 'said', 'that', 'with', 'the', 'immedi', 'threat', 'of', 'the', 'first', 'interst', 'bancorp', '&', 'lt', ';', 'i', '>', 'takeov', 'bid', 'gone', ',', 'bankamerica', 'is', 'under', 'no', 'pressur', 'to', 'sell', 'the', 'secur', 'into', 'a', 'market', 'that', 'will', 'be', 'nervou', 'on', 'bank', 'stock', 'in', 'the', 'near', 'term', '.']

# %% [markdown]
# Now let us compare the stemming results to lemmatisation. For this task, NLTK provides the [class WordNetLemmatizer](https://www.nltk.org/_modules/nltk/stem/wordnet.html) with the method lemmatize(). This method takes an argument, `pos`, that determines whether the lemmatizer is applied to nouns, verbs, adjectives or adverbs.
#
# TODO 6: Use the WordNetLemmatizer to lemmatize the nouns in the tokenized sentences. Set the `pos` argument to 'n'.
#
# TODO 7: Add a second call to lemmatize() to lemmatize the verbs in the sentences as well. Set the `pos` argument to 'v'.
#
# How do the results compare with the Porter stemmer?
#
# How have the verbs in the sentences changed?

# %%
# nltk.download('wordnet')

# %%
lemmatizer = nltk.WordNetLemmatizer() 
nltk.download('wordnet')
lemma_sents = []
for sent in tokenized_sents:
    
    ### WRITE YOUR OWN CODE HERE
    lemma_sent = [lemmatizer.lemmatize(lemmatizer.lemmatize(tok, pos='v'), pos='n') for tok in sent]
    #######
    
    lemma_sents.append(lemma_sent)
    
    print("<LEMMATIZED TOKENS>")
    print(lemma_sent)
# Out:
# <LEMMATIZED TOKENS>
# ['BankAmerica', 'Corp', 'be', 'not', 'under', 'pressure', 'to', 'act', 'quickly', 'on', 'it', 'propose', 'equity', 'offer', 'and', 'would', 'do', 'well', 'to', 'delay', 'it', 'because', 'of', 'the', 'stock', "'s", 'recent', 'poor', 'performance', ',', 'bank', 'analyst', 'say', '.']
# <LEMMATIZED TOKENS>
# ['Some', 'analyst', 'say', 'they', 'have', 'recommend', 'BankAmerica', 'delay', 'it', 'up', 'to', 'one-billion-dlr', 'equity', 'offer', ',', 'which', 'have', 'yet', 'to', 'be', 'approve', 'by', 'the', 'Securities', 'and', 'Exchange', 'Commission', '.']
# <LEMMATIZED TOKENS>
# ['BankAmerica', 'stock', 'fell', 'this', 'week', ',', 'along', 'with', 'other', 'bank', 'issue', ',', 'on', 'the', 'news', 'that', 'Brazil', 'have', 'suspend', 'interest', 'payment', 'on', 'a', 'large', 'portion', 'of', 'it', 'foreign', 'debt', '.']
# <LEMMATIZED TOKENS>
# ['The', 'stock', 'trade', 'around', '12', ',', 'down', '1/8', ',', 'this', 'afternoon', ',', 'after', 'fall', 'to', '11-1/2', 'earlier', 'this', 'week', 'on', 'the', 'news', '.']
# <LEMMATIZED TOKENS>
# ['Banking', 'analyst', 'say', 'that', 'with', 'the', 'immediate', 'threat', 'of', 'the', 'First', 'Interstate', 'Bancorp', '&', 'lt', ';', 'I', '>', 'takeover', 'bid', 'go', ',', 'BankAmerica', 'be', 'under', 'no', 'pressure', 'to', 'sell', 'the', 'security', 'into', 'a', 'market', 'that', 'will', 'be', 'nervous', 'on', 'bank', 'stock', 'in', 'the', 'near', 'term', '.']
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
